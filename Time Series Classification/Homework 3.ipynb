# %% [markdown]
# # Name : Rohit Kulkarni USC ID : 5402749044

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from numpy import array
from sklearn.model_selection import train_test_split
import statsmodels.stats.api as sms
import numpy as np, scipy.stats as st
import itertools
from itertools import cycle
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn import svm, datasets
from sklearn.feature_selection import RFE
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn import metrics
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import roc_curve, auc
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
from sklearn.utils import shuffle
import warnings
warnings.filterwarnings("ignore",category=FutureWarning)
from sklearn.model_selection import cross_val_score
from scipy import stats
import statsmodels.api as sm
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# Reading Test Data

# %%
data_bending1_test_1=pd.read_csv("AReM/bending1/dataset1.csv", skiprows=4, error_bad_lines=False)
data_bending1_test_2=pd.read_csv("AReM/bending1/dataset2.csv", skiprows=4, error_bad_lines=False)

data_bending2_test_1=pd.read_csv("AReM/bending2/dataset1.csv", skiprows=4, error_bad_lines=False)
data_bending2_test_2=pd.read_csv("AReM/bending2/dataset2.csv", skiprows=4, error_bad_lines=False)

data_cycling_test_1=pd.read_csv("AReM/cycling/dataset1.csv", skiprows=4, error_bad_lines=False)
data_cycling_test_2=pd.read_csv("AReM/cycling/dataset2.csv", skiprows=4, error_bad_lines=False)
data_cycling_test_3=pd.read_csv("AReM/cycling/dataset3.csv", skiprows=4, error_bad_lines=False)

data_lying_test_1=pd.read_csv("AReM/lying/dataset1.csv", skiprows=4, error_bad_lines=False)
data_lying_test_2=pd.read_csv("AReM/lying/dataset2.csv", skiprows=4, error_bad_lines=False)
data_lying_test_3=pd.read_csv("AReM/lying/dataset3.csv", skiprows=4, error_bad_lines=False)

data_sitting_test_1=pd.read_csv("AReM/sitting/dataset1.csv", skiprows=4, error_bad_lines=False)
data_sitting_test_2=pd.read_csv("AReM/sitting/dataset2.csv", skiprows=4, error_bad_lines=False)
data_sitting_test_3=pd.read_csv("AReM/sitting/dataset3.csv", skiprows=4, error_bad_lines=False)

data_standing_test_1=pd.read_csv("AReM/standing/dataset1.csv", skiprows=4, error_bad_lines=False)
data_standing_test_2=pd.read_csv("AReM/standing/dataset2.csv", skiprows=4, error_bad_lines=False)
data_standing_test_3=pd.read_csv("AReM/standing/dataset3.csv", skiprows=4, error_bad_lines=False)

data_walking_test_1=pd.read_csv("AReM/walking/dataset1.csv", skiprows=4, error_bad_lines=False)
data_walking_test_2=pd.read_csv("AReM/walking/dataset2.csv", skiprows=4, error_bad_lines=False)
data_walking_test_3=pd.read_csv("AReM/walking/dataset3.csv", skiprows=4, error_bad_lines=False)

# %% [markdown]
# Reading Training Data

# %%
data_bending1_training_1=pd.read_csv("AReM/bending1/dataset3.csv", skiprows=4, error_bad_lines=False)
data_bending1_training_2=pd.read_csv("AReM/bending1/dataset4.csv", skiprows=4, error_bad_lines=False)
data_bending1_training_3=pd.read_csv("AReM/bending1/dataset5.csv", skiprows=4, error_bad_lines=False)
data_bending1_training_4=pd.read_csv("AReM/bending1/dataset6.csv", skiprows=4, error_bad_lines=False)
data_bending1_training_5=pd.read_csv("AReM/bending1/dataset7.csv", skiprows=4, error_bad_lines=False)

data_bending2_training_1=pd.read_csv("AReM/bending2/dataset3.csv", skiprows=4, error_bad_lines=False)
data_bending2_training_2=pd.read_csv("AReM/bending2/dataset4.csv", skiprows=4, error_bad_lines=False)
data_bending2_training_3=pd.read_csv("AReM/bending2/dataset5.csv", skiprows=4, error_bad_lines=False)
data_bending2_training_4=pd.read_csv("AReM/bending2/dataset6.csv", skiprows=4, error_bad_lines=False)

data_cycling_training_1=pd.read_csv("AReM/cycling/dataset4.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_2=pd.read_csv("AReM/cycling/dataset5.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_3=pd.read_csv("AReM/cycling/dataset6.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_4=pd.read_csv("AReM/cycling/dataset7.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_5=pd.read_csv("AReM/cycling/dataset8.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_6=pd.read_csv("AReM/cycling/dataset9.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_7=pd.read_csv("AReM/cycling/dataset10.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_8=pd.read_csv("AReM/cycling/dataset11.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_9=pd.read_csv("AReM/cycling/dataset12.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_10=pd.read_csv("AReM/cycling/dataset13.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_11=pd.read_csv("AReM/cycling/dataset14.csv", skiprows=4, error_bad_lines=False)
data_cycling_training_12=pd.read_csv("AReM/cycling/dataset15.csv", skiprows=4, error_bad_lines=False)

data_lying_training_1=pd.read_csv("AReM/lying/dataset4.csv", skiprows=4, error_bad_lines=False)
data_lying_training_2=pd.read_csv("AReM/lying/dataset5.csv", skiprows=4, error_bad_lines=False)
data_lying_training_3=pd.read_csv("AReM/lying/dataset6.csv", skiprows=4, error_bad_lines=False)
data_lying_training_4=pd.read_csv("AReM/lying/dataset7.csv", skiprows=4, error_bad_lines=False)
data_lying_training_5=pd.read_csv("AReM/lying/dataset8.csv", skiprows=4, error_bad_lines=False)
data_lying_training_6=pd.read_csv("AReM/lying/dataset9.csv", skiprows=4, error_bad_lines=False)
data_lying_training_7=pd.read_csv("AReM/lying/dataset10.csv", skiprows=4, error_bad_lines=False)
data_lying_training_8=pd.read_csv("AReM/lying/dataset11.csv", skiprows=4, error_bad_lines=False)
data_lying_training_9=pd.read_csv("AReM/lying/dataset12.csv", skiprows=4, error_bad_lines=False)
data_lying_training_10=pd.read_csv("AReM/lying/dataset13.csv", skiprows=4, error_bad_lines=False)
data_lying_training_11=pd.read_csv("AReM/lying/dataset14.csv", skiprows=4, error_bad_lines=False)
data_lying_training_12=pd.read_csv("AReM/lying/dataset15.csv", skiprows=4, error_bad_lines=False)

data_sitting_training_1=pd.read_csv("AReM/sitting/dataset4.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_2=pd.read_csv("AReM/sitting/dataset5.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_3=pd.read_csv("AReM/sitting/dataset6.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_4=pd.read_csv("AReM/sitting/dataset7.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_5=pd.read_csv("AReM/sitting/dataset8.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_6=pd.read_csv("AReM/sitting/dataset9.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_7=pd.read_csv("AReM/sitting/dataset10.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_8=pd.read_csv("AReM/sitting/dataset11.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_9=pd.read_csv("AReM/sitting/dataset12.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_10=pd.read_csv("AReM/sitting/dataset13.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_11=pd.read_csv("AReM/sitting/dataset14.csv", skiprows=4, error_bad_lines=False)
data_sitting_training_12=pd.read_csv("AReM/sitting/dataset15.csv", skiprows=4, error_bad_lines=False)

data_standing_training_1=pd.read_csv("AReM/standing/dataset4.csv", skiprows=4, error_bad_lines=False)
data_standing_training_2=pd.read_csv("AReM/standing/dataset5.csv", skiprows=4, error_bad_lines=False)
data_standing_training_3=pd.read_csv("AReM/standing/dataset6.csv", skiprows=4, error_bad_lines=False)
data_standing_training_4=pd.read_csv("AReM/standing/dataset7.csv", skiprows=4, error_bad_lines=False)
data_standing_training_5=pd.read_csv("AReM/standing/dataset8.csv", skiprows=4, error_bad_lines=False)
data_standing_training_6=pd.read_csv("AReM/standing/dataset9.csv", skiprows=4, error_bad_lines=False)
data_standing_training_7=pd.read_csv("AReM/standing/dataset10.csv", skiprows=4, error_bad_lines=False)
data_standing_training_8=pd.read_csv("AReM/standing/dataset11.csv", skiprows=4, error_bad_lines=False)
data_standing_training_9=pd.read_csv("AReM/standing/dataset12.csv", skiprows=4, error_bad_lines=False)
data_standing_training_10=pd.read_csv("AReM/standing/dataset13.csv", skiprows=4, error_bad_lines=False)
data_standing_training_11=pd.read_csv("AReM/standing/dataset14.csv", skiprows=4, error_bad_lines=False)
data_standing_training_12=pd.read_csv("AReM/standing/dataset15.csv", skiprows=4, error_bad_lines=False)

data_walking_training_1=pd.read_csv("AReM/walking/dataset4.csv", skiprows=4, error_bad_lines=False)
data_walking_training_2=pd.read_csv("AReM/walking/dataset5.csv", skiprows=4, error_bad_lines=False)
data_walking_training_3=pd.read_csv("AReM/walking/dataset6.csv", skiprows=4, error_bad_lines=False)
data_walking_training_4=pd.read_csv("AReM/walking/dataset7.csv", skiprows=4, error_bad_lines=False)
data_walking_training_5=pd.read_csv("AReM/walking/dataset8.csv", skiprows=4, error_bad_lines=False)
data_walking_training_6=pd.read_csv("AReM/walking/dataset9.csv", skiprows=4, error_bad_lines=False)
data_walking_training_7=pd.read_csv("AReM/walking/dataset10.csv", skiprows=4, error_bad_lines=False)
data_walking_training_8=pd.read_csv("AReM/walking/dataset11.csv", skiprows=4, error_bad_lines=False)
data_walking_training_9=pd.read_csv("AReM/walking/dataset12.csv", skiprows=4, error_bad_lines=False)
data_walking_training_10=pd.read_csv("AReM/walking/dataset13.csv", skiprows=4, error_bad_lines=False)
data_walking_training_11=pd.read_csv("AReM/walking/dataset14.csv", skiprows=4, error_bad_lines=False)
data_walking_training_12=pd.read_csv("AReM/walking/dataset15.csv", skiprows=4, error_bad_lines=False)
# Out:
# b'Skipping line 485: expected 7 fields, saw 8\n'
# b'Skipping line 485: expected 7 fields, saw 8\n'

# %%
new_dataset=pd.DataFrame(columns=['Instance','Min1','Max1','Mean1','Median1','SD1','1st Quartile1','3rd Quartile1','Min2','Max2','Mean2','Median2','SD2','1st Quartile2','3rd Quartile2','Min3','Max3','Mean3','Median3','SD3','1st Quartile3','3rd Quartile3','Min4','Max4','Mean4','Median4','SD4','1st Quartile4','3rd Quartile4','Min5','Max5','Mean5','Median5','SD5','1st Quartile5','3rd Quartile5','Min6','Max6','Mean6','Median6','SD6','1st Quartile6','3rd Quartile6'])

# %%
new_dataset=new_dataset.append({'Instance':'1','Min1':data_bending1_test_1['avg_rss12'].min(),'Max1': data_bending1_test_1['avg_rss12'].max(),'Mean1': data_bending1_test_1['avg_rss12'].mean(),'Median1': data_bending1_test_1['avg_rss12'].median(),'SD1': data_bending1_test_1['avg_rss12'].std(),'1st Quartile1': data_bending1_test_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending1_test_1['avg_rss12'].quantile(0.75),'Min2': data_bending1_test_1['var_rss12'].min(),'Max2': data_bending1_test_1['var_rss12'].max(),'Mean2': data_bending1_test_1['var_rss12'].mean(),'Median2': data_bending1_test_1['var_rss12'].median(),'SD2': data_bending1_test_1['var_rss12'].std(),'1st Quartile2': data_bending1_test_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending1_test_1['var_rss12'].quantile(0.75),'Min3': data_bending1_test_1['avg_rss13'].min(),'Max3': data_bending1_test_1['avg_rss13'].max(),'Mean3': data_bending1_test_1['avg_rss13'].mean(),'Median3': data_bending1_test_1['avg_rss13'].median(),'SD3': data_bending1_test_1['avg_rss13'].std(),'1st Quartile3': data_bending1_test_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending1_test_1['avg_rss13'].quantile(0.75),'Min4': data_bending1_test_1['var_rss13'].min(),'Max4': data_bending1_test_1['var_rss13'].max(),'Mean4': data_bending1_test_1['var_rss13'].mean(),'Median4': data_bending1_test_1['var_rss13'].median(),'SD4': data_bending1_test_1['var_rss13'].std(),'1st Quartile4': data_bending1_test_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending1_test_1['var_rss13'].quantile(0.75),'Min5': data_bending1_test_1['avg_rss23'].min(),'Max5': data_bending1_test_1['avg_rss23'].max(),'Mean5': data_bending1_test_1['avg_rss23'].mean(),'Median5': data_bending1_test_1['avg_rss23'].median(),'SD5': data_bending1_test_1['avg_rss23'].std(),'1st Quartile5': data_bending1_test_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending1_test_1['avg_rss23'].quantile(0.75),'Min6': data_bending1_test_1['var_rss23'].min(),'Max6': data_bending1_test_1['var_rss23'].max(),'Mean6': data_bending1_test_1['var_rss23'].mean(),'Median6': data_bending1_test_1['var_rss23'].median(),'SD6': data_bending1_test_1['var_rss23'].std(),'1st Quartile6': data_bending1_test_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending1_test_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'2','Min1':data_bending1_test_2['avg_rss12'].min(),'Max1': data_bending1_test_2['avg_rss12'].max(),'Mean1': data_bending1_test_2['avg_rss12'].mean(),'Median1': data_bending1_test_2['avg_rss12'].median(),'SD1': data_bending1_test_2['avg_rss12'].std(),'1st Quartile1': data_bending1_test_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending1_test_2['avg_rss12'].quantile(0.75),'Min2': data_bending1_test_2['var_rss12'].min(),'Max2': data_bending1_test_2['var_rss12'].max(),'Mean2': data_bending1_test_2['var_rss12'].mean(),'Median2': data_bending1_test_2['var_rss12'].median(),'SD2': data_bending1_test_2['var_rss12'].std(),'1st Quartile2': data_bending1_test_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending1_test_2['var_rss12'].quantile(0.75),'Min3': data_bending1_test_2['avg_rss13'].min(),'Max3': data_bending1_test_2['avg_rss13'].max(),'Mean3': data_bending1_test_2['avg_rss13'].mean(),'Median3': data_bending1_test_2['avg_rss13'].median(),'SD3': data_bending1_test_2['avg_rss13'].std(),'1st Quartile3': data_bending1_test_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending1_test_2['avg_rss13'].quantile(0.75),'Min4': data_bending1_test_2['var_rss13'].min(),'Max4': data_bending1_test_2['var_rss13'].max(),'Mean4': data_bending1_test_2['var_rss13'].mean(),'Median4': data_bending1_test_2['var_rss13'].median(),'SD4': data_bending1_test_2['var_rss13'].std(),'1st Quartile4': data_bending1_test_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending1_test_2['var_rss13'].quantile(0.75),'Min5': data_bending1_test_2['avg_rss23'].min(),'Max5': data_bending1_test_2['avg_rss23'].max(),'Mean5': data_bending1_test_2['avg_rss23'].mean(),'Median5': data_bending1_test_2['avg_rss23'].median(),'SD5': data_bending1_test_2['avg_rss23'].std(),'1st Quartile5': data_bending1_test_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending1_test_2['avg_rss23'].quantile(0.75),'Min6': data_bending1_test_2['var_rss23'].min(),'Max6': data_bending1_test_2['var_rss23'].max(),'Mean6': data_bending1_test_2['var_rss23'].mean(),'Median6': data_bending1_test_2['var_rss23'].median(),'SD6': data_bending1_test_2['var_rss23'].std(),'1st Quartile6': data_bending1_test_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending1_test_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'3','Min1':data_bending2_test_1['avg_rss12'].min(),'Max1': data_bending2_test_1['avg_rss12'].max(),'Mean1': data_bending2_test_1['avg_rss12'].mean(),'Median1': data_bending2_test_1['avg_rss12'].median(),'SD1': data_bending2_test_1['avg_rss12'].std(),'1st Quartile1': data_bending2_test_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending2_test_1['avg_rss12'].quantile(0.75),'Min2': data_bending2_test_1['var_rss12'].min(),'Max2': data_bending2_test_1['var_rss12'].max(),'Mean2': data_bending2_test_1['var_rss12'].mean(),'Median2': data_bending2_test_1['var_rss12'].median(),'SD2': data_bending2_test_1['var_rss12'].std(),'1st Quartile2': data_bending2_test_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending2_test_1['var_rss12'].quantile(0.75),'Min3': data_bending2_test_1['avg_rss13'].min(),'Max3': data_bending2_test_1['avg_rss13'].max(),'Mean3': data_bending2_test_1['avg_rss13'].mean(),'Median3': data_bending2_test_1['avg_rss13'].median(),'SD3': data_bending2_test_1['avg_rss13'].std(),'1st Quartile3': data_bending2_test_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending2_test_1['avg_rss13'].quantile(0.75),'Min4': data_bending2_test_1['var_rss13'].min(),'Max4': data_bending2_test_1['var_rss13'].max(),'Mean4': data_bending2_test_1['var_rss13'].mean(),'Median4': data_bending2_test_1['var_rss13'].median(),'SD4': data_bending2_test_1['var_rss13'].std(),'1st Quartile4': data_bending2_test_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending2_test_1['var_rss13'].quantile(0.75),'Min5': data_bending2_test_1['avg_rss23'].min(),'Max5': data_bending2_test_1['avg_rss23'].max(),'Mean5': data_bending2_test_1['avg_rss23'].mean(),'Median5': data_bending2_test_1['avg_rss23'].median(),'SD5': data_bending2_test_1['avg_rss23'].std(),'1st Quartile5': data_bending2_test_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending2_test_1['avg_rss23'].quantile(0.75),'Min6': data_bending2_test_1['var_rss23'].min(),'Max6': data_bending2_test_1['var_rss23'].max(),'Mean6': data_bending2_test_1['var_rss23'].mean(),'Median6': data_bending2_test_1['var_rss23'].median(),'SD6': data_bending2_test_1['var_rss23'].std(),'1st Quartile6': data_bending2_test_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending2_test_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'4','Min1':data_bending2_test_2['avg_rss12'].min(),'Max1': data_bending2_test_2['avg_rss12'].max(),'Mean1': data_bending2_test_2['avg_rss12'].mean(),'Median1': data_bending2_test_2['avg_rss12'].median(),'SD1': data_bending2_test_2['avg_rss12'].std(),'1st Quartile1': data_bending2_test_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending2_test_2['avg_rss12'].quantile(0.75),'Min2': data_bending2_test_2['var_rss12'].min(),'Max2': data_bending2_test_2['var_rss12'].max(),'Mean2': data_bending2_test_2['var_rss12'].mean(),'Median2': data_bending2_test_2['var_rss12'].median(),'SD2': data_bending2_test_2['var_rss12'].std(),'1st Quartile2': data_bending2_test_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending2_test_2['var_rss12'].quantile(0.75),'Min3': data_bending2_test_2['avg_rss13'].min(),'Max3': data_bending2_test_2['avg_rss13'].max(),'Mean3': data_bending2_test_2['avg_rss13'].mean(),'Median3': data_bending2_test_2['avg_rss13'].median(),'SD3': data_bending2_test_2['avg_rss13'].std(),'1st Quartile3': data_bending2_test_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending2_test_2['avg_rss13'].quantile(0.75),'Min4': data_bending2_test_2['var_rss13'].min(),'Max4': data_bending2_test_2['var_rss13'].max(),'Mean4': data_bending2_test_2['var_rss13'].mean(),'Median4': data_bending2_test_2['var_rss13'].median(),'SD4': data_bending2_test_2['var_rss13'].std(),'1st Quartile4': data_bending2_test_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending2_test_2['var_rss13'].quantile(0.75),'Min5': data_bending2_test_2['avg_rss23'].min(),'Max5': data_bending2_test_2['avg_rss23'].max(),'Mean5': data_bending2_test_2['avg_rss23'].mean(),'Median5': data_bending2_test_2['avg_rss23'].median(),'SD5': data_bending2_test_2['avg_rss23'].std(),'1st Quartile5': data_bending2_test_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending2_test_2['avg_rss23'].quantile(0.75),'Min6': data_bending2_test_2['var_rss23'].min(),'Max6': data_bending2_test_2['var_rss23'].max(),'Mean6': data_bending2_test_2['var_rss23'].mean(),'Median6': data_bending2_test_2['var_rss23'].median(),'SD6': data_bending2_test_2['var_rss23'].std(),'1st Quartile6': data_bending2_test_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending2_test_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'5','Min1':data_cycling_test_1['avg_rss12'].min(),'Max1': data_cycling_test_1['avg_rss12'].max(),'Mean1': data_cycling_test_1['avg_rss12'].mean(),'Median1': data_cycling_test_1['avg_rss12'].median(),'SD1': data_cycling_test_1['avg_rss12'].std(),'1st Quartile1': data_cycling_test_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_test_1['avg_rss12'].quantile(0.75),'Min2': data_cycling_test_1['var_rss12'].min(),'Max2': data_cycling_test_1['var_rss12'].max(),'Mean2': data_cycling_test_1['var_rss12'].mean(),'Median2': data_cycling_test_1['var_rss12'].median(),'SD2': data_cycling_test_1['var_rss12'].std(),'1st Quartile2': data_cycling_test_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_test_1['var_rss12'].quantile(0.75),'Min3': data_cycling_test_1['avg_rss13'].min(),'Max3': data_cycling_test_1['avg_rss13'].max(),'Mean3': data_cycling_test_1['avg_rss13'].mean(),'Median3': data_cycling_test_1['avg_rss13'].median(),'SD3': data_cycling_test_1['avg_rss13'].std(),'1st Quartile3': data_cycling_test_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_test_1['avg_rss13'].quantile(0.75),'Min4': data_cycling_test_1['var_rss13'].min(),'Max4': data_cycling_test_1['var_rss13'].max(),'Mean4': data_cycling_test_1['var_rss13'].mean(),'Median4': data_cycling_test_1['var_rss13'].median(),'SD4': data_cycling_test_1['var_rss13'].std(),'1st Quartile4': data_cycling_test_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_test_1['var_rss13'].quantile(0.75),'Min5': data_cycling_test_1['avg_rss23'].min(),'Max5': data_cycling_test_1['avg_rss23'].max(),'Mean5': data_cycling_test_1['avg_rss23'].mean(),'Median5': data_cycling_test_1['avg_rss23'].median(),'SD5': data_cycling_test_1['avg_rss23'].std(),'1st Quartile5': data_cycling_test_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_test_1['avg_rss23'].quantile(0.75),'Min6': data_cycling_test_1['var_rss23'].min(),'Max6': data_cycling_test_1['var_rss23'].max(),'Mean6': data_cycling_test_1['var_rss23'].mean(),'Median6': data_cycling_test_1['var_rss23'].median(),'SD6': data_cycling_test_1['var_rss23'].std(),'1st Quartile6': data_cycling_test_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_test_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'6','Min1':data_cycling_test_2['avg_rss12'].min(),'Max1': data_cycling_test_2['avg_rss12'].max(),'Mean1': data_cycling_test_2['avg_rss12'].mean(),'Median1': data_cycling_test_2['avg_rss12'].median(),'SD1': data_cycling_test_2['avg_rss12'].std(),'1st Quartile1': data_cycling_test_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_test_2['avg_rss12'].quantile(0.75),'Min2': data_cycling_test_2['var_rss12'].min(),'Max2': data_cycling_test_2['var_rss12'].max(),'Mean2': data_cycling_test_2['var_rss12'].mean(),'Median2': data_cycling_test_2['var_rss12'].median(),'SD2': data_cycling_test_2['var_rss12'].std(),'1st Quartile2': data_cycling_test_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_test_2['var_rss12'].quantile(0.75),'Min3': data_cycling_test_2['avg_rss13'].min(),'Max3': data_cycling_test_2['avg_rss13'].max(),'Mean3': data_cycling_test_2['avg_rss13'].mean(),'Median3': data_cycling_test_2['avg_rss13'].median(),'SD3': data_cycling_test_2['avg_rss13'].std(),'1st Quartile3': data_cycling_test_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_test_2['avg_rss13'].quantile(0.75),'Min4': data_cycling_test_2['var_rss13'].min(),'Max4': data_cycling_test_2['var_rss13'].max(),'Mean4': data_cycling_test_2['var_rss13'].mean(),'Median4': data_cycling_test_2['var_rss13'].median(),'SD4': data_cycling_test_2['var_rss13'].std(),'1st Quartile4': data_cycling_test_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_test_2['var_rss13'].quantile(0.75),'Min5': data_cycling_test_2['avg_rss23'].min(),'Max5': data_cycling_test_2['avg_rss23'].max(),'Mean5': data_cycling_test_2['avg_rss23'].mean(),'Median5': data_cycling_test_2['avg_rss23'].median(),'SD5': data_cycling_test_2['avg_rss23'].std(),'1st Quartile5': data_cycling_test_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_test_2['avg_rss23'].quantile(0.75),'Min6': data_cycling_test_2['var_rss23'].min(),'Max6': data_cycling_test_2['var_rss23'].max(),'Mean6': data_cycling_test_2['var_rss23'].mean(),'Median6': data_cycling_test_2['var_rss23'].median(),'SD6': data_cycling_test_2['var_rss23'].std(),'1st Quartile6': data_cycling_test_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_test_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'7','Min1':data_cycling_test_3['avg_rss12'].min(),'Max1': data_cycling_test_3['avg_rss12'].max(),'Mean1': data_cycling_test_3['avg_rss12'].mean(),'Median1': data_cycling_test_3['avg_rss12'].median(),'SD1': data_cycling_test_3['avg_rss12'].std(),'1st Quartile1': data_cycling_test_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_test_3['avg_rss12'].quantile(0.75),'Min2': data_cycling_test_3['var_rss12'].min(),'Max2': data_cycling_test_3['var_rss12'].max(),'Mean2': data_cycling_test_3['var_rss12'].mean(),'Median2': data_cycling_test_3['var_rss12'].median(),'SD2': data_cycling_test_3['var_rss12'].std(),'1st Quartile2': data_cycling_test_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_test_3['var_rss12'].quantile(0.75),'Min3': data_cycling_test_3['avg_rss13'].min(),'Max3': data_cycling_test_3['avg_rss13'].max(),'Mean3': data_cycling_test_3['avg_rss13'].mean(),'Median3': data_cycling_test_3['avg_rss13'].median(),'SD3': data_cycling_test_3['avg_rss13'].std(),'1st Quartile3': data_cycling_test_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_test_3['avg_rss13'].quantile(0.75),'Min4': data_cycling_test_3['var_rss13'].min(),'Max4': data_cycling_test_3['var_rss13'].max(),'Mean4': data_cycling_test_3['var_rss13'].mean(),'Median4': data_cycling_test_3['var_rss13'].median(),'SD4': data_cycling_test_3['var_rss13'].std(),'1st Quartile4': data_cycling_test_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_test_3['var_rss13'].quantile(0.75),'Min5': data_cycling_test_3['avg_rss23'].min(),'Max5': data_cycling_test_3['avg_rss23'].max(),'Mean5': data_cycling_test_3['avg_rss23'].mean(),'Median5': data_cycling_test_3['avg_rss23'].median(),'SD5': data_cycling_test_3['avg_rss23'].std(),'1st Quartile5': data_cycling_test_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_test_3['avg_rss23'].quantile(0.75),'Min6': data_cycling_test_3['var_rss23'].min(),'Max6': data_cycling_test_3['var_rss23'].max(),'Mean6': data_cycling_test_3['var_rss23'].mean(),'Median6': data_cycling_test_3['var_rss23'].median(),'SD6': data_cycling_test_3['var_rss23'].std(),'1st Quartile6': data_cycling_test_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_test_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'8','Min1':data_lying_test_1['avg_rss12'].min(),'Max1': data_lying_test_1['avg_rss12'].max(),'Mean1': data_lying_test_1['avg_rss12'].mean(),'Median1': data_lying_test_1['avg_rss12'].median(),'SD1': data_lying_test_1['avg_rss12'].std(),'1st Quartile1': data_lying_test_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_test_1['avg_rss12'].quantile(0.75),'Min2': data_lying_test_1['var_rss12'].min(),'Max2': data_lying_test_1['var_rss12'].max(),'Mean2': data_lying_test_1['var_rss12'].mean(),'Median2': data_lying_test_1['var_rss12'].median(),'SD2': data_lying_test_1['var_rss12'].std(),'1st Quartile2': data_lying_test_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_test_1['var_rss12'].quantile(0.75),'Min3': data_lying_test_1['avg_rss13'].min(),'Max3': data_lying_test_1['avg_rss13'].max(),'Mean3': data_lying_test_1['avg_rss13'].mean(),'Median3': data_lying_test_1['avg_rss13'].median(),'SD3': data_lying_test_1['avg_rss13'].std(),'1st Quartile3': data_lying_test_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_test_1['avg_rss13'].quantile(0.75),'Min4': data_lying_test_1['var_rss13'].min(),'Max4': data_lying_test_1['var_rss13'].max(),'Mean4': data_lying_test_1['var_rss13'].mean(),'Median4': data_lying_test_1['var_rss13'].median(),'SD4': data_lying_test_1['var_rss13'].std(),'1st Quartile4': data_lying_test_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_test_1['var_rss13'].quantile(0.75),'Min5': data_lying_test_1['avg_rss23'].min(),'Max5': data_lying_test_1['avg_rss23'].max(),'Mean5': data_lying_test_1['avg_rss23'].mean(),'Median5': data_lying_test_1['avg_rss23'].median(),'SD5': data_lying_test_1['avg_rss23'].std(),'1st Quartile5': data_lying_test_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_test_1['avg_rss23'].quantile(0.75),'Min6': data_lying_test_1['var_rss23'].min(),'Max6': data_lying_test_1['var_rss23'].max(),'Mean6': data_lying_test_1['var_rss23'].mean(),'Median6': data_lying_test_1['var_rss23'].median(),'SD6': data_lying_test_1['var_rss23'].std(),'1st Quartile6': data_lying_test_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_test_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'9','Min1':data_lying_test_2['avg_rss12'].min(),'Max1': data_lying_test_2['avg_rss12'].max(),'Mean1': data_lying_test_2['avg_rss12'].mean(),'Median1': data_lying_test_2['avg_rss12'].median(),'SD1': data_lying_test_2['avg_rss12'].std(),'1st Quartile1': data_lying_test_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_test_2['avg_rss12'].quantile(0.75),'Min2': data_lying_test_2['var_rss12'].min(),'Max2': data_lying_test_2['var_rss12'].max(),'Mean2': data_lying_test_2['var_rss12'].mean(),'Median2': data_lying_test_2['var_rss12'].median(),'SD2': data_lying_test_2['var_rss12'].std(),'1st Quartile2': data_lying_test_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_test_2['var_rss12'].quantile(0.75),'Min3': data_lying_test_2['avg_rss13'].min(),'Max3': data_lying_test_2['avg_rss13'].max(),'Mean3': data_lying_test_2['avg_rss13'].mean(),'Median3': data_lying_test_2['avg_rss13'].median(),'SD3': data_lying_test_2['avg_rss13'].std(),'1st Quartile3': data_lying_test_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_test_2['avg_rss13'].quantile(0.75),'Min4': data_lying_test_2['var_rss13'].min(),'Max4': data_lying_test_2['var_rss13'].max(),'Mean4': data_lying_test_2['var_rss13'].mean(),'Median4': data_lying_test_2['var_rss13'].median(),'SD4': data_lying_test_2['var_rss13'].std(),'1st Quartile4': data_lying_test_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_test_2['var_rss13'].quantile(0.75),'Min5': data_lying_test_2['avg_rss23'].min(),'Max5': data_lying_test_2['avg_rss23'].max(),'Mean5': data_lying_test_2['avg_rss23'].mean(),'Median5': data_lying_test_2['avg_rss23'].median(),'SD5': data_lying_test_2['avg_rss23'].std(),'1st Quartile5': data_lying_test_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_test_2['avg_rss23'].quantile(0.75),'Min6': data_lying_test_2['var_rss23'].min(),'Max6': data_lying_test_2['var_rss23'].max(),'Mean6': data_lying_test_2['var_rss23'].mean(),'Median6': data_lying_test_2['var_rss23'].median(),'SD6': data_lying_test_2['var_rss23'].std(),'1st Quartile6': data_lying_test_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_test_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'10','Min1':data_lying_test_3['avg_rss12'].min(),'Max1': data_lying_test_3['avg_rss12'].max(),'Mean1': data_lying_test_3['avg_rss12'].mean(),'Median1': data_lying_test_3['avg_rss12'].median(),'SD1': data_lying_test_3['avg_rss12'].std(),'1st Quartile1': data_lying_test_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_test_3['avg_rss12'].quantile(0.75),'Min2': data_lying_test_3['var_rss12'].min(),'Max2': data_lying_test_3['var_rss12'].max(),'Mean2': data_lying_test_3['var_rss12'].mean(),'Median2': data_lying_test_3['var_rss12'].median(),'SD2': data_lying_test_3['var_rss12'].std(),'1st Quartile2': data_lying_test_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_test_3['var_rss12'].quantile(0.75),'Min3': data_lying_test_3['avg_rss13'].min(),'Max3': data_lying_test_3['avg_rss13'].max(),'Mean3': data_lying_test_3['avg_rss13'].mean(),'Median3': data_lying_test_3['avg_rss13'].median(),'SD3': data_lying_test_3['avg_rss13'].std(),'1st Quartile3': data_lying_test_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_test_3['avg_rss13'].quantile(0.75),'Min4': data_lying_test_3['var_rss13'].min(),'Max4': data_lying_test_3['var_rss13'].max(),'Mean4': data_lying_test_3['var_rss13'].mean(),'Median4': data_lying_test_3['var_rss13'].median(),'SD4': data_lying_test_3['var_rss13'].std(),'1st Quartile4': data_lying_test_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_test_3['var_rss13'].quantile(0.75),'Min5': data_lying_test_3['avg_rss23'].min(),'Max5': data_lying_test_3['avg_rss23'].max(),'Mean5': data_lying_test_3['avg_rss23'].mean(),'Median5': data_lying_test_3['avg_rss23'].median(),'SD5': data_lying_test_3['avg_rss23'].std(),'1st Quartile5': data_lying_test_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_test_3['avg_rss23'].quantile(0.75),'Min6': data_lying_test_3['var_rss23'].min(),'Max6': data_lying_test_3['var_rss23'].max(),'Mean6': data_lying_test_3['var_rss23'].mean(),'Median6': data_lying_test_3['var_rss23'].median(),'SD6': data_lying_test_3['var_rss23'].std(),'1st Quartile6': data_lying_test_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_test_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'11','Min1':data_sitting_test_1['avg_rss12'].min(),'Max1': data_sitting_test_1['avg_rss12'].max(),'Mean1': data_sitting_test_1['avg_rss12'].mean(),'Median1': data_sitting_test_1['avg_rss12'].median(),'SD1': data_sitting_test_1['avg_rss12'].std(),'1st Quartile1': data_sitting_test_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_test_1['avg_rss12'].quantile(0.75),'Min2': data_sitting_test_1['var_rss12'].min(),'Max2': data_sitting_test_1['var_rss12'].max(),'Mean2': data_sitting_test_1['var_rss12'].mean(),'Median2': data_sitting_test_1['var_rss12'].median(),'SD2': data_sitting_test_1['var_rss12'].std(),'1st Quartile2': data_sitting_test_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_test_1['var_rss12'].quantile(0.75),'Min3': data_sitting_test_1['avg_rss13'].min(),'Max3': data_sitting_test_1['avg_rss13'].max(),'Mean3': data_sitting_test_1['avg_rss13'].mean(),'Median3': data_sitting_test_1['avg_rss13'].median(),'SD3': data_sitting_test_1['avg_rss13'].std(),'1st Quartile3': data_sitting_test_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_test_1['avg_rss13'].quantile(0.75),'Min4': data_sitting_test_1['var_rss13'].min(),'Max4': data_sitting_test_1['var_rss13'].max(),'Mean4': data_sitting_test_1['var_rss13'].mean(),'Median4': data_sitting_test_1['var_rss13'].median(),'SD4': data_sitting_test_1['var_rss13'].std(),'1st Quartile4': data_sitting_test_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_test_1['var_rss13'].quantile(0.75),'Min5': data_sitting_test_1['avg_rss23'].min(),'Max5': data_sitting_test_1['avg_rss23'].max(),'Mean5': data_sitting_test_1['avg_rss23'].mean(),'Median5': data_sitting_test_1['avg_rss23'].median(),'SD5': data_sitting_test_1['avg_rss23'].std(),'1st Quartile5': data_sitting_test_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_test_1['avg_rss23'].quantile(0.75),'Min6': data_sitting_test_1['var_rss23'].min(),'Max6': data_sitting_test_1['var_rss23'].max(),'Mean6': data_sitting_test_1['var_rss23'].mean(),'Median6': data_sitting_test_1['var_rss23'].median(),'SD6': data_sitting_test_1['var_rss23'].std(),'1st Quartile6': data_sitting_test_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_test_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'12','Min1':data_sitting_test_2['avg_rss12'].min(),'Max1': data_sitting_test_2['avg_rss12'].max(),'Mean1': data_sitting_test_2['avg_rss12'].mean(),'Median1': data_sitting_test_2['avg_rss12'].median(),'SD1': data_sitting_test_2['avg_rss12'].std(),'1st Quartile1': data_sitting_test_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_test_2['avg_rss12'].quantile(0.75),'Min2': data_sitting_test_2['var_rss12'].min(),'Max2': data_sitting_test_2['var_rss12'].max(),'Mean2': data_sitting_test_2['var_rss12'].mean(),'Median2': data_sitting_test_2['var_rss12'].median(),'SD2': data_sitting_test_2['var_rss12'].std(),'1st Quartile2': data_sitting_test_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_test_2['var_rss12'].quantile(0.75),'Min3': data_sitting_test_2['avg_rss13'].min(),'Max3': data_sitting_test_2['avg_rss13'].max(),'Mean3': data_sitting_test_2['avg_rss13'].mean(),'Median3': data_sitting_test_2['avg_rss13'].median(),'SD3': data_sitting_test_2['avg_rss13'].std(),'1st Quartile3': data_sitting_test_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_test_2['avg_rss13'].quantile(0.75),'Min4': data_sitting_test_2['var_rss13'].min(),'Max4': data_sitting_test_2['var_rss13'].max(),'Mean4': data_sitting_test_2['var_rss13'].mean(),'Median4': data_sitting_test_2['var_rss13'].median(),'SD4': data_sitting_test_2['var_rss13'].std(),'1st Quartile4': data_sitting_test_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_test_2['var_rss13'].quantile(0.75),'Min5': data_sitting_test_2['avg_rss23'].min(),'Max5': data_sitting_test_2['avg_rss23'].max(),'Mean5': data_sitting_test_2['avg_rss23'].mean(),'Median5': data_sitting_test_2['avg_rss23'].median(),'SD5': data_sitting_test_2['avg_rss23'].std(),'1st Quartile5': data_sitting_test_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_test_2['avg_rss23'].quantile(0.75),'Min6': data_sitting_test_2['var_rss23'].min(),'Max6': data_sitting_test_2['var_rss23'].max(),'Mean6': data_sitting_test_2['var_rss23'].mean(),'Median6': data_sitting_test_2['var_rss23'].median(),'SD6': data_sitting_test_2['var_rss23'].std(),'1st Quartile6': data_sitting_test_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_test_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'13','Min1':data_sitting_test_3['avg_rss12'].min(),'Max1': data_sitting_test_3['avg_rss12'].max(),'Mean1': data_sitting_test_3['avg_rss12'].mean(),'Median1': data_sitting_test_3['avg_rss12'].median(),'SD1': data_sitting_test_3['avg_rss12'].std(),'1st Quartile1': data_sitting_test_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_test_3['avg_rss12'].quantile(0.75),'Min2': data_sitting_test_3['var_rss12'].min(),'Max2': data_sitting_test_3['var_rss12'].max(),'Mean2': data_sitting_test_3['var_rss12'].mean(),'Median2': data_sitting_test_3['var_rss12'].median(),'SD2': data_sitting_test_3['var_rss12'].std(),'1st Quartile2': data_sitting_test_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_test_3['var_rss12'].quantile(0.75),'Min3': data_sitting_test_3['avg_rss13'].min(),'Max3': data_sitting_test_3['avg_rss13'].max(),'Mean3': data_sitting_test_3['avg_rss13'].mean(),'Median3': data_sitting_test_3['avg_rss13'].median(),'SD3': data_sitting_test_3['avg_rss13'].std(),'1st Quartile3': data_sitting_test_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_test_3['avg_rss13'].quantile(0.75),'Min4': data_sitting_test_3['var_rss13'].min(),'Max4': data_sitting_test_3['var_rss13'].max(),'Mean4': data_sitting_test_3['var_rss13'].mean(),'Median4': data_sitting_test_3['var_rss13'].median(),'SD4': data_sitting_test_3['var_rss13'].std(),'1st Quartile4': data_sitting_test_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_test_3['var_rss13'].quantile(0.75),'Min5': data_sitting_test_3['avg_rss23'].min(),'Max5': data_sitting_test_3['avg_rss23'].max(),'Mean5': data_sitting_test_3['avg_rss23'].mean(),'Median5': data_sitting_test_3['avg_rss23'].median(),'SD5': data_sitting_test_3['avg_rss23'].std(),'1st Quartile5': data_sitting_test_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_test_3['avg_rss23'].quantile(0.75),'Min6': data_sitting_test_3['var_rss23'].min(),'Max6': data_sitting_test_3['var_rss23'].max(),'Mean6': data_sitting_test_3['var_rss23'].mean(),'Median6': data_sitting_test_3['var_rss23'].median(),'SD6': data_sitting_test_3['var_rss23'].std(),'1st Quartile6': data_sitting_test_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_test_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'14','Min1':data_standing_test_1['avg_rss12'].min(),'Max1': data_standing_test_1['avg_rss12'].max(),'Mean1': data_standing_test_1['avg_rss12'].mean(),'Median1': data_standing_test_1['avg_rss12'].median(),'SD1': data_standing_test_1['avg_rss12'].std(),'1st Quartile1': data_standing_test_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_test_1['avg_rss12'].quantile(0.75),'Min2': data_standing_test_1['var_rss12'].min(),'Max2': data_standing_test_1['var_rss12'].max(),'Mean2': data_standing_test_1['var_rss12'].mean(),'Median2': data_standing_test_1['var_rss12'].median(),'SD2': data_standing_test_1['var_rss12'].std(),'1st Quartile2': data_standing_test_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_test_1['var_rss12'].quantile(0.75),'Min3': data_standing_test_1['avg_rss13'].min(),'Max3': data_standing_test_1['avg_rss13'].max(),'Mean3': data_standing_test_1['avg_rss13'].mean(),'Median3': data_standing_test_1['avg_rss13'].median(),'SD3': data_standing_test_1['avg_rss13'].std(),'1st Quartile3': data_standing_test_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_test_1['avg_rss13'].quantile(0.75),'Min4': data_standing_test_1['var_rss13'].min(),'Max4': data_standing_test_1['var_rss13'].max(),'Mean4': data_standing_test_1['var_rss13'].mean(),'Median4': data_standing_test_1['var_rss13'].median(),'SD4': data_standing_test_1['var_rss13'].std(),'1st Quartile4': data_standing_test_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_test_1['var_rss13'].quantile(0.75),'Min5': data_standing_test_1['avg_rss23'].min(),'Max5': data_standing_test_1['avg_rss23'].max(),'Mean5': data_standing_test_1['avg_rss23'].mean(),'Median5': data_standing_test_1['avg_rss23'].median(),'SD5': data_standing_test_1['avg_rss23'].std(),'1st Quartile5': data_standing_test_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_test_1['avg_rss23'].quantile(0.75),'Min6': data_standing_test_1['var_rss23'].min(),'Max6': data_standing_test_1['var_rss23'].max(),'Mean6': data_standing_test_1['var_rss23'].mean(),'Median6': data_standing_test_1['var_rss23'].median(),'SD6': data_standing_test_1['var_rss23'].std(),'1st Quartile6': data_standing_test_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_test_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'15','Min1':data_standing_test_2['avg_rss12'].min(),'Max1': data_standing_test_2['avg_rss12'].max(),'Mean1': data_standing_test_2['avg_rss12'].mean(),'Median1': data_standing_test_2['avg_rss12'].median(),'SD1': data_standing_test_2['avg_rss12'].std(),'1st Quartile1': data_standing_test_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_test_2['avg_rss12'].quantile(0.75),'Min2': data_standing_test_2['var_rss12'].min(),'Max2': data_standing_test_2['var_rss12'].max(),'Mean2': data_standing_test_2['var_rss12'].mean(),'Median2': data_standing_test_2['var_rss12'].median(),'SD2': data_standing_test_2['var_rss12'].std(),'1st Quartile2': data_standing_test_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_test_2['var_rss12'].quantile(0.75),'Min3': data_standing_test_2['avg_rss13'].min(),'Max3': data_standing_test_2['avg_rss13'].max(),'Mean3': data_standing_test_2['avg_rss13'].mean(),'Median3': data_standing_test_2['avg_rss13'].median(),'SD3': data_standing_test_2['avg_rss13'].std(),'1st Quartile3': data_standing_test_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_test_2['avg_rss13'].quantile(0.75),'Min4': data_standing_test_2['var_rss13'].min(),'Max4': data_standing_test_2['var_rss13'].max(),'Mean4': data_standing_test_2['var_rss13'].mean(),'Median4': data_standing_test_2['var_rss13'].median(),'SD4': data_standing_test_2['var_rss13'].std(),'1st Quartile4': data_standing_test_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_test_2['var_rss13'].quantile(0.75),'Min5': data_standing_test_2['avg_rss23'].min(),'Max5': data_standing_test_2['avg_rss23'].max(),'Mean5': data_standing_test_2['avg_rss23'].mean(),'Median5': data_standing_test_2['avg_rss23'].median(),'SD5': data_standing_test_2['avg_rss23'].std(),'1st Quartile5': data_standing_test_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_test_2['avg_rss23'].quantile(0.75),'Min6': data_standing_test_2['var_rss23'].min(),'Max6': data_standing_test_2['var_rss23'].max(),'Mean6': data_standing_test_2['var_rss23'].mean(),'Median6': data_standing_test_2['var_rss23'].median(),'SD6': data_standing_test_2['var_rss23'].std(),'1st Quartile6': data_standing_test_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_test_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'16','Min1':data_standing_test_3['avg_rss12'].min(),'Max1': data_standing_test_3['avg_rss12'].max(),'Mean1': data_standing_test_3['avg_rss12'].mean(),'Median1': data_standing_test_3['avg_rss12'].median(),'SD1': data_standing_test_3['avg_rss12'].std(),'1st Quartile1': data_standing_test_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_test_3['avg_rss12'].quantile(0.75),'Min2': data_standing_test_3['var_rss12'].min(),'Max2': data_standing_test_3['var_rss12'].max(),'Mean2': data_standing_test_3['var_rss12'].mean(),'Median2': data_standing_test_3['var_rss12'].median(),'SD2': data_standing_test_3['var_rss12'].std(),'1st Quartile2': data_standing_test_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_test_3['var_rss12'].quantile(0.75),'Min3': data_standing_test_3['avg_rss13'].min(),'Max3': data_standing_test_3['avg_rss13'].max(),'Mean3': data_standing_test_3['avg_rss13'].mean(),'Median3': data_standing_test_3['avg_rss13'].median(),'SD3': data_standing_test_3['avg_rss13'].std(),'1st Quartile3': data_standing_test_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_test_3['avg_rss13'].quantile(0.75),'Min4': data_standing_test_3['var_rss13'].min(),'Max4': data_standing_test_3['var_rss13'].max(),'Mean4': data_standing_test_3['var_rss13'].mean(),'Median4': data_standing_test_3['var_rss13'].median(),'SD4': data_standing_test_3['var_rss13'].std(),'1st Quartile4': data_standing_test_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_test_3['var_rss13'].quantile(0.75),'Min5': data_standing_test_3['avg_rss23'].min(),'Max5': data_standing_test_3['avg_rss23'].max(),'Mean5': data_standing_test_3['avg_rss23'].mean(),'Median5': data_standing_test_3['avg_rss23'].median(),'SD5': data_standing_test_3['avg_rss23'].std(),'1st Quartile5': data_standing_test_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_test_3['avg_rss23'].quantile(0.75),'Min6': data_standing_test_3['var_rss23'].min(),'Max6': data_standing_test_3['var_rss23'].max(),'Mean6': data_standing_test_3['var_rss23'].mean(),'Median6': data_standing_test_3['var_rss23'].median(),'SD6': data_standing_test_3['var_rss23'].std(),'1st Quartile6': data_standing_test_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_test_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'17','Min1':data_walking_test_1['avg_rss12'].min(),'Max1': data_walking_test_1['avg_rss12'].max(),'Mean1': data_walking_test_1['avg_rss12'].mean(),'Median1': data_walking_test_1['avg_rss12'].median(),'SD1': data_walking_test_1['avg_rss12'].std(),'1st Quartile1': data_walking_test_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_test_1['avg_rss12'].quantile(0.75),'Min2': data_walking_test_1['var_rss12'].min(),'Max2': data_walking_test_1['var_rss12'].max(),'Mean2': data_walking_test_1['var_rss12'].mean(),'Median2': data_walking_test_1['var_rss12'].median(),'SD2': data_walking_test_1['var_rss12'].std(),'1st Quartile2': data_walking_test_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_test_1['var_rss12'].quantile(0.75),'Min3': data_walking_test_1['avg_rss13'].min(),'Max3': data_walking_test_1['avg_rss13'].max(),'Mean3': data_walking_test_1['avg_rss13'].mean(),'Median3': data_walking_test_1['avg_rss13'].median(),'SD3': data_walking_test_1['avg_rss13'].std(),'1st Quartile3': data_walking_test_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_test_1['avg_rss13'].quantile(0.75),'Min4': data_walking_test_1['var_rss13'].min(),'Max4': data_walking_test_1['var_rss13'].max(),'Mean4': data_walking_test_1['var_rss13'].mean(),'Median4': data_walking_test_1['var_rss13'].median(),'SD4': data_walking_test_1['var_rss13'].std(),'1st Quartile4': data_walking_test_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_test_1['var_rss13'].quantile(0.75),'Min5': data_walking_test_1['avg_rss23'].min(),'Max5': data_walking_test_1['avg_rss23'].max(),'Mean5': data_walking_test_1['avg_rss23'].mean(),'Median5': data_walking_test_1['avg_rss23'].median(),'SD5': data_walking_test_1['avg_rss23'].std(),'1st Quartile5': data_walking_test_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_test_1['avg_rss23'].quantile(0.75),'Min6': data_walking_test_1['var_rss23'].min(),'Max6': data_walking_test_1['var_rss23'].max(),'Mean6': data_walking_test_1['var_rss23'].mean(),'Median6': data_walking_test_1['var_rss23'].median(),'SD6': data_walking_test_1['var_rss23'].std(),'1st Quartile6': data_walking_test_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_test_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'18','Min1':data_walking_test_2['avg_rss12'].min(),'Max1': data_walking_test_2['avg_rss12'].max(),'Mean1': data_walking_test_2['avg_rss12'].mean(),'Median1': data_walking_test_2['avg_rss12'].median(),'SD1': data_walking_test_2['avg_rss12'].std(),'1st Quartile1': data_walking_test_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_test_2['avg_rss12'].quantile(0.75),'Min2': data_walking_test_2['var_rss12'].min(),'Max2': data_walking_test_2['var_rss12'].max(),'Mean2': data_walking_test_2['var_rss12'].mean(),'Median2': data_walking_test_2['var_rss12'].median(),'SD2': data_walking_test_2['var_rss12'].std(),'1st Quartile2': data_walking_test_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_test_2['var_rss12'].quantile(0.75),'Min3': data_walking_test_2['avg_rss13'].min(),'Max3': data_walking_test_2['avg_rss13'].max(),'Mean3': data_walking_test_2['avg_rss13'].mean(),'Median3': data_walking_test_2['avg_rss13'].median(),'SD3': data_walking_test_2['avg_rss13'].std(),'1st Quartile3': data_walking_test_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_test_2['avg_rss13'].quantile(0.75),'Min4': data_walking_test_2['var_rss13'].min(),'Max4': data_walking_test_2['var_rss13'].max(),'Mean4': data_walking_test_2['var_rss13'].mean(),'Median4': data_walking_test_2['var_rss13'].median(),'SD4': data_walking_test_2['var_rss13'].std(),'1st Quartile4': data_walking_test_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_test_2['var_rss13'].quantile(0.75),'Min5': data_walking_test_2['avg_rss23'].min(),'Max5': data_walking_test_2['avg_rss23'].max(),'Mean5': data_walking_test_2['avg_rss23'].mean(),'Median5': data_walking_test_2['avg_rss23'].median(),'SD5': data_walking_test_2['avg_rss23'].std(),'1st Quartile5': data_walking_test_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_test_2['avg_rss23'].quantile(0.75),'Min6': data_walking_test_2['var_rss23'].min(),'Max6': data_walking_test_2['var_rss23'].max(),'Mean6': data_walking_test_2['var_rss23'].mean(),'Median6': data_walking_test_2['var_rss23'].median(),'SD6': data_walking_test_2['var_rss23'].std(),'1st Quartile6': data_walking_test_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_test_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'19','Min1':data_walking_test_3['avg_rss12'].min(),'Max1': data_walking_test_3['avg_rss12'].max(),'Mean1': data_walking_test_3['avg_rss12'].mean(),'Median1': data_walking_test_3['avg_rss12'].median(),'SD1': data_walking_test_3['avg_rss12'].std(),'1st Quartile1': data_walking_test_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_test_3['avg_rss12'].quantile(0.75),'Min2': data_walking_test_3['var_rss12'].min(),'Max2': data_walking_test_3['var_rss12'].max(),'Mean2': data_walking_test_3['var_rss12'].mean(),'Median2': data_walking_test_3['var_rss12'].median(),'SD2': data_walking_test_3['var_rss12'].std(),'1st Quartile2': data_walking_test_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_test_3['var_rss12'].quantile(0.75),'Min3': data_walking_test_3['avg_rss13'].min(),'Max3': data_walking_test_3['avg_rss13'].max(),'Mean3': data_walking_test_3['avg_rss13'].mean(),'Median3': data_walking_test_3['avg_rss13'].median(),'SD3': data_walking_test_3['avg_rss13'].std(),'1st Quartile3': data_walking_test_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_test_3['avg_rss13'].quantile(0.75),'Min4': data_walking_test_3['var_rss13'].min(),'Max4': data_walking_test_3['var_rss13'].max(),'Mean4': data_walking_test_3['var_rss13'].mean(),'Median4': data_walking_test_3['var_rss13'].median(),'SD4': data_walking_test_3['var_rss13'].std(),'1st Quartile4': data_walking_test_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_test_3['var_rss13'].quantile(0.75),'Min5': data_walking_test_3['avg_rss23'].min(),'Max5': data_walking_test_3['avg_rss23'].max(),'Mean5': data_walking_test_3['avg_rss23'].mean(),'Median5': data_walking_test_3['avg_rss23'].median(),'SD5': data_walking_test_3['avg_rss23'].std(),'1st Quartile5': data_walking_test_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_test_3['avg_rss23'].quantile(0.75),'Min6': data_walking_test_3['var_rss23'].min(),'Max6': data_walking_test_3['var_rss23'].max(),'Mean6': data_walking_test_3['var_rss23'].mean(),'Median6': data_walking_test_3['var_rss23'].median(),'SD6': data_walking_test_3['var_rss23'].std(),'1st Quartile6': data_walking_test_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_test_3['var_rss23'].quantile(0.75)}, ignore_index=True)

# %%
new_dataset=new_dataset.append({'Instance':'20','Min1':data_bending1_training_1['avg_rss12'].min(),'Max1': data_bending1_training_1['avg_rss12'].max(),'Mean1': data_bending1_training_1['avg_rss12'].mean(),'Median1': data_bending1_training_1['avg_rss12'].median(),'SD1': data_bending1_training_1['avg_rss12'].std(),'1st Quartile1': data_bending1_training_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending1_training_1['avg_rss12'].quantile(0.75),'Min2': data_bending1_training_1['var_rss12'].min(),'Max2': data_bending1_training_1['var_rss12'].max(),'Mean2': data_bending1_training_1['var_rss12'].mean(),'Median2': data_bending1_training_1['var_rss12'].median(),'SD2': data_bending1_training_1['var_rss12'].std(),'1st Quartile2': data_bending1_training_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending1_training_1['var_rss12'].quantile(0.75),'Min3': data_bending1_training_1['avg_rss13'].min(),'Max3': data_bending1_training_1['avg_rss13'].max(),'Mean3': data_bending1_training_1['avg_rss13'].mean(),'Median3': data_bending1_training_1['avg_rss13'].median(),'SD3': data_bending1_training_1['avg_rss13'].std(),'1st Quartile3': data_bending1_training_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending1_training_1['avg_rss13'].quantile(0.75),'Min4': data_bending1_training_1['var_rss13'].min(),'Max4': data_bending1_training_1['var_rss13'].max(),'Mean4': data_bending1_training_1['var_rss13'].mean(),'Median4': data_bending1_training_1['var_rss13'].median(),'SD4': data_bending1_training_1['var_rss13'].std(),'1st Quartile4': data_bending1_training_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending1_training_1['var_rss13'].quantile(0.75),'Min5': data_bending1_training_1['avg_rss23'].min(),'Max5': data_bending1_training_1['avg_rss23'].max(),'Mean5': data_bending1_training_1['avg_rss23'].mean(),'Median5': data_bending1_training_1['avg_rss23'].median(),'SD5': data_bending1_training_1['avg_rss23'].std(),'1st Quartile5': data_bending1_training_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending1_training_1['avg_rss23'].quantile(0.75),'Min6': data_bending1_training_1['var_rss23'].min(),'Max6': data_bending1_training_1['var_rss23'].max(),'Mean6': data_bending1_training_1['var_rss23'].mean(),'Median6': data_bending1_training_1['var_rss23'].median(),'SD6': data_bending1_training_1['var_rss23'].std(),'1st Quartile6': data_bending1_training_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending1_training_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'21','Min1':data_bending1_training_2['avg_rss12'].min(),'Max1': data_bending1_training_2['avg_rss12'].max(),'Mean1': data_bending1_training_2['avg_rss12'].mean(),'Median1': data_bending1_training_2['avg_rss12'].median(),'SD1': data_bending1_training_2['avg_rss12'].std(),'1st Quartile1': data_bending1_training_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending1_training_2['avg_rss12'].quantile(0.75),'Min2': data_bending1_training_2['var_rss12'].min(),'Max2': data_bending1_training_2['var_rss12'].max(),'Mean2': data_bending1_training_2['var_rss12'].mean(),'Median2': data_bending1_training_2['var_rss12'].median(),'SD2': data_bending1_training_2['var_rss12'].std(),'1st Quartile2': data_bending1_training_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending1_training_2['var_rss12'].quantile(0.75),'Min3': data_bending1_training_2['avg_rss13'].min(),'Max3': data_bending1_training_2['avg_rss13'].max(),'Mean3': data_bending1_training_2['avg_rss13'].mean(),'Median3': data_bending1_training_2['avg_rss13'].median(),'SD3': data_bending1_training_2['avg_rss13'].std(),'1st Quartile3': data_bending1_training_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending1_training_2['avg_rss13'].quantile(0.75),'Min4': data_bending1_training_2['var_rss13'].min(),'Max4': data_bending1_training_2['var_rss13'].max(),'Mean4': data_bending1_training_2['var_rss13'].mean(),'Median4': data_bending1_training_2['var_rss13'].median(),'SD4': data_bending1_training_2['var_rss13'].std(),'1st Quartile4': data_bending1_training_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending1_training_2['var_rss13'].quantile(0.75),'Min5': data_bending1_training_2['avg_rss23'].min(),'Max5': data_bending1_training_2['avg_rss23'].max(),'Mean5': data_bending1_training_2['avg_rss23'].mean(),'Median5': data_bending1_training_2['avg_rss23'].median(),'SD5': data_bending1_training_2['avg_rss23'].std(),'1st Quartile5': data_bending1_training_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending1_training_2['avg_rss23'].quantile(0.75),'Min6': data_bending1_training_2['var_rss23'].min(),'Max6': data_bending1_training_2['var_rss23'].max(),'Mean6': data_bending1_training_2['var_rss23'].mean(),'Median6': data_bending1_training_2['var_rss23'].median(),'SD6': data_bending1_training_2['var_rss23'].std(),'1st Quartile6': data_bending1_training_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending1_training_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'22','Min1':data_bending1_training_3['avg_rss12'].min(),'Max1': data_bending1_training_3['avg_rss12'].max(),'Mean1': data_bending1_training_3['avg_rss12'].mean(),'Median1': data_bending1_training_3['avg_rss12'].median(),'SD1': data_bending1_training_3['avg_rss12'].std(),'1st Quartile1': data_bending1_training_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending1_training_3['avg_rss12'].quantile(0.75),'Min2': data_bending1_training_3['var_rss12'].min(),'Max2': data_bending1_training_3['var_rss12'].max(),'Mean2': data_bending1_training_3['var_rss12'].mean(),'Median2': data_bending1_training_3['var_rss12'].median(),'SD2': data_bending1_training_3['var_rss12'].std(),'1st Quartile2': data_bending1_training_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending1_training_3['var_rss12'].quantile(0.75),'Min3': data_bending1_training_3['avg_rss13'].min(),'Max3': data_bending1_training_3['avg_rss13'].max(),'Mean3': data_bending1_training_3['avg_rss13'].mean(),'Median3': data_bending1_training_3['avg_rss13'].median(),'SD3': data_bending1_training_3['avg_rss13'].std(),'1st Quartile3': data_bending1_training_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending1_training_3['avg_rss13'].quantile(0.75),'Min4': data_bending1_training_3['var_rss13'].min(),'Max4': data_bending1_training_3['var_rss13'].max(),'Mean4': data_bending1_training_3['var_rss13'].mean(),'Median4': data_bending1_training_3['var_rss13'].median(),'SD4': data_bending1_training_3['var_rss13'].std(),'1st Quartile4': data_bending1_training_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending1_training_3['var_rss13'].quantile(0.75),'Min5': data_bending1_training_3['avg_rss23'].min(),'Max5': data_bending1_training_3['avg_rss23'].max(),'Mean5': data_bending1_training_3['avg_rss23'].mean(),'Median5': data_bending1_training_3['avg_rss23'].median(),'SD5': data_bending1_training_3['avg_rss23'].std(),'1st Quartile5': data_bending1_training_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending1_training_3['avg_rss23'].quantile(0.75),'Min6': data_bending1_training_3['var_rss23'].min(),'Max6': data_bending1_training_3['var_rss23'].max(),'Mean6': data_bending1_training_3['var_rss23'].mean(),'Median6': data_bending1_training_3['var_rss23'].median(),'SD6': data_bending1_training_3['var_rss23'].std(),'1st Quartile6': data_bending1_training_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending1_training_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'23','Min1':data_bending1_training_4['avg_rss12'].min(),'Max1': data_bending1_training_4['avg_rss12'].max(),'Mean1': data_bending1_training_4['avg_rss12'].mean(),'Median1': data_bending1_training_4['avg_rss12'].median(),'SD1': data_bending1_training_4['avg_rss12'].std(),'1st Quartile1': data_bending1_training_4['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending1_training_4['avg_rss12'].quantile(0.75),'Min2': data_bending1_training_4['var_rss12'].min(),'Max2': data_bending1_training_4['var_rss12'].max(),'Mean2': data_bending1_training_4['var_rss12'].mean(),'Median2': data_bending1_training_4['var_rss12'].median(),'SD2': data_bending1_training_4['var_rss12'].std(),'1st Quartile2': data_bending1_training_4['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending1_training_4['var_rss12'].quantile(0.75),'Min3': data_bending1_training_4['avg_rss13'].min(),'Max3': data_bending1_training_4['avg_rss13'].max(),'Mean3': data_bending1_training_4['avg_rss13'].mean(),'Median3': data_bending1_training_4['avg_rss13'].median(),'SD3': data_bending1_training_4['avg_rss13'].std(),'1st Quartile3': data_bending1_training_4['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending1_training_4['avg_rss13'].quantile(0.75),'Min4': data_bending1_training_4['var_rss13'].min(),'Max4': data_bending1_training_4['var_rss13'].max(),'Mean4': data_bending1_training_4['var_rss13'].mean(),'Median4': data_bending1_training_4['var_rss13'].median(),'SD4': data_bending1_training_4['var_rss13'].std(),'1st Quartile4': data_bending1_training_4['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending1_training_4['var_rss13'].quantile(0.75),'Min5': data_bending1_training_4['avg_rss23'].min(),'Max5': data_bending1_training_4['avg_rss23'].max(),'Mean5': data_bending1_training_4['avg_rss23'].mean(),'Median5': data_bending1_training_4['avg_rss23'].median(),'SD5': data_bending1_training_4['avg_rss23'].std(),'1st Quartile5': data_bending1_training_4['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending1_training_4['avg_rss23'].quantile(0.75),'Min6': data_bending1_training_4['var_rss23'].min(),'Max6': data_bending1_training_4['var_rss23'].max(),'Mean6': data_bending1_training_4['var_rss23'].mean(),'Median6': data_bending1_training_4['var_rss23'].median(),'SD6': data_bending1_training_4['var_rss23'].std(),'1st Quartile6': data_bending1_training_4['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending1_training_4['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'24','Min1':data_bending1_training_5['avg_rss12'].min(),'Max1': data_bending1_training_5['avg_rss12'].max(),'Mean1': data_bending1_training_5['avg_rss12'].mean(),'Median1': data_bending1_training_5['avg_rss12'].median(),'SD1': data_bending1_training_5['avg_rss12'].std(),'1st Quartile1': data_bending1_training_5['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending1_training_5['avg_rss12'].quantile(0.75),'Min2': data_bending1_training_5['var_rss12'].min(),'Max2': data_bending1_training_5['var_rss12'].max(),'Mean2': data_bending1_training_5['var_rss12'].mean(),'Median2': data_bending1_training_5['var_rss12'].median(),'SD2': data_bending1_training_5['var_rss12'].std(),'1st Quartile2': data_bending1_training_5['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending1_training_5['var_rss12'].quantile(0.75),'Min3': data_bending1_training_5['avg_rss13'].min(),'Max3': data_bending1_training_5['avg_rss13'].max(),'Mean3': data_bending1_training_5['avg_rss13'].mean(),'Median3': data_bending1_training_5['avg_rss13'].median(),'SD3': data_bending1_training_5['avg_rss13'].std(),'1st Quartile3': data_bending1_training_5['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending1_training_5['avg_rss13'].quantile(0.75),'Min4': data_bending1_training_5['var_rss13'].min(),'Max4': data_bending1_training_5['var_rss13'].max(),'Mean4': data_bending1_training_5['var_rss13'].mean(),'Median4': data_bending1_training_5['var_rss13'].median(),'SD4': data_bending1_training_5['var_rss13'].std(),'1st Quartile4': data_bending1_training_5['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending1_training_5['var_rss13'].quantile(0.75),'Min5': data_bending1_training_5['avg_rss23'].min(),'Max5': data_bending1_training_5['avg_rss23'].max(),'Mean5': data_bending1_training_5['avg_rss23'].mean(),'Median5': data_bending1_training_5['avg_rss23'].median(),'SD5': data_bending1_training_5['avg_rss23'].std(),'1st Quartile5': data_bending1_training_5['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending1_training_5['avg_rss23'].quantile(0.75),'Min6': data_bending1_training_5['var_rss23'].min(),'Max6': data_bending1_training_5['var_rss23'].max(),'Mean6': data_bending1_training_5['var_rss23'].mean(),'Median6': data_bending1_training_5['var_rss23'].median(),'SD6': data_bending1_training_5['var_rss23'].std(),'1st Quartile6': data_bending1_training_5['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending1_training_5['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'25','Min1':data_bending2_training_1['avg_rss12'].min(),'Max1': data_bending2_training_1['avg_rss12'].max(),'Mean1': data_bending2_training_1['avg_rss12'].mean(),'Median1': data_bending2_training_1['avg_rss12'].median(),'SD1': data_bending2_training_1['avg_rss12'].std(),'1st Quartile1': data_bending2_training_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending2_training_1['avg_rss12'].quantile(0.75),'Min2': data_bending2_training_1['var_rss12'].min(),'Max2': data_bending2_training_1['var_rss12'].max(),'Mean2': data_bending2_training_1['var_rss12'].mean(),'Median2': data_bending2_training_1['var_rss12'].median(),'SD2': data_bending2_training_1['var_rss12'].std(),'1st Quartile2': data_bending2_training_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending2_training_1['var_rss12'].quantile(0.75),'Min3': data_bending2_training_1['avg_rss13'].min(),'Max3': data_bending2_training_1['avg_rss13'].max(),'Mean3': data_bending2_training_1['avg_rss13'].mean(),'Median3': data_bending2_training_1['avg_rss13'].median(),'SD3': data_bending2_training_1['avg_rss13'].std(),'1st Quartile3': data_bending2_training_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending2_training_1['avg_rss13'].quantile(0.75),'Min4': data_bending2_training_1['var_rss13'].min(),'Max4': data_bending2_training_1['var_rss13'].max(),'Mean4': data_bending2_training_1['var_rss13'].mean(),'Median4': data_bending2_training_1['var_rss13'].median(),'SD4': data_bending2_training_1['var_rss13'].std(),'1st Quartile4': data_bending2_training_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending2_training_1['var_rss13'].quantile(0.75),'Min5': data_bending2_training_1['avg_rss23'].min(),'Max5': data_bending2_training_1['avg_rss23'].max(),'Mean5': data_bending2_training_1['avg_rss23'].mean(),'Median5': data_bending2_training_1['avg_rss23'].median(),'SD5': data_bending2_training_1['avg_rss23'].std(),'1st Quartile5': data_bending2_training_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending2_training_1['avg_rss23'].quantile(0.75),'Min6': data_bending2_training_1['var_rss23'].min(),'Max6': data_bending2_training_1['var_rss23'].max(),'Mean6': data_bending2_training_1['var_rss23'].mean(),'Median6': data_bending2_training_1['var_rss23'].median(),'SD6': data_bending2_training_1['var_rss23'].std(),'1st Quartile6': data_bending2_training_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending2_training_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'26','Min1':data_bending2_training_2['avg_rss12'].min(),'Max1': data_bending2_training_2['avg_rss12'].max(),'Mean1': data_bending2_training_2['avg_rss12'].mean(),'Median1': data_bending2_training_2['avg_rss12'].median(),'SD1': data_bending2_training_2['avg_rss12'].std(),'1st Quartile1': data_bending2_training_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending2_training_2['avg_rss12'].quantile(0.75),'Min2': data_bending2_training_2['var_rss12'].min(),'Max2': data_bending2_training_2['var_rss12'].max(),'Mean2': data_bending2_training_2['var_rss12'].mean(),'Median2': data_bending2_training_2['var_rss12'].median(),'SD2': data_bending2_training_2['var_rss12'].std(),'1st Quartile2': data_bending2_training_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending2_training_2['var_rss12'].quantile(0.75),'Min3': data_bending2_training_2['avg_rss13'].min(),'Max3': data_bending2_training_2['avg_rss13'].max(),'Mean3': data_bending2_training_2['avg_rss13'].mean(),'Median3': data_bending2_training_2['avg_rss13'].median(),'SD3': data_bending2_training_2['avg_rss13'].std(),'1st Quartile3': data_bending2_training_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending2_training_2['avg_rss13'].quantile(0.75),'Min4': data_bending2_training_2['var_rss13'].min(),'Max4': data_bending2_training_2['var_rss13'].max(),'Mean4': data_bending2_training_2['var_rss13'].mean(),'Median4': data_bending2_training_2['var_rss13'].median(),'SD4': data_bending2_training_2['var_rss13'].std(),'1st Quartile4': data_bending2_training_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending2_training_2['var_rss13'].quantile(0.75),'Min5': data_bending2_training_2['avg_rss23'].min(),'Max5': data_bending2_training_2['avg_rss23'].max(),'Mean5': data_bending2_training_2['avg_rss23'].mean(),'Median5': data_bending2_training_2['avg_rss23'].median(),'SD5': data_bending2_training_2['avg_rss23'].std(),'1st Quartile5': data_bending2_training_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending2_training_2['avg_rss23'].quantile(0.75),'Min6': data_bending2_training_2['var_rss23'].min(),'Max6': data_bending2_training_2['var_rss23'].max(),'Mean6': data_bending2_training_2['var_rss23'].mean(),'Median6': data_bending2_training_2['var_rss23'].median(),'SD6': data_bending2_training_2['var_rss23'].std(),'1st Quartile6': data_bending2_training_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending2_training_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'27','Min1':data_bending2_training_3['avg_rss12'].min(),'Max1': data_bending2_training_3['avg_rss12'].max(),'Mean1': data_bending2_training_3['avg_rss12'].mean(),'Median1': data_bending2_training_3['avg_rss12'].median(),'SD1': data_bending2_training_3['avg_rss12'].std(),'1st Quartile1': data_bending2_training_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending2_training_3['avg_rss12'].quantile(0.75),'Min2': data_bending2_training_3['var_rss12'].min(),'Max2': data_bending2_training_3['var_rss12'].max(),'Mean2': data_bending2_training_3['var_rss12'].mean(),'Median2': data_bending2_training_3['var_rss12'].median(),'SD2': data_bending2_training_3['var_rss12'].std(),'1st Quartile2': data_bending2_training_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending2_training_3['var_rss12'].quantile(0.75),'Min3': data_bending2_training_3['avg_rss13'].min(),'Max3': data_bending2_training_3['avg_rss13'].max(),'Mean3': data_bending2_training_3['avg_rss13'].mean(),'Median3': data_bending2_training_3['avg_rss13'].median(),'SD3': data_bending2_training_3['avg_rss13'].std(),'1st Quartile3': data_bending2_training_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending2_training_3['avg_rss13'].quantile(0.75),'Min4': data_bending2_training_3['var_rss13'].min(),'Max4': data_bending2_training_3['var_rss13'].max(),'Mean4': data_bending2_training_3['var_rss13'].mean(),'Median4': data_bending2_training_3['var_rss13'].median(),'SD4': data_bending2_training_3['var_rss13'].std(),'1st Quartile4': data_bending2_training_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending2_training_3['var_rss13'].quantile(0.75),'Min5': data_bending2_training_3['avg_rss23'].min(),'Max5': data_bending2_training_3['avg_rss23'].max(),'Mean5': data_bending2_training_3['avg_rss23'].mean(),'Median5': data_bending2_training_3['avg_rss23'].median(),'SD5': data_bending2_training_3['avg_rss23'].std(),'1st Quartile5': data_bending2_training_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending2_training_3['avg_rss23'].quantile(0.75),'Min6': data_bending2_training_3['var_rss23'].min(),'Max6': data_bending2_training_3['var_rss23'].max(),'Mean6': data_bending2_training_3['var_rss23'].mean(),'Median6': data_bending2_training_3['var_rss23'].median(),'SD6': data_bending2_training_3['var_rss23'].std(),'1st Quartile6': data_bending2_training_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending2_training_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'28','Min1':data_bending2_training_4['avg_rss12'].min(),'Max1': data_bending2_training_4['avg_rss12'].max(),'Mean1': data_bending2_training_4['avg_rss12'].mean(),'Median1': data_bending2_training_4['avg_rss12'].median(),'SD1': data_bending2_training_4['avg_rss12'].std(),'1st Quartile1': data_bending2_training_4['avg_rss12'].quantile(0.25),'3rd Quartile1': data_bending2_training_4['avg_rss12'].quantile(0.75),'Min2': data_bending2_training_4['var_rss12'].min(),'Max2': data_bending2_training_4['var_rss12'].max(),'Mean2': data_bending2_training_4['var_rss12'].mean(),'Median2': data_bending2_training_4['var_rss12'].median(),'SD2': data_bending2_training_4['var_rss12'].std(),'1st Quartile2': data_bending2_training_4['var_rss12'].quantile(0.25),'3rd Quartile2': data_bending2_training_4['var_rss12'].quantile(0.75),'Min3': data_bending2_training_4['avg_rss13'].min(),'Max3': data_bending2_training_4['avg_rss13'].max(),'Mean3': data_bending2_training_4['avg_rss13'].mean(),'Median3': data_bending2_training_4['avg_rss13'].median(),'SD3': data_bending2_training_4['avg_rss13'].std(),'1st Quartile3': data_bending2_training_4['avg_rss13'].quantile(0.25),'3rd Quartile3': data_bending2_training_4['avg_rss13'].quantile(0.75),'Min4': data_bending2_training_4['var_rss13'].min(),'Max4': data_bending2_training_4['var_rss13'].max(),'Mean4': data_bending2_training_4['var_rss13'].mean(),'Median4': data_bending2_training_4['var_rss13'].median(),'SD4': data_bending2_training_4['var_rss13'].std(),'1st Quartile4': data_bending2_training_4['var_rss13'].quantile(0.25),'3rd Quartile4': data_bending2_training_4['var_rss13'].quantile(0.75),'Min5': data_bending2_training_4['avg_rss23'].min(),'Max5': data_bending2_training_4['avg_rss23'].max(),'Mean5': data_bending2_training_4['avg_rss23'].mean(),'Median5': data_bending2_training_4['avg_rss23'].median(),'SD5': data_bending2_training_4['avg_rss23'].std(),'1st Quartile5': data_bending2_training_4['avg_rss23'].quantile(0.25),'3rd Quartile5': data_bending2_training_4['avg_rss23'].quantile(0.75),'Min6': data_bending2_training_4['var_rss23'].min(),'Max6': data_bending2_training_4['var_rss23'].max(),'Mean6': data_bending2_training_4['var_rss23'].mean(),'Median6': data_bending2_training_4['var_rss23'].median(),'SD6': data_bending2_training_4['var_rss23'].std(),'1st Quartile6': data_bending2_training_4['var_rss23'].quantile(0.25),'3rd Quartile6': data_bending2_training_4['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'29','Min1':data_cycling_training_1['avg_rss12'].min(),'Max1': data_cycling_training_1['avg_rss12'].max(),'Mean1': data_cycling_training_1['avg_rss12'].mean(),'Median1': data_cycling_training_1['avg_rss12'].median(),'SD1': data_cycling_training_1['avg_rss12'].std(),'1st Quartile1': data_cycling_training_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_1['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_1['var_rss12'].min(),'Max2': data_cycling_training_1['var_rss12'].max(),'Mean2': data_cycling_training_1['var_rss12'].mean(),'Median2': data_cycling_training_1['var_rss12'].median(),'SD2': data_cycling_training_1['var_rss12'].std(),'1st Quartile2': data_cycling_training_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_1['var_rss12'].quantile(0.75),'Min3': data_cycling_training_1['avg_rss13'].min(),'Max3': data_cycling_training_1['avg_rss13'].max(),'Mean3': data_cycling_training_1['avg_rss13'].mean(),'Median3': data_cycling_training_1['avg_rss13'].median(),'SD3': data_cycling_training_1['avg_rss13'].std(),'1st Quartile3': data_cycling_training_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_1['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_1['var_rss13'].min(),'Max4': data_cycling_training_1['var_rss13'].max(),'Mean4': data_cycling_training_1['var_rss13'].mean(),'Median4': data_cycling_training_1['var_rss13'].median(),'SD4': data_cycling_training_1['var_rss13'].std(),'1st Quartile4': data_cycling_training_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_1['var_rss13'].quantile(0.75),'Min5': data_cycling_training_1['avg_rss23'].min(),'Max5': data_cycling_training_1['avg_rss23'].max(),'Mean5': data_cycling_training_1['avg_rss23'].mean(),'Median5': data_cycling_training_1['avg_rss23'].median(),'SD5': data_cycling_training_1['avg_rss23'].std(),'1st Quartile5': data_cycling_training_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_1['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_1['var_rss23'].min(),'Max6': data_cycling_training_1['var_rss23'].max(),'Mean6': data_cycling_training_1['var_rss23'].mean(),'Median6': data_cycling_training_1['var_rss23'].median(),'SD6': data_cycling_training_1['var_rss23'].std(),'1st Quartile6': data_cycling_training_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'30','Min1':data_cycling_training_2['avg_rss12'].min(),'Max1': data_cycling_training_2['avg_rss12'].max(),'Mean1': data_cycling_training_2['avg_rss12'].mean(),'Median1': data_cycling_training_2['avg_rss12'].median(),'SD1': data_cycling_training_2['avg_rss12'].std(),'1st Quartile1': data_cycling_training_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_2['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_2['var_rss12'].min(),'Max2': data_cycling_training_2['var_rss12'].max(),'Mean2': data_cycling_training_2['var_rss12'].mean(),'Median2': data_cycling_training_2['var_rss12'].median(),'SD2': data_cycling_training_2['var_rss12'].std(),'1st Quartile2': data_cycling_training_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_2['var_rss12'].quantile(0.75),'Min3': data_cycling_training_2['avg_rss13'].min(),'Max3': data_cycling_training_2['avg_rss13'].max(),'Mean3': data_cycling_training_2['avg_rss13'].mean(),'Median3': data_cycling_training_2['avg_rss13'].median(),'SD3': data_cycling_training_2['avg_rss13'].std(),'1st Quartile3': data_cycling_training_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_2['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_2['var_rss13'].min(),'Max4': data_cycling_training_2['var_rss13'].max(),'Mean4': data_cycling_training_2['var_rss13'].mean(),'Median4': data_cycling_training_2['var_rss13'].median(),'SD4': data_cycling_training_2['var_rss13'].std(),'1st Quartile4': data_cycling_training_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_2['var_rss13'].quantile(0.75),'Min5': data_cycling_training_2['avg_rss23'].min(),'Max5': data_cycling_training_2['avg_rss23'].max(),'Mean5': data_cycling_training_2['avg_rss23'].mean(),'Median5': data_cycling_training_2['avg_rss23'].median(),'SD5': data_cycling_training_2['avg_rss23'].std(),'1st Quartile5': data_cycling_training_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_2['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_2['var_rss23'].min(),'Max6': data_cycling_training_2['var_rss23'].max(),'Mean6': data_cycling_training_2['var_rss23'].mean(),'Median6': data_cycling_training_2['var_rss23'].median(),'SD6': data_cycling_training_2['var_rss23'].std(),'1st Quartile6': data_cycling_training_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'31','Min1':data_cycling_training_3['avg_rss12'].min(),'Max1': data_cycling_training_3['avg_rss12'].max(),'Mean1': data_cycling_training_3['avg_rss12'].mean(),'Median1': data_cycling_training_3['avg_rss12'].median(),'SD1': data_cycling_training_3['avg_rss12'].std(),'1st Quartile1': data_cycling_training_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_3['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_3['var_rss12'].min(),'Max2': data_cycling_training_3['var_rss12'].max(),'Mean2': data_cycling_training_3['var_rss12'].mean(),'Median2': data_cycling_training_3['var_rss12'].median(),'SD2': data_cycling_training_3['var_rss12'].std(),'1st Quartile2': data_cycling_training_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_3['var_rss12'].quantile(0.75),'Min3': data_cycling_training_3['avg_rss13'].min(),'Max3': data_cycling_training_3['avg_rss13'].max(),'Mean3': data_cycling_training_3['avg_rss13'].mean(),'Median3': data_cycling_training_3['avg_rss13'].median(),'SD3': data_cycling_training_3['avg_rss13'].std(),'1st Quartile3': data_cycling_training_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_3['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_3['var_rss13'].min(),'Max4': data_cycling_training_3['var_rss13'].max(),'Mean4': data_cycling_training_3['var_rss13'].mean(),'Median4': data_cycling_training_3['var_rss13'].median(),'SD4': data_cycling_training_3['var_rss13'].std(),'1st Quartile4': data_cycling_training_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_3['var_rss13'].quantile(0.75),'Min5': data_cycling_training_3['avg_rss23'].min(),'Max5': data_cycling_training_3['avg_rss23'].max(),'Mean5': data_cycling_training_3['avg_rss23'].mean(),'Median5': data_cycling_training_3['avg_rss23'].median(),'SD5': data_cycling_training_3['avg_rss23'].std(),'1st Quartile5': data_cycling_training_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_3['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_3['var_rss23'].min(),'Max6': data_cycling_training_3['var_rss23'].max(),'Mean6': data_cycling_training_3['var_rss23'].mean(),'Median6': data_cycling_training_3['var_rss23'].median(),'SD6': data_cycling_training_3['var_rss23'].std(),'1st Quartile6': data_cycling_training_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'32','Min1':data_cycling_training_4['avg_rss12'].min(),'Max1': data_cycling_training_4['avg_rss12'].max(),'Mean1': data_cycling_training_4['avg_rss12'].mean(),'Median1': data_cycling_training_4['avg_rss12'].median(),'SD1': data_cycling_training_4['avg_rss12'].std(),'1st Quartile1': data_cycling_training_4['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_4['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_4['var_rss12'].min(),'Max2': data_cycling_training_4['var_rss12'].max(),'Mean2': data_cycling_training_4['var_rss12'].mean(),'Median2': data_cycling_training_4['var_rss12'].median(),'SD2': data_cycling_training_4['var_rss12'].std(),'1st Quartile2': data_cycling_training_4['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_4['var_rss12'].quantile(0.75),'Min3': data_cycling_training_4['avg_rss13'].min(),'Max3': data_cycling_training_4['avg_rss13'].max(),'Mean3': data_cycling_training_4['avg_rss13'].mean(),'Median3': data_cycling_training_4['avg_rss13'].median(),'SD3': data_cycling_training_4['avg_rss13'].std(),'1st Quartile3': data_cycling_training_4['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_4['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_4['var_rss13'].min(),'Max4': data_cycling_training_4['var_rss13'].max(),'Mean4': data_cycling_training_4['var_rss13'].mean(),'Median4': data_cycling_training_4['var_rss13'].median(),'SD4': data_cycling_training_4['var_rss13'].std(),'1st Quartile4': data_cycling_training_4['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_4['var_rss13'].quantile(0.75),'Min5': data_cycling_training_4['avg_rss23'].min(),'Max5': data_cycling_training_4['avg_rss23'].max(),'Mean5': data_cycling_training_4['avg_rss23'].mean(),'Median5': data_cycling_training_4['avg_rss23'].median(),'SD5': data_cycling_training_4['avg_rss23'].std(),'1st Quartile5': data_cycling_training_4['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_4['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_4['var_rss23'].min(),'Max6': data_cycling_training_4['var_rss23'].max(),'Mean6': data_cycling_training_4['var_rss23'].mean(),'Median6': data_cycling_training_4['var_rss23'].median(),'SD6': data_cycling_training_4['var_rss23'].std(),'1st Quartile6': data_cycling_training_4['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_4['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'33','Min1':data_cycling_training_5['avg_rss12'].min(),'Max1': data_cycling_training_5['avg_rss12'].max(),'Mean1': data_cycling_training_5['avg_rss12'].mean(),'Median1': data_cycling_training_5['avg_rss12'].median(),'SD1': data_cycling_training_5['avg_rss12'].std(),'1st Quartile1': data_cycling_training_5['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_5['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_5['var_rss12'].min(),'Max2': data_cycling_training_5['var_rss12'].max(),'Mean2': data_cycling_training_5['var_rss12'].mean(),'Median2': data_cycling_training_5['var_rss12'].median(),'SD2': data_cycling_training_5['var_rss12'].std(),'1st Quartile2': data_cycling_training_5['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_5['var_rss12'].quantile(0.75),'Min3': data_cycling_training_5['avg_rss13'].min(),'Max3': data_cycling_training_5['avg_rss13'].max(),'Mean3': data_cycling_training_5['avg_rss13'].mean(),'Median3': data_cycling_training_5['avg_rss13'].median(),'SD3': data_cycling_training_5['avg_rss13'].std(),'1st Quartile3': data_cycling_training_5['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_5['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_5['var_rss13'].min(),'Max4': data_cycling_training_5['var_rss13'].max(),'Mean4': data_cycling_training_5['var_rss13'].mean(),'Median4': data_cycling_training_5['var_rss13'].median(),'SD4': data_cycling_training_5['var_rss13'].std(),'1st Quartile4': data_cycling_training_5['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_5['var_rss13'].quantile(0.75),'Min5': data_cycling_training_5['avg_rss23'].min(),'Max5': data_cycling_training_5['avg_rss23'].max(),'Mean5': data_cycling_training_5['avg_rss23'].mean(),'Median5': data_cycling_training_5['avg_rss23'].median(),'SD5': data_cycling_training_5['avg_rss23'].std(),'1st Quartile5': data_cycling_training_5['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_5['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_5['var_rss23'].min(),'Max6': data_cycling_training_5['var_rss23'].max(),'Mean6': data_cycling_training_5['var_rss23'].mean(),'Median6': data_cycling_training_5['var_rss23'].median(),'SD6': data_cycling_training_5['var_rss23'].std(),'1st Quartile6': data_cycling_training_5['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_5['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'34','Min1':data_cycling_training_6['avg_rss12'].min(),'Max1': data_cycling_training_6['avg_rss12'].max(),'Mean1': data_cycling_training_6['avg_rss12'].mean(),'Median1': data_cycling_training_6['avg_rss12'].median(),'SD1': data_cycling_training_6['avg_rss12'].std(),'1st Quartile1': data_cycling_training_6['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_6['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_6['var_rss12'].min(),'Max2': data_cycling_training_6['var_rss12'].max(),'Mean2': data_cycling_training_6['var_rss12'].mean(),'Median2': data_cycling_training_6['var_rss12'].median(),'SD2': data_cycling_training_6['var_rss12'].std(),'1st Quartile2': data_cycling_training_6['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_6['var_rss12'].quantile(0.75),'Min3': data_cycling_training_6['avg_rss13'].min(),'Max3': data_cycling_training_6['avg_rss13'].max(),'Mean3': data_cycling_training_6['avg_rss13'].mean(),'Median3': data_cycling_training_6['avg_rss13'].median(),'SD3': data_cycling_training_6['avg_rss13'].std(),'1st Quartile3': data_cycling_training_6['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_6['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_6['var_rss13'].min(),'Max4': data_cycling_training_6['var_rss13'].max(),'Mean4': data_cycling_training_6['var_rss13'].mean(),'Median4': data_cycling_training_6['var_rss13'].median(),'SD4': data_cycling_training_6['var_rss13'].std(),'1st Quartile4': data_cycling_training_6['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_6['var_rss13'].quantile(0.75),'Min5': data_cycling_training_6['avg_rss23'].min(),'Max5': data_cycling_training_6['avg_rss23'].max(),'Mean5': data_cycling_training_6['avg_rss23'].mean(),'Median5': data_cycling_training_6['avg_rss23'].median(),'SD5': data_cycling_training_6['avg_rss23'].std(),'1st Quartile5': data_cycling_training_6['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_6['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_6['var_rss23'].min(),'Max6': data_cycling_training_6['var_rss23'].max(),'Mean6': data_cycling_training_6['var_rss23'].mean(),'Median6': data_cycling_training_6['var_rss23'].median(),'SD6': data_cycling_training_6['var_rss23'].std(),'1st Quartile6': data_cycling_training_6['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_6['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'35','Min1':data_cycling_training_7['avg_rss12'].min(),'Max1': data_cycling_training_7['avg_rss12'].max(),'Mean1': data_cycling_training_7['avg_rss12'].mean(),'Median1': data_cycling_training_7['avg_rss12'].median(),'SD1': data_cycling_training_7['avg_rss12'].std(),'1st Quartile1': data_cycling_training_7['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_7['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_7['var_rss12'].min(),'Max2': data_cycling_training_7['var_rss12'].max(),'Mean2': data_cycling_training_7['var_rss12'].mean(),'Median2': data_cycling_training_7['var_rss12'].median(),'SD2': data_cycling_training_7['var_rss12'].std(),'1st Quartile2': data_cycling_training_7['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_7['var_rss12'].quantile(0.75),'Min3': data_cycling_training_7['avg_rss13'].min(),'Max3': data_cycling_training_7['avg_rss13'].max(),'Mean3': data_cycling_training_7['avg_rss13'].mean(),'Median3': data_cycling_training_7['avg_rss13'].median(),'SD3': data_cycling_training_7['avg_rss13'].std(),'1st Quartile3': data_cycling_training_7['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_7['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_7['var_rss13'].min(),'Max4': data_cycling_training_7['var_rss13'].max(),'Mean4': data_cycling_training_7['var_rss13'].mean(),'Median4': data_cycling_training_7['var_rss13'].median(),'SD4': data_cycling_training_7['var_rss13'].std(),'1st Quartile4': data_cycling_training_7['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_7['var_rss13'].quantile(0.75),'Min5': data_cycling_training_7['avg_rss23'].min(),'Max5': data_cycling_training_7['avg_rss23'].max(),'Mean5': data_cycling_training_7['avg_rss23'].mean(),'Median5': data_cycling_training_7['avg_rss23'].median(),'SD5': data_cycling_training_7['avg_rss23'].std(),'1st Quartile5': data_cycling_training_7['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_7['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_7['var_rss23'].min(),'Max6': data_cycling_training_7['var_rss23'].max(),'Mean6': data_cycling_training_7['var_rss23'].mean(),'Median6': data_cycling_training_7['var_rss23'].median(),'SD6': data_cycling_training_7['var_rss23'].std(),'1st Quartile6': data_cycling_training_7['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_7['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'36','Min1':data_cycling_training_8['avg_rss12'].min(),'Max1': data_cycling_training_8['avg_rss12'].max(),'Mean1': data_cycling_training_8['avg_rss12'].mean(),'Median1': data_cycling_training_8['avg_rss12'].median(),'SD1': data_cycling_training_8['avg_rss12'].std(),'1st Quartile1': data_cycling_training_8['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_8['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_8['var_rss12'].min(),'Max2': data_cycling_training_8['var_rss12'].max(),'Mean2': data_cycling_training_8['var_rss12'].mean(),'Median2': data_cycling_training_8['var_rss12'].median(),'SD2': data_cycling_training_8['var_rss12'].std(),'1st Quartile2': data_cycling_training_8['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_8['var_rss12'].quantile(0.75),'Min3': data_cycling_training_8['avg_rss13'].min(),'Max3': data_cycling_training_8['avg_rss13'].max(),'Mean3': data_cycling_training_8['avg_rss13'].mean(),'Median3': data_cycling_training_8['avg_rss13'].median(),'SD3': data_cycling_training_8['avg_rss13'].std(),'1st Quartile3': data_cycling_training_8['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_8['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_8['var_rss13'].min(),'Max4': data_cycling_training_8['var_rss13'].max(),'Mean4': data_cycling_training_8['var_rss13'].mean(),'Median4': data_cycling_training_8['var_rss13'].median(),'SD4': data_cycling_training_8['var_rss13'].std(),'1st Quartile4': data_cycling_training_8['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_8['var_rss13'].quantile(0.75),'Min5': data_cycling_training_8['avg_rss23'].min(),'Max5': data_cycling_training_8['avg_rss23'].max(),'Mean5': data_cycling_training_8['avg_rss23'].mean(),'Median5': data_cycling_training_8['avg_rss23'].median(),'SD5': data_cycling_training_8['avg_rss23'].std(),'1st Quartile5': data_cycling_training_8['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_8['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_8['var_rss23'].min(),'Max6': data_cycling_training_8['var_rss23'].max(),'Mean6': data_cycling_training_8['var_rss23'].mean(),'Median6': data_cycling_training_8['var_rss23'].median(),'SD6': data_cycling_training_8['var_rss23'].std(),'1st Quartile6': data_cycling_training_8['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_8['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'37','Min1':data_cycling_training_9['avg_rss12'].min(),'Max1': data_cycling_training_9['avg_rss12'].max(),'Mean1': data_cycling_training_9['avg_rss12'].mean(),'Median1': data_cycling_training_9['avg_rss12'].median(),'SD1': data_cycling_training_9['avg_rss12'].std(),'1st Quartile1': data_cycling_training_9['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_9['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_9['var_rss12'].min(),'Max2': data_cycling_training_9['var_rss12'].max(),'Mean2': data_cycling_training_9['var_rss12'].mean(),'Median2': data_cycling_training_9['var_rss12'].median(),'SD2': data_cycling_training_9['var_rss12'].std(),'1st Quartile2': data_cycling_training_9['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_9['var_rss12'].quantile(0.75),'Min3': data_cycling_training_9['avg_rss13'].min(),'Max3': data_cycling_training_9['avg_rss13'].max(),'Mean3': data_cycling_training_9['avg_rss13'].mean(),'Median3': data_cycling_training_9['avg_rss13'].median(),'SD3': data_cycling_training_9['avg_rss13'].std(),'1st Quartile3': data_cycling_training_9['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_9['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_9['var_rss13'].min(),'Max4': data_cycling_training_9['var_rss13'].max(),'Mean4': data_cycling_training_9['var_rss13'].mean(),'Median4': data_cycling_training_9['var_rss13'].median(),'SD4': data_cycling_training_9['var_rss13'].std(),'1st Quartile4': data_cycling_training_9['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_9['var_rss13'].quantile(0.75),'Min5': data_cycling_training_9['avg_rss23'].min(),'Max5': data_cycling_training_9['avg_rss23'].max(),'Mean5': data_cycling_training_9['avg_rss23'].mean(),'Median5': data_cycling_training_9['avg_rss23'].median(),'SD5': data_cycling_training_9['avg_rss23'].std(),'1st Quartile5': data_cycling_training_9['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_9['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_9['var_rss23'].min(),'Max6': data_cycling_training_9['var_rss23'].max(),'Mean6': data_cycling_training_9['var_rss23'].mean(),'Median6': data_cycling_training_9['var_rss23'].median(),'SD6': data_cycling_training_9['var_rss23'].std(),'1st Quartile6': data_cycling_training_9['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_9['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'38','Min1':data_cycling_training_10['avg_rss12'].min(),'Max1': data_cycling_training_10['avg_rss12'].max(),'Mean1': data_cycling_training_10['avg_rss12'].mean(),'Median1': data_cycling_training_10['avg_rss12'].median(),'SD1': data_cycling_training_10['avg_rss12'].std(),'1st Quartile1': data_cycling_training_10['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_10['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_10['var_rss12'].min(),'Max2': data_cycling_training_10['var_rss12'].max(),'Mean2': data_cycling_training_10['var_rss12'].mean(),'Median2': data_cycling_training_10['var_rss12'].median(),'SD2': data_cycling_training_10['var_rss12'].std(),'1st Quartile2': data_cycling_training_10['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_10['var_rss12'].quantile(0.75),'Min3': data_cycling_training_10['avg_rss13'].min(),'Max3': data_cycling_training_10['avg_rss13'].max(),'Mean3': data_cycling_training_10['avg_rss13'].mean(),'Median3': data_cycling_training_10['avg_rss13'].median(),'SD3': data_cycling_training_10['avg_rss13'].std(),'1st Quartile3': data_cycling_training_10['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_10['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_10['var_rss13'].min(),'Max4': data_cycling_training_10['var_rss13'].max(),'Mean4': data_cycling_training_10['var_rss13'].mean(),'Median4': data_cycling_training_10['var_rss13'].median(),'SD4': data_cycling_training_10['var_rss13'].std(),'1st Quartile4': data_cycling_training_10['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_10['var_rss13'].quantile(0.75),'Min5': data_cycling_training_10['avg_rss23'].min(),'Max5': data_cycling_training_10['avg_rss23'].max(),'Mean5': data_cycling_training_10['avg_rss23'].mean(),'Median5': data_cycling_training_10['avg_rss23'].median(),'SD5': data_cycling_training_10['avg_rss23'].std(),'1st Quartile5': data_cycling_training_10['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_10['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_10['var_rss23'].min(),'Max6': data_cycling_training_10['var_rss23'].max(),'Mean6': data_cycling_training_10['var_rss23'].mean(),'Median6': data_cycling_training_10['var_rss23'].median(),'SD6': data_cycling_training_10['var_rss23'].std(),'1st Quartile6': data_cycling_training_10['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_10['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'39','Min1':data_cycling_training_11['avg_rss12'].min(),'Max1': data_cycling_training_11['avg_rss12'].max(),'Mean1': data_cycling_training_11['avg_rss12'].mean(),'Median1': data_cycling_training_11['avg_rss12'].median(),'SD1': data_cycling_training_11['avg_rss12'].std(),'1st Quartile1': data_cycling_training_11['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_11['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_11['var_rss12'].min(),'Max2': data_cycling_training_11['var_rss12'].max(),'Mean2': data_cycling_training_11['var_rss12'].mean(),'Median2': data_cycling_training_11['var_rss12'].median(),'SD2': data_cycling_training_11['var_rss12'].std(),'1st Quartile2': data_cycling_training_11['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_11['var_rss12'].quantile(0.75),'Min3': data_cycling_training_11['avg_rss13'].min(),'Max3': data_cycling_training_11['avg_rss13'].max(),'Mean3': data_cycling_training_11['avg_rss13'].mean(),'Median3': data_cycling_training_11['avg_rss13'].median(),'SD3': data_cycling_training_11['avg_rss13'].std(),'1st Quartile3': data_cycling_training_11['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_11['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_11['var_rss13'].min(),'Max4': data_cycling_training_11['var_rss13'].max(),'Mean4': data_cycling_training_11['var_rss13'].mean(),'Median4': data_cycling_training_11['var_rss13'].median(),'SD4': data_cycling_training_11['var_rss13'].std(),'1st Quartile4': data_cycling_training_11['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_11['var_rss13'].quantile(0.75),'Min5': data_cycling_training_11['avg_rss23'].min(),'Max5': data_cycling_training_11['avg_rss23'].max(),'Mean5': data_cycling_training_11['avg_rss23'].mean(),'Median5': data_cycling_training_11['avg_rss23'].median(),'SD5': data_cycling_training_11['avg_rss23'].std(),'1st Quartile5': data_cycling_training_11['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_11['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_11['var_rss23'].min(),'Max6': data_cycling_training_11['var_rss23'].max(),'Mean6': data_cycling_training_11['var_rss23'].mean(),'Median6': data_cycling_training_11['var_rss23'].median(),'SD6': data_cycling_training_11['var_rss23'].std(),'1st Quartile6': data_cycling_training_11['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_11['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'40','Min1':data_cycling_training_12['avg_rss12'].min(),'Max1': data_cycling_training_12['avg_rss12'].max(),'Mean1': data_cycling_training_12['avg_rss12'].mean(),'Median1': data_cycling_training_12['avg_rss12'].median(),'SD1': data_cycling_training_12['avg_rss12'].std(),'1st Quartile1': data_cycling_training_12['avg_rss12'].quantile(0.25),'3rd Quartile1': data_cycling_training_12['avg_rss12'].quantile(0.75),'Min2': data_cycling_training_12['var_rss12'].min(),'Max2': data_cycling_training_12['var_rss12'].max(),'Mean2': data_cycling_training_12['var_rss12'].mean(),'Median2': data_cycling_training_12['var_rss12'].median(),'SD2': data_cycling_training_12['var_rss12'].std(),'1st Quartile2': data_cycling_training_12['var_rss12'].quantile(0.25),'3rd Quartile2': data_cycling_training_12['var_rss12'].quantile(0.75),'Min3': data_cycling_training_12['avg_rss13'].min(),'Max3': data_cycling_training_12['avg_rss13'].max(),'Mean3': data_cycling_training_12['avg_rss13'].mean(),'Median3': data_cycling_training_12['avg_rss13'].median(),'SD3': data_cycling_training_12['avg_rss13'].std(),'1st Quartile3': data_cycling_training_12['avg_rss13'].quantile(0.25),'3rd Quartile3': data_cycling_training_12['avg_rss13'].quantile(0.75),'Min4': data_cycling_training_12['var_rss13'].min(),'Max4': data_cycling_training_12['var_rss13'].max(),'Mean4': data_cycling_training_12['var_rss13'].mean(),'Median4': data_cycling_training_12['var_rss13'].median(),'SD4': data_cycling_training_12['var_rss13'].std(),'1st Quartile4': data_cycling_training_12['var_rss13'].quantile(0.25),'3rd Quartile4': data_cycling_training_12['var_rss13'].quantile(0.75),'Min5': data_cycling_training_12['avg_rss23'].min(),'Max5': data_cycling_training_12['avg_rss23'].max(),'Mean5': data_cycling_training_12['avg_rss23'].mean(),'Median5': data_cycling_training_12['avg_rss23'].median(),'SD5': data_cycling_training_12['avg_rss23'].std(),'1st Quartile5': data_cycling_training_12['avg_rss23'].quantile(0.25),'3rd Quartile5': data_cycling_training_12['avg_rss23'].quantile(0.75),'Min6': data_cycling_training_12['var_rss23'].min(),'Max6': data_cycling_training_12['var_rss23'].max(),'Mean6': data_cycling_training_12['var_rss23'].mean(),'Median6': data_cycling_training_12['var_rss23'].median(),'SD6': data_cycling_training_12['var_rss23'].std(),'1st Quartile6': data_cycling_training_12['var_rss23'].quantile(0.25),'3rd Quartile6': data_cycling_training_12['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'41','Min1':data_lying_training_1['avg_rss12'].min(),'Max1': data_lying_training_1['avg_rss12'].max(),'Mean1': data_lying_training_1['avg_rss12'].mean(),'Median1': data_lying_training_1['avg_rss12'].median(),'SD1': data_lying_training_1['avg_rss12'].std(),'1st Quartile1': data_lying_training_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_1['avg_rss12'].quantile(0.75),'Min2': data_lying_training_1['var_rss12'].min(),'Max2': data_lying_training_1['var_rss12'].max(),'Mean2': data_lying_training_1['var_rss12'].mean(),'Median2': data_lying_training_1['var_rss12'].median(),'SD2': data_lying_training_1['var_rss12'].std(),'1st Quartile2': data_lying_training_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_1['var_rss12'].quantile(0.75),'Min3': data_lying_training_1['avg_rss13'].min(),'Max3': data_lying_training_1['avg_rss13'].max(),'Mean3': data_lying_training_1['avg_rss13'].mean(),'Median3': data_lying_training_1['avg_rss13'].median(),'SD3': data_lying_training_1['avg_rss13'].std(),'1st Quartile3': data_lying_training_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_1['avg_rss13'].quantile(0.75),'Min4': data_lying_training_1['var_rss13'].min(),'Max4': data_lying_training_1['var_rss13'].max(),'Mean4': data_lying_training_1['var_rss13'].mean(),'Median4': data_lying_training_1['var_rss13'].median(),'SD4': data_lying_training_1['var_rss13'].std(),'1st Quartile4': data_lying_training_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_1['var_rss13'].quantile(0.75),'Min5': data_lying_training_1['avg_rss23'].min(),'Max5': data_lying_training_1['avg_rss23'].max(),'Mean5': data_lying_training_1['avg_rss23'].mean(),'Median5': data_lying_training_1['avg_rss23'].median(),'SD5': data_lying_training_1['avg_rss23'].std(),'1st Quartile5': data_lying_training_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_1['avg_rss23'].quantile(0.75),'Min6': data_lying_training_1['var_rss23'].min(),'Max6': data_lying_training_1['var_rss23'].max(),'Mean6': data_lying_training_1['var_rss23'].mean(),'Median6': data_lying_training_1['var_rss23'].median(),'SD6': data_lying_training_1['var_rss23'].std(),'1st Quartile6': data_lying_training_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'42','Min1':data_lying_training_2['avg_rss12'].min(),'Max1': data_lying_training_2['avg_rss12'].max(),'Mean1': data_lying_training_2['avg_rss12'].mean(),'Median1': data_lying_training_2['avg_rss12'].median(),'SD1': data_lying_training_2['avg_rss12'].std(),'1st Quartile1': data_lying_training_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_2['avg_rss12'].quantile(0.75),'Min2': data_lying_training_2['var_rss12'].min(),'Max2': data_lying_training_2['var_rss12'].max(),'Mean2': data_lying_training_2['var_rss12'].mean(),'Median2': data_lying_training_2['var_rss12'].median(),'SD2': data_lying_training_2['var_rss12'].std(),'1st Quartile2': data_lying_training_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_2['var_rss12'].quantile(0.75),'Min3': data_lying_training_2['avg_rss13'].min(),'Max3': data_lying_training_2['avg_rss13'].max(),'Mean3': data_lying_training_2['avg_rss13'].mean(),'Median3': data_lying_training_2['avg_rss13'].median(),'SD3': data_lying_training_2['avg_rss13'].std(),'1st Quartile3': data_lying_training_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_2['avg_rss13'].quantile(0.75),'Min4': data_lying_training_2['var_rss13'].min(),'Max4': data_lying_training_2['var_rss13'].max(),'Mean4': data_lying_training_2['var_rss13'].mean(),'Median4': data_lying_training_2['var_rss13'].median(),'SD4': data_lying_training_2['var_rss13'].std(),'1st Quartile4': data_lying_training_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_2['var_rss13'].quantile(0.75),'Min5': data_lying_training_2['avg_rss23'].min(),'Max5': data_lying_training_2['avg_rss23'].max(),'Mean5': data_lying_training_2['avg_rss23'].mean(),'Median5': data_lying_training_2['avg_rss23'].median(),'SD5': data_lying_training_2['avg_rss23'].std(),'1st Quartile5': data_lying_training_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_2['avg_rss23'].quantile(0.75),'Min6': data_lying_training_2['var_rss23'].min(),'Max6': data_lying_training_2['var_rss23'].max(),'Mean6': data_lying_training_2['var_rss23'].mean(),'Median6': data_lying_training_2['var_rss23'].median(),'SD6': data_lying_training_2['var_rss23'].std(),'1st Quartile6': data_lying_training_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'43','Min1':data_lying_training_3['avg_rss12'].min(),'Max1': data_lying_training_3['avg_rss12'].max(),'Mean1': data_lying_training_3['avg_rss12'].mean(),'Median1': data_lying_training_3['avg_rss12'].median(),'SD1': data_lying_training_3['avg_rss12'].std(),'1st Quartile1': data_lying_training_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_3['avg_rss12'].quantile(0.75),'Min2': data_lying_training_3['var_rss12'].min(),'Max2': data_lying_training_3['var_rss12'].max(),'Mean2': data_lying_training_3['var_rss12'].mean(),'Median2': data_lying_training_3['var_rss12'].median(),'SD2': data_lying_training_3['var_rss12'].std(),'1st Quartile2': data_lying_training_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_3['var_rss12'].quantile(0.75),'Min3': data_lying_training_3['avg_rss13'].min(),'Max3': data_lying_training_3['avg_rss13'].max(),'Mean3': data_lying_training_3['avg_rss13'].mean(),'Median3': data_lying_training_3['avg_rss13'].median(),'SD3': data_lying_training_3['avg_rss13'].std(),'1st Quartile3': data_lying_training_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_3['avg_rss13'].quantile(0.75),'Min4': data_lying_training_3['var_rss13'].min(),'Max4': data_lying_training_3['var_rss13'].max(),'Mean4': data_lying_training_3['var_rss13'].mean(),'Median4': data_lying_training_3['var_rss13'].median(),'SD4': data_lying_training_3['var_rss13'].std(),'1st Quartile4': data_lying_training_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_3['var_rss13'].quantile(0.75),'Min5': data_lying_training_3['avg_rss23'].min(),'Max5': data_lying_training_3['avg_rss23'].max(),'Mean5': data_lying_training_3['avg_rss23'].mean(),'Median5': data_lying_training_3['avg_rss23'].median(),'SD5': data_lying_training_3['avg_rss23'].std(),'1st Quartile5': data_lying_training_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_3['avg_rss23'].quantile(0.75),'Min6': data_lying_training_3['var_rss23'].min(),'Max6': data_lying_training_3['var_rss23'].max(),'Mean6': data_lying_training_3['var_rss23'].mean(),'Median6': data_lying_training_3['var_rss23'].median(),'SD6': data_lying_training_3['var_rss23'].std(),'1st Quartile6': data_lying_training_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'44','Min1':data_lying_training_4['avg_rss12'].min(),'Max1': data_lying_training_4['avg_rss12'].max(),'Mean1': data_lying_training_4['avg_rss12'].mean(),'Median1': data_lying_training_4['avg_rss12'].median(),'SD1': data_lying_training_4['avg_rss12'].std(),'1st Quartile1': data_lying_training_4['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_4['avg_rss12'].quantile(0.75),'Min2': data_lying_training_4['var_rss12'].min(),'Max2': data_lying_training_4['var_rss12'].max(),'Mean2': data_lying_training_4['var_rss12'].mean(),'Median2': data_lying_training_4['var_rss12'].median(),'SD2': data_lying_training_4['var_rss12'].std(),'1st Quartile2': data_lying_training_4['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_4['var_rss12'].quantile(0.75),'Min3': data_lying_training_4['avg_rss13'].min(),'Max3': data_lying_training_4['avg_rss13'].max(),'Mean3': data_lying_training_4['avg_rss13'].mean(),'Median3': data_lying_training_4['avg_rss13'].median(),'SD3': data_lying_training_4['avg_rss13'].std(),'1st Quartile3': data_lying_training_4['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_4['avg_rss13'].quantile(0.75),'Min4': data_lying_training_4['var_rss13'].min(),'Max4': data_lying_training_4['var_rss13'].max(),'Mean4': data_lying_training_4['var_rss13'].mean(),'Median4': data_lying_training_4['var_rss13'].median(),'SD4': data_lying_training_4['var_rss13'].std(),'1st Quartile4': data_lying_training_4['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_4['var_rss13'].quantile(0.75),'Min5': data_lying_training_4['avg_rss23'].min(),'Max5': data_lying_training_4['avg_rss23'].max(),'Mean5': data_lying_training_4['avg_rss23'].mean(),'Median5': data_lying_training_4['avg_rss23'].median(),'SD5': data_lying_training_4['avg_rss23'].std(),'1st Quartile5': data_lying_training_4['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_4['avg_rss23'].quantile(0.75),'Min6': data_lying_training_4['var_rss23'].min(),'Max6': data_lying_training_4['var_rss23'].max(),'Mean6': data_lying_training_4['var_rss23'].mean(),'Median6': data_lying_training_4['var_rss23'].median(),'SD6': data_lying_training_4['var_rss23'].std(),'1st Quartile6': data_lying_training_4['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_4['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'45','Min1':data_lying_training_5['avg_rss12'].min(),'Max1': data_lying_training_5['avg_rss12'].max(),'Mean1': data_lying_training_5['avg_rss12'].mean(),'Median1': data_lying_training_5['avg_rss12'].median(),'SD1': data_lying_training_5['avg_rss12'].std(),'1st Quartile1': data_lying_training_5['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_5['avg_rss12'].quantile(0.75),'Min2': data_lying_training_5['var_rss12'].min(),'Max2': data_lying_training_5['var_rss12'].max(),'Mean2': data_lying_training_5['var_rss12'].mean(),'Median2': data_lying_training_5['var_rss12'].median(),'SD2': data_lying_training_5['var_rss12'].std(),'1st Quartile2': data_lying_training_5['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_5['var_rss12'].quantile(0.75),'Min3': data_lying_training_5['avg_rss13'].min(),'Max3': data_lying_training_5['avg_rss13'].max(),'Mean3': data_lying_training_5['avg_rss13'].mean(),'Median3': data_lying_training_5['avg_rss13'].median(),'SD3': data_lying_training_5['avg_rss13'].std(),'1st Quartile3': data_lying_training_5['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_5['avg_rss13'].quantile(0.75),'Min4': data_lying_training_5['var_rss13'].min(),'Max4': data_lying_training_5['var_rss13'].max(),'Mean4': data_lying_training_5['var_rss13'].mean(),'Median4': data_lying_training_5['var_rss13'].median(),'SD4': data_lying_training_5['var_rss13'].std(),'1st Quartile4': data_lying_training_5['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_5['var_rss13'].quantile(0.75),'Min5': data_lying_training_5['avg_rss23'].min(),'Max5': data_lying_training_5['avg_rss23'].max(),'Mean5': data_lying_training_5['avg_rss23'].mean(),'Median5': data_lying_training_5['avg_rss23'].median(),'SD5': data_lying_training_5['avg_rss23'].std(),'1st Quartile5': data_lying_training_5['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_5['avg_rss23'].quantile(0.75),'Min6': data_lying_training_5['var_rss23'].min(),'Max6': data_lying_training_5['var_rss23'].max(),'Mean6': data_lying_training_5['var_rss23'].mean(),'Median6': data_lying_training_5['var_rss23'].median(),'SD6': data_lying_training_5['var_rss23'].std(),'1st Quartile6': data_lying_training_5['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_5['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'46','Min1':data_lying_training_6['avg_rss12'].min(),'Max1': data_lying_training_6['avg_rss12'].max(),'Mean1': data_lying_training_6['avg_rss12'].mean(),'Median1': data_lying_training_6['avg_rss12'].median(),'SD1': data_lying_training_6['avg_rss12'].std(),'1st Quartile1': data_lying_training_6['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_6['avg_rss12'].quantile(0.75),'Min2': data_lying_training_6['var_rss12'].min(),'Max2': data_lying_training_6['var_rss12'].max(),'Mean2': data_lying_training_6['var_rss12'].mean(),'Median2': data_lying_training_6['var_rss12'].median(),'SD2': data_lying_training_6['var_rss12'].std(),'1st Quartile2': data_lying_training_6['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_6['var_rss12'].quantile(0.75),'Min3': data_lying_training_6['avg_rss13'].min(),'Max3': data_lying_training_6['avg_rss13'].max(),'Mean3': data_lying_training_6['avg_rss13'].mean(),'Median3': data_lying_training_6['avg_rss13'].median(),'SD3': data_lying_training_6['avg_rss13'].std(),'1st Quartile3': data_lying_training_6['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_6['avg_rss13'].quantile(0.75),'Min4': data_lying_training_6['var_rss13'].min(),'Max4': data_lying_training_6['var_rss13'].max(),'Mean4': data_lying_training_6['var_rss13'].mean(),'Median4': data_lying_training_6['var_rss13'].median(),'SD4': data_lying_training_6['var_rss13'].std(),'1st Quartile4': data_lying_training_6['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_6['var_rss13'].quantile(0.75),'Min5': data_lying_training_6['avg_rss23'].min(),'Max5': data_lying_training_6['avg_rss23'].max(),'Mean5': data_lying_training_6['avg_rss23'].mean(),'Median5': data_lying_training_6['avg_rss23'].median(),'SD5': data_lying_training_6['avg_rss23'].std(),'1st Quartile5': data_lying_training_6['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_6['avg_rss23'].quantile(0.75),'Min6': data_lying_training_6['var_rss23'].min(),'Max6': data_lying_training_6['var_rss23'].max(),'Mean6': data_lying_training_6['var_rss23'].mean(),'Median6': data_lying_training_6['var_rss23'].median(),'SD6': data_lying_training_6['var_rss23'].std(),'1st Quartile6': data_lying_training_6['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_6['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'47','Min1':data_lying_training_7['avg_rss12'].min(),'Max1': data_lying_training_7['avg_rss12'].max(),'Mean1': data_lying_training_7['avg_rss12'].mean(),'Median1': data_lying_training_7['avg_rss12'].median(),'SD1': data_lying_training_7['avg_rss12'].std(),'1st Quartile1': data_lying_training_7['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_7['avg_rss12'].quantile(0.75),'Min2': data_lying_training_7['var_rss12'].min(),'Max2': data_lying_training_7['var_rss12'].max(),'Mean2': data_lying_training_7['var_rss12'].mean(),'Median2': data_lying_training_7['var_rss12'].median(),'SD2': data_lying_training_7['var_rss12'].std(),'1st Quartile2': data_lying_training_7['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_7['var_rss12'].quantile(0.75),'Min3': data_lying_training_7['avg_rss13'].min(),'Max3': data_lying_training_7['avg_rss13'].max(),'Mean3': data_lying_training_7['avg_rss13'].mean(),'Median3': data_lying_training_7['avg_rss13'].median(),'SD3': data_lying_training_7['avg_rss13'].std(),'1st Quartile3': data_lying_training_7['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_7['avg_rss13'].quantile(0.75),'Min4': data_lying_training_7['var_rss13'].min(),'Max4': data_lying_training_7['var_rss13'].max(),'Mean4': data_lying_training_7['var_rss13'].mean(),'Median4': data_lying_training_7['var_rss13'].median(),'SD4': data_lying_training_7['var_rss13'].std(),'1st Quartile4': data_lying_training_7['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_7['var_rss13'].quantile(0.75),'Min5': data_lying_training_7['avg_rss23'].min(),'Max5': data_lying_training_7['avg_rss23'].max(),'Mean5': data_lying_training_7['avg_rss23'].mean(),'Median5': data_lying_training_7['avg_rss23'].median(),'SD5': data_lying_training_7['avg_rss23'].std(),'1st Quartile5': data_lying_training_7['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_7['avg_rss23'].quantile(0.75),'Min6': data_lying_training_7['var_rss23'].min(),'Max6': data_lying_training_7['var_rss23'].max(),'Mean6': data_lying_training_7['var_rss23'].mean(),'Median6': data_lying_training_7['var_rss23'].median(),'SD6': data_lying_training_7['var_rss23'].std(),'1st Quartile6': data_lying_training_7['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_7['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'48','Min1':data_lying_training_8['avg_rss12'].min(),'Max1': data_lying_training_8['avg_rss12'].max(),'Mean1': data_lying_training_8['avg_rss12'].mean(),'Median1': data_lying_training_8['avg_rss12'].median(),'SD1': data_lying_training_8['avg_rss12'].std(),'1st Quartile1': data_lying_training_8['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_8['avg_rss12'].quantile(0.75),'Min2': data_lying_training_8['var_rss12'].min(),'Max2': data_lying_training_8['var_rss12'].max(),'Mean2': data_lying_training_8['var_rss12'].mean(),'Median2': data_lying_training_8['var_rss12'].median(),'SD2': data_lying_training_8['var_rss12'].std(),'1st Quartile2': data_lying_training_8['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_8['var_rss12'].quantile(0.75),'Min3': data_lying_training_8['avg_rss13'].min(),'Max3': data_lying_training_8['avg_rss13'].max(),'Mean3': data_lying_training_8['avg_rss13'].mean(),'Median3': data_lying_training_8['avg_rss13'].median(),'SD3': data_lying_training_8['avg_rss13'].std(),'1st Quartile3': data_lying_training_8['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_8['avg_rss13'].quantile(0.75),'Min4': data_lying_training_8['var_rss13'].min(),'Max4': data_lying_training_8['var_rss13'].max(),'Mean4': data_lying_training_8['var_rss13'].mean(),'Median4': data_lying_training_8['var_rss13'].median(),'SD4': data_lying_training_8['var_rss13'].std(),'1st Quartile4': data_lying_training_8['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_8['var_rss13'].quantile(0.75),'Min5': data_lying_training_8['avg_rss23'].min(),'Max5': data_lying_training_8['avg_rss23'].max(),'Mean5': data_lying_training_8['avg_rss23'].mean(),'Median5': data_lying_training_8['avg_rss23'].median(),'SD5': data_lying_training_8['avg_rss23'].std(),'1st Quartile5': data_lying_training_8['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_8['avg_rss23'].quantile(0.75),'Min6': data_lying_training_8['var_rss23'].min(),'Max6': data_lying_training_8['var_rss23'].max(),'Mean6': data_lying_training_8['var_rss23'].mean(),'Median6': data_lying_training_8['var_rss23'].median(),'SD6': data_lying_training_8['var_rss23'].std(),'1st Quartile6': data_lying_training_8['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_8['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'49','Min1':data_lying_training_9['avg_rss12'].min(),'Max1': data_lying_training_9['avg_rss12'].max(),'Mean1': data_lying_training_9['avg_rss12'].mean(),'Median1': data_lying_training_9['avg_rss12'].median(),'SD1': data_lying_training_9['avg_rss12'].std(),'1st Quartile1': data_lying_training_9['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_9['avg_rss12'].quantile(0.75),'Min2': data_lying_training_9['var_rss12'].min(),'Max2': data_lying_training_9['var_rss12'].max(),'Mean2': data_lying_training_9['var_rss12'].mean(),'Median2': data_lying_training_9['var_rss12'].median(),'SD2': data_lying_training_9['var_rss12'].std(),'1st Quartile2': data_lying_training_9['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_9['var_rss12'].quantile(0.75),'Min3': data_lying_training_9['avg_rss13'].min(),'Max3': data_lying_training_9['avg_rss13'].max(),'Mean3': data_lying_training_9['avg_rss13'].mean(),'Median3': data_lying_training_9['avg_rss13'].median(),'SD3': data_lying_training_9['avg_rss13'].std(),'1st Quartile3': data_lying_training_9['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_9['avg_rss13'].quantile(0.75),'Min4': data_lying_training_9['var_rss13'].min(),'Max4': data_lying_training_9['var_rss13'].max(),'Mean4': data_lying_training_9['var_rss13'].mean(),'Median4': data_lying_training_9['var_rss13'].median(),'SD4': data_lying_training_9['var_rss13'].std(),'1st Quartile4': data_lying_training_9['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_9['var_rss13'].quantile(0.75),'Min5': data_lying_training_9['avg_rss23'].min(),'Max5': data_lying_training_9['avg_rss23'].max(),'Mean5': data_lying_training_9['avg_rss23'].mean(),'Median5': data_lying_training_9['avg_rss23'].median(),'SD5': data_lying_training_9['avg_rss23'].std(),'1st Quartile5': data_lying_training_9['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_9['avg_rss23'].quantile(0.75),'Min6': data_lying_training_9['var_rss23'].min(),'Max6': data_lying_training_9['var_rss23'].max(),'Mean6': data_lying_training_9['var_rss23'].mean(),'Median6': data_lying_training_9['var_rss23'].median(),'SD6': data_lying_training_9['var_rss23'].std(),'1st Quartile6': data_lying_training_9['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_9['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'50','Min1':data_lying_training_10['avg_rss12'].min(),'Max1': data_lying_training_10['avg_rss12'].max(),'Mean1': data_lying_training_10['avg_rss12'].mean(),'Median1': data_lying_training_10['avg_rss12'].median(),'SD1': data_lying_training_10['avg_rss12'].std(),'1st Quartile1': data_lying_training_10['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_10['avg_rss12'].quantile(0.75),'Min2': data_lying_training_10['var_rss12'].min(),'Max2': data_lying_training_10['var_rss12'].max(),'Mean2': data_lying_training_10['var_rss12'].mean(),'Median2': data_lying_training_10['var_rss12'].median(),'SD2': data_lying_training_10['var_rss12'].std(),'1st Quartile2': data_lying_training_10['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_10['var_rss12'].quantile(0.75),'Min3': data_lying_training_10['avg_rss13'].min(),'Max3': data_lying_training_10['avg_rss13'].max(),'Mean3': data_lying_training_10['avg_rss13'].mean(),'Median3': data_lying_training_10['avg_rss13'].median(),'SD3': data_lying_training_10['avg_rss13'].std(),'1st Quartile3': data_lying_training_10['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_10['avg_rss13'].quantile(0.75),'Min4': data_lying_training_10['var_rss13'].min(),'Max4': data_lying_training_10['var_rss13'].max(),'Mean4': data_lying_training_10['var_rss13'].mean(),'Median4': data_lying_training_10['var_rss13'].median(),'SD4': data_lying_training_10['var_rss13'].std(),'1st Quartile4': data_lying_training_10['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_10['var_rss13'].quantile(0.75),'Min5': data_lying_training_10['avg_rss23'].min(),'Max5': data_lying_training_10['avg_rss23'].max(),'Mean5': data_lying_training_10['avg_rss23'].mean(),'Median5': data_lying_training_10['avg_rss23'].median(),'SD5': data_lying_training_10['avg_rss23'].std(),'1st Quartile5': data_lying_training_10['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_10['avg_rss23'].quantile(0.75),'Min6': data_lying_training_10['var_rss23'].min(),'Max6': data_lying_training_10['var_rss23'].max(),'Mean6': data_lying_training_10['var_rss23'].mean(),'Median6': data_lying_training_10['var_rss23'].median(),'SD6': data_lying_training_10['var_rss23'].std(),'1st Quartile6': data_lying_training_10['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_10['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'51','Min1':data_lying_training_11['avg_rss12'].min(),'Max1': data_lying_training_11['avg_rss12'].max(),'Mean1': data_lying_training_11['avg_rss12'].mean(),'Median1': data_lying_training_11['avg_rss12'].median(),'SD1': data_lying_training_11['avg_rss12'].std(),'1st Quartile1': data_lying_training_11['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_11['avg_rss12'].quantile(0.75),'Min2': data_lying_training_11['var_rss12'].min(),'Max2': data_lying_training_11['var_rss12'].max(),'Mean2': data_lying_training_11['var_rss12'].mean(),'Median2': data_lying_training_11['var_rss12'].median(),'SD2': data_lying_training_11['var_rss12'].std(),'1st Quartile2': data_lying_training_11['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_11['var_rss12'].quantile(0.75),'Min3': data_lying_training_11['avg_rss13'].min(),'Max3': data_lying_training_11['avg_rss13'].max(),'Mean3': data_lying_training_11['avg_rss13'].mean(),'Median3': data_lying_training_11['avg_rss13'].median(),'SD3': data_lying_training_11['avg_rss13'].std(),'1st Quartile3': data_lying_training_11['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_11['avg_rss13'].quantile(0.75),'Min4': data_lying_training_11['var_rss13'].min(),'Max4': data_lying_training_11['var_rss13'].max(),'Mean4': data_lying_training_11['var_rss13'].mean(),'Median4': data_lying_training_11['var_rss13'].median(),'SD4': data_lying_training_11['var_rss13'].std(),'1st Quartile4': data_lying_training_11['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_11['var_rss13'].quantile(0.75),'Min5': data_lying_training_11['avg_rss23'].min(),'Max5': data_lying_training_11['avg_rss23'].max(),'Mean5': data_lying_training_11['avg_rss23'].mean(),'Median5': data_lying_training_11['avg_rss23'].median(),'SD5': data_lying_training_11['avg_rss23'].std(),'1st Quartile5': data_lying_training_11['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_11['avg_rss23'].quantile(0.75),'Min6': data_lying_training_11['var_rss23'].min(),'Max6': data_lying_training_11['var_rss23'].max(),'Mean6': data_lying_training_11['var_rss23'].mean(),'Median6': data_lying_training_11['var_rss23'].median(),'SD6': data_lying_training_11['var_rss23'].std(),'1st Quartile6': data_lying_training_11['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_11['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'52','Min1':data_lying_training_12['avg_rss12'].min(),'Max1': data_lying_training_12['avg_rss12'].max(),'Mean1': data_lying_training_12['avg_rss12'].mean(),'Median1': data_lying_training_12['avg_rss12'].median(),'SD1': data_lying_training_12['avg_rss12'].std(),'1st Quartile1': data_lying_training_12['avg_rss12'].quantile(0.25),'3rd Quartile1': data_lying_training_12['avg_rss12'].quantile(0.75),'Min2': data_lying_training_12['var_rss12'].min(),'Max2': data_lying_training_12['var_rss12'].max(),'Mean2': data_lying_training_12['var_rss12'].mean(),'Median2': data_lying_training_12['var_rss12'].median(),'SD2': data_lying_training_12['var_rss12'].std(),'1st Quartile2': data_lying_training_12['var_rss12'].quantile(0.25),'3rd Quartile2': data_lying_training_12['var_rss12'].quantile(0.75),'Min3': data_lying_training_12['avg_rss13'].min(),'Max3': data_lying_training_12['avg_rss13'].max(),'Mean3': data_lying_training_12['avg_rss13'].mean(),'Median3': data_lying_training_12['avg_rss13'].median(),'SD3': data_lying_training_12['avg_rss13'].std(),'1st Quartile3': data_lying_training_12['avg_rss13'].quantile(0.25),'3rd Quartile3': data_lying_training_12['avg_rss13'].quantile(0.75),'Min4': data_lying_training_12['var_rss13'].min(),'Max4': data_lying_training_12['var_rss13'].max(),'Mean4': data_lying_training_12['var_rss13'].mean(),'Median4': data_lying_training_12['var_rss13'].median(),'SD4': data_lying_training_12['var_rss13'].std(),'1st Quartile4': data_lying_training_12['var_rss13'].quantile(0.25),'3rd Quartile4': data_lying_training_12['var_rss13'].quantile(0.75),'Min5': data_lying_training_12['avg_rss23'].min(),'Max5': data_lying_training_12['avg_rss23'].max(),'Mean5': data_lying_training_12['avg_rss23'].mean(),'Median5': data_lying_training_12['avg_rss23'].median(),'SD5': data_lying_training_12['avg_rss23'].std(),'1st Quartile5': data_lying_training_12['avg_rss23'].quantile(0.25),'3rd Quartile5': data_lying_training_12['avg_rss23'].quantile(0.75),'Min6': data_lying_training_12['var_rss23'].min(),'Max6': data_lying_training_12['var_rss23'].max(),'Mean6': data_lying_training_12['var_rss23'].mean(),'Median6': data_lying_training_12['var_rss23'].median(),'SD6': data_lying_training_12['var_rss23'].std(),'1st Quartile6': data_lying_training_12['var_rss23'].quantile(0.25),'3rd Quartile6': data_lying_training_12['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'53','Min1':data_sitting_training_1['avg_rss12'].min(),'Max1': data_sitting_training_1['avg_rss12'].max(),'Mean1': data_sitting_training_1['avg_rss12'].mean(),'Median1': data_sitting_training_1['avg_rss12'].median(),'SD1': data_sitting_training_1['avg_rss12'].std(),'1st Quartile1': data_sitting_training_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_1['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_1['var_rss12'].min(),'Max2': data_sitting_training_1['var_rss12'].max(),'Mean2': data_sitting_training_1['var_rss12'].mean(),'Median2': data_sitting_training_1['var_rss12'].median(),'SD2': data_sitting_training_1['var_rss12'].std(),'1st Quartile2': data_sitting_training_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_1['var_rss12'].quantile(0.75),'Min3': data_sitting_training_1['avg_rss13'].min(),'Max3': data_sitting_training_1['avg_rss13'].max(),'Mean3': data_sitting_training_1['avg_rss13'].mean(),'Median3': data_sitting_training_1['avg_rss13'].median(),'SD3': data_sitting_training_1['avg_rss13'].std(),'1st Quartile3': data_sitting_training_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_1['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_1['var_rss13'].min(),'Max4': data_sitting_training_1['var_rss13'].max(),'Mean4': data_sitting_training_1['var_rss13'].mean(),'Median4': data_sitting_training_1['var_rss13'].median(),'SD4': data_sitting_training_1['var_rss13'].std(),'1st Quartile4': data_sitting_training_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_1['var_rss13'].quantile(0.75),'Min5': data_sitting_training_1['avg_rss23'].min(),'Max5': data_sitting_training_1['avg_rss23'].max(),'Mean5': data_sitting_training_1['avg_rss23'].mean(),'Median5': data_sitting_training_1['avg_rss23'].median(),'SD5': data_sitting_training_1['avg_rss23'].std(),'1st Quartile5': data_sitting_training_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_1['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_1['var_rss23'].min(),'Max6': data_sitting_training_1['var_rss23'].max(),'Mean6': data_sitting_training_1['var_rss23'].mean(),'Median6': data_sitting_training_1['var_rss23'].median(),'SD6': data_sitting_training_1['var_rss23'].std(),'1st Quartile6': data_sitting_training_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'54','Min1':data_sitting_training_2['avg_rss12'].min(),'Max1': data_sitting_training_2['avg_rss12'].max(),'Mean1': data_sitting_training_2['avg_rss12'].mean(),'Median1': data_sitting_training_2['avg_rss12'].median(),'SD1': data_sitting_training_2['avg_rss12'].std(),'1st Quartile1': data_sitting_training_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_2['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_2['var_rss12'].min(),'Max2': data_sitting_training_2['var_rss12'].max(),'Mean2': data_sitting_training_2['var_rss12'].mean(),'Median2': data_sitting_training_2['var_rss12'].median(),'SD2': data_sitting_training_2['var_rss12'].std(),'1st Quartile2': data_sitting_training_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_2['var_rss12'].quantile(0.75),'Min3': data_sitting_training_2['avg_rss13'].min(),'Max3': data_sitting_training_2['avg_rss13'].max(),'Mean3': data_sitting_training_2['avg_rss13'].mean(),'Median3': data_sitting_training_2['avg_rss13'].median(),'SD3': data_sitting_training_2['avg_rss13'].std(),'1st Quartile3': data_sitting_training_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_2['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_2['var_rss13'].min(),'Max4': data_sitting_training_2['var_rss13'].max(),'Mean4': data_sitting_training_2['var_rss13'].mean(),'Median4': data_sitting_training_2['var_rss13'].median(),'SD4': data_sitting_training_2['var_rss13'].std(),'1st Quartile4': data_sitting_training_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_2['var_rss13'].quantile(0.75),'Min5': data_sitting_training_2['avg_rss23'].min(),'Max5': data_sitting_training_2['avg_rss23'].max(),'Mean5': data_sitting_training_2['avg_rss23'].mean(),'Median5': data_sitting_training_2['avg_rss23'].median(),'SD5': data_sitting_training_2['avg_rss23'].std(),'1st Quartile5': data_sitting_training_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_2['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_2['var_rss23'].min(),'Max6': data_sitting_training_2['var_rss23'].max(),'Mean6': data_sitting_training_2['var_rss23'].mean(),'Median6': data_sitting_training_2['var_rss23'].median(),'SD6': data_sitting_training_2['var_rss23'].std(),'1st Quartile6': data_sitting_training_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'55','Min1':data_sitting_training_3['avg_rss12'].min(),'Max1': data_sitting_training_3['avg_rss12'].max(),'Mean1': data_sitting_training_3['avg_rss12'].mean(),'Median1': data_sitting_training_3['avg_rss12'].median(),'SD1': data_sitting_training_3['avg_rss12'].std(),'1st Quartile1': data_sitting_training_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_3['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_3['var_rss12'].min(),'Max2': data_sitting_training_3['var_rss12'].max(),'Mean2': data_sitting_training_3['var_rss12'].mean(),'Median2': data_sitting_training_3['var_rss12'].median(),'SD2': data_sitting_training_3['var_rss12'].std(),'1st Quartile2': data_sitting_training_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_3['var_rss12'].quantile(0.75),'Min3': data_sitting_training_3['avg_rss13'].min(),'Max3': data_sitting_training_3['avg_rss13'].max(),'Mean3': data_sitting_training_3['avg_rss13'].mean(),'Median3': data_sitting_training_3['avg_rss13'].median(),'SD3': data_sitting_training_3['avg_rss13'].std(),'1st Quartile3': data_sitting_training_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_3['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_3['var_rss13'].min(),'Max4': data_sitting_training_3['var_rss13'].max(),'Mean4': data_sitting_training_3['var_rss13'].mean(),'Median4': data_sitting_training_3['var_rss13'].median(),'SD4': data_sitting_training_3['var_rss13'].std(),'1st Quartile4': data_sitting_training_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_3['var_rss13'].quantile(0.75),'Min5': data_sitting_training_3['avg_rss23'].min(),'Max5': data_sitting_training_3['avg_rss23'].max(),'Mean5': data_sitting_training_3['avg_rss23'].mean(),'Median5': data_sitting_training_3['avg_rss23'].median(),'SD5': data_sitting_training_3['avg_rss23'].std(),'1st Quartile5': data_sitting_training_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_3['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_3['var_rss23'].min(),'Max6': data_sitting_training_3['var_rss23'].max(),'Mean6': data_sitting_training_3['var_rss23'].mean(),'Median6': data_sitting_training_3['var_rss23'].median(),'SD6': data_sitting_training_3['var_rss23'].std(),'1st Quartile6': data_sitting_training_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'56','Min1':data_sitting_training_4['avg_rss12'].min(),'Max1': data_sitting_training_4['avg_rss12'].max(),'Mean1': data_sitting_training_4['avg_rss12'].mean(),'Median1': data_sitting_training_4['avg_rss12'].median(),'SD1': data_sitting_training_4['avg_rss12'].std(),'1st Quartile1': data_sitting_training_4['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_4['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_4['var_rss12'].min(),'Max2': data_sitting_training_4['var_rss12'].max(),'Mean2': data_sitting_training_4['var_rss12'].mean(),'Median2': data_sitting_training_4['var_rss12'].median(),'SD2': data_sitting_training_4['var_rss12'].std(),'1st Quartile2': data_sitting_training_4['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_4['var_rss12'].quantile(0.75),'Min3': data_sitting_training_4['avg_rss13'].min(),'Max3': data_sitting_training_4['avg_rss13'].max(),'Mean3': data_sitting_training_4['avg_rss13'].mean(),'Median3': data_sitting_training_4['avg_rss13'].median(),'SD3': data_sitting_training_4['avg_rss13'].std(),'1st Quartile3': data_sitting_training_4['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_4['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_4['var_rss13'].min(),'Max4': data_sitting_training_4['var_rss13'].max(),'Mean4': data_sitting_training_4['var_rss13'].mean(),'Median4': data_sitting_training_4['var_rss13'].median(),'SD4': data_sitting_training_4['var_rss13'].std(),'1st Quartile4': data_sitting_training_4['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_4['var_rss13'].quantile(0.75),'Min5': data_sitting_training_4['avg_rss23'].min(),'Max5': data_sitting_training_4['avg_rss23'].max(),'Mean5': data_sitting_training_4['avg_rss23'].mean(),'Median5': data_sitting_training_4['avg_rss23'].median(),'SD5': data_sitting_training_4['avg_rss23'].std(),'1st Quartile5': data_sitting_training_4['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_4['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_4['var_rss23'].min(),'Max6': data_sitting_training_4['var_rss23'].max(),'Mean6': data_sitting_training_4['var_rss23'].mean(),'Median6': data_sitting_training_4['var_rss23'].median(),'SD6': data_sitting_training_4['var_rss23'].std(),'1st Quartile6': data_sitting_training_4['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_4['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'57','Min1':data_sitting_training_5['avg_rss12'].min(),'Max1': data_sitting_training_5['avg_rss12'].max(),'Mean1': data_sitting_training_5['avg_rss12'].mean(),'Median1': data_sitting_training_5['avg_rss12'].median(),'SD1': data_sitting_training_5['avg_rss12'].std(),'1st Quartile1': data_sitting_training_5['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_5['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_5['var_rss12'].min(),'Max2': data_sitting_training_5['var_rss12'].max(),'Mean2': data_sitting_training_5['var_rss12'].mean(),'Median2': data_sitting_training_5['var_rss12'].median(),'SD2': data_sitting_training_5['var_rss12'].std(),'1st Quartile2': data_sitting_training_5['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_5['var_rss12'].quantile(0.75),'Min3': data_sitting_training_5['avg_rss13'].min(),'Max3': data_sitting_training_5['avg_rss13'].max(),'Mean3': data_sitting_training_5['avg_rss13'].mean(),'Median3': data_sitting_training_5['avg_rss13'].median(),'SD3': data_sitting_training_5['avg_rss13'].std(),'1st Quartile3': data_sitting_training_5['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_5['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_5['var_rss13'].min(),'Max4': data_sitting_training_5['var_rss13'].max(),'Mean4': data_sitting_training_5['var_rss13'].mean(),'Median4': data_sitting_training_5['var_rss13'].median(),'SD4': data_sitting_training_5['var_rss13'].std(),'1st Quartile4': data_sitting_training_5['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_5['var_rss13'].quantile(0.75),'Min5': data_sitting_training_5['avg_rss23'].min(),'Max5': data_sitting_training_5['avg_rss23'].max(),'Mean5': data_sitting_training_5['avg_rss23'].mean(),'Median5': data_sitting_training_5['avg_rss23'].median(),'SD5': data_sitting_training_5['avg_rss23'].std(),'1st Quartile5': data_sitting_training_5['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_5['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_5['var_rss23'].min(),'Max6': data_sitting_training_5['var_rss23'].max(),'Mean6': data_sitting_training_5['var_rss23'].mean(),'Median6': data_sitting_training_5['var_rss23'].median(),'SD6': data_sitting_training_5['var_rss23'].std(),'1st Quartile6': data_sitting_training_5['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_5['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'58','Min1':data_sitting_training_6['avg_rss12'].min(),'Max1': data_sitting_training_6['avg_rss12'].max(),'Mean1': data_sitting_training_6['avg_rss12'].mean(),'Median1': data_sitting_training_6['avg_rss12'].median(),'SD1': data_sitting_training_6['avg_rss12'].std(),'1st Quartile1': data_sitting_training_6['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_6['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_6['var_rss12'].min(),'Max2': data_sitting_training_6['var_rss12'].max(),'Mean2': data_sitting_training_6['var_rss12'].mean(),'Median2': data_sitting_training_6['var_rss12'].median(),'SD2': data_sitting_training_6['var_rss12'].std(),'1st Quartile2': data_sitting_training_6['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_6['var_rss12'].quantile(0.75),'Min3': data_sitting_training_6['avg_rss13'].min(),'Max3': data_sitting_training_6['avg_rss13'].max(),'Mean3': data_sitting_training_6['avg_rss13'].mean(),'Median3': data_sitting_training_6['avg_rss13'].median(),'SD3': data_sitting_training_6['avg_rss13'].std(),'1st Quartile3': data_sitting_training_6['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_6['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_6['var_rss13'].min(),'Max4': data_sitting_training_6['var_rss13'].max(),'Mean4': data_sitting_training_6['var_rss13'].mean(),'Median4': data_sitting_training_6['var_rss13'].median(),'SD4': data_sitting_training_6['var_rss13'].std(),'1st Quartile4': data_sitting_training_6['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_6['var_rss13'].quantile(0.75),'Min5': data_sitting_training_6['avg_rss23'].min(),'Max5': data_sitting_training_6['avg_rss23'].max(),'Mean5': data_sitting_training_6['avg_rss23'].mean(),'Median5': data_sitting_training_6['avg_rss23'].median(),'SD5': data_sitting_training_6['avg_rss23'].std(),'1st Quartile5': data_sitting_training_6['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_6['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_6['var_rss23'].min(),'Max6': data_sitting_training_6['var_rss23'].max(),'Mean6': data_sitting_training_6['var_rss23'].mean(),'Median6': data_sitting_training_6['var_rss23'].median(),'SD6': data_sitting_training_6['var_rss23'].std(),'1st Quartile6': data_sitting_training_6['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_6['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'59','Min1':data_sitting_training_7['avg_rss12'].min(),'Max1': data_sitting_training_7['avg_rss12'].max(),'Mean1': data_sitting_training_7['avg_rss12'].mean(),'Median1': data_sitting_training_7['avg_rss12'].median(),'SD1': data_sitting_training_7['avg_rss12'].std(),'1st Quartile1': data_sitting_training_7['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_7['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_7['var_rss12'].min(),'Max2': data_sitting_training_7['var_rss12'].max(),'Mean2': data_sitting_training_7['var_rss12'].mean(),'Median2': data_sitting_training_7['var_rss12'].median(),'SD2': data_sitting_training_7['var_rss12'].std(),'1st Quartile2': data_sitting_training_7['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_7['var_rss12'].quantile(0.75),'Min3': data_sitting_training_7['avg_rss13'].min(),'Max3': data_sitting_training_7['avg_rss13'].max(),'Mean3': data_sitting_training_7['avg_rss13'].mean(),'Median3': data_sitting_training_7['avg_rss13'].median(),'SD3': data_sitting_training_7['avg_rss13'].std(),'1st Quartile3': data_sitting_training_7['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_7['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_7['var_rss13'].min(),'Max4': data_sitting_training_7['var_rss13'].max(),'Mean4': data_sitting_training_7['var_rss13'].mean(),'Median4': data_sitting_training_7['var_rss13'].median(),'SD4': data_sitting_training_7['var_rss13'].std(),'1st Quartile4': data_sitting_training_7['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_7['var_rss13'].quantile(0.75),'Min5': data_sitting_training_7['avg_rss23'].min(),'Max5': data_sitting_training_7['avg_rss23'].max(),'Mean5': data_sitting_training_7['avg_rss23'].mean(),'Median5': data_sitting_training_7['avg_rss23'].median(),'SD5': data_sitting_training_7['avg_rss23'].std(),'1st Quartile5': data_sitting_training_7['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_7['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_7['var_rss23'].min(),'Max6': data_sitting_training_7['var_rss23'].max(),'Mean6': data_sitting_training_7['var_rss23'].mean(),'Median6': data_sitting_training_7['var_rss23'].median(),'SD6': data_sitting_training_7['var_rss23'].std(),'1st Quartile6': data_sitting_training_7['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_7['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'60','Min1':data_sitting_training_8['avg_rss12'].min(),'Max1': data_sitting_training_8['avg_rss12'].max(),'Mean1': data_sitting_training_8['avg_rss12'].mean(),'Median1': data_sitting_training_8['avg_rss12'].median(),'SD1': data_sitting_training_8['avg_rss12'].std(),'1st Quartile1': data_sitting_training_8['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_8['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_8['var_rss12'].min(),'Max2': data_sitting_training_8['var_rss12'].max(),'Mean2': data_sitting_training_8['var_rss12'].mean(),'Median2': data_sitting_training_8['var_rss12'].median(),'SD2': data_sitting_training_8['var_rss12'].std(),'1st Quartile2': data_sitting_training_8['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_8['var_rss12'].quantile(0.75),'Min3': data_sitting_training_8['avg_rss13'].min(),'Max3': data_sitting_training_8['avg_rss13'].max(),'Mean3': data_sitting_training_8['avg_rss13'].mean(),'Median3': data_sitting_training_8['avg_rss13'].median(),'SD3': data_sitting_training_8['avg_rss13'].std(),'1st Quartile3': data_sitting_training_8['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_8['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_8['var_rss13'].min(),'Max4': data_sitting_training_8['var_rss13'].max(),'Mean4': data_sitting_training_8['var_rss13'].mean(),'Median4': data_sitting_training_8['var_rss13'].median(),'SD4': data_sitting_training_8['var_rss13'].std(),'1st Quartile4': data_sitting_training_8['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_8['var_rss13'].quantile(0.75),'Min5': data_sitting_training_8['avg_rss23'].min(),'Max5': data_sitting_training_8['avg_rss23'].max(),'Mean5': data_sitting_training_8['avg_rss23'].mean(),'Median5': data_sitting_training_8['avg_rss23'].median(),'SD5': data_sitting_training_8['avg_rss23'].std(),'1st Quartile5': data_sitting_training_8['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_8['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_8['var_rss23'].min(),'Max6': data_sitting_training_8['var_rss23'].max(),'Mean6': data_sitting_training_8['var_rss23'].mean(),'Median6': data_sitting_training_8['var_rss23'].median(),'SD6': data_sitting_training_8['var_rss23'].std(),'1st Quartile6': data_sitting_training_8['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_8['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'61','Min1':data_sitting_training_9['avg_rss12'].min(),'Max1': data_sitting_training_9['avg_rss12'].max(),'Mean1': data_sitting_training_9['avg_rss12'].mean(),'Median1': data_sitting_training_9['avg_rss12'].median(),'SD1': data_sitting_training_9['avg_rss12'].std(),'1st Quartile1': data_sitting_training_9['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_9['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_9['var_rss12'].min(),'Max2': data_sitting_training_9['var_rss12'].max(),'Mean2': data_sitting_training_9['var_rss12'].mean(),'Median2': data_sitting_training_9['var_rss12'].median(),'SD2': data_sitting_training_9['var_rss12'].std(),'1st Quartile2': data_sitting_training_9['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_9['var_rss12'].quantile(0.75),'Min3': data_sitting_training_9['avg_rss13'].min(),'Max3': data_sitting_training_9['avg_rss13'].max(),'Mean3': data_sitting_training_9['avg_rss13'].mean(),'Median3': data_sitting_training_9['avg_rss13'].median(),'SD3': data_sitting_training_9['avg_rss13'].std(),'1st Quartile3': data_sitting_training_9['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_9['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_9['var_rss13'].min(),'Max4': data_sitting_training_9['var_rss13'].max(),'Mean4': data_sitting_training_9['var_rss13'].mean(),'Median4': data_sitting_training_9['var_rss13'].median(),'SD4': data_sitting_training_9['var_rss13'].std(),'1st Quartile4': data_sitting_training_9['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_9['var_rss13'].quantile(0.75),'Min5': data_sitting_training_9['avg_rss23'].min(),'Max5': data_sitting_training_9['avg_rss23'].max(),'Mean5': data_sitting_training_9['avg_rss23'].mean(),'Median5': data_sitting_training_9['avg_rss23'].median(),'SD5': data_sitting_training_9['avg_rss23'].std(),'1st Quartile5': data_sitting_training_9['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_9['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_9['var_rss23'].min(),'Max6': data_sitting_training_9['var_rss23'].max(),'Mean6': data_sitting_training_9['var_rss23'].mean(),'Median6': data_sitting_training_9['var_rss23'].median(),'SD6': data_sitting_training_9['var_rss23'].std(),'1st Quartile6': data_sitting_training_9['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_9['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'62','Min1':data_sitting_training_10['avg_rss12'].min(),'Max1': data_sitting_training_10['avg_rss12'].max(),'Mean1': data_sitting_training_10['avg_rss12'].mean(),'Median1': data_sitting_training_10['avg_rss12'].median(),'SD1': data_sitting_training_10['avg_rss12'].std(),'1st Quartile1': data_sitting_training_10['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_10['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_10['var_rss12'].min(),'Max2': data_sitting_training_10['var_rss12'].max(),'Mean2': data_sitting_training_10['var_rss12'].mean(),'Median2': data_sitting_training_10['var_rss12'].median(),'SD2': data_sitting_training_10['var_rss12'].std(),'1st Quartile2': data_sitting_training_10['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_10['var_rss12'].quantile(0.75),'Min3': data_sitting_training_10['avg_rss13'].min(),'Max3': data_sitting_training_10['avg_rss13'].max(),'Mean3': data_sitting_training_10['avg_rss13'].mean(),'Median3': data_sitting_training_10['avg_rss13'].median(),'SD3': data_sitting_training_10['avg_rss13'].std(),'1st Quartile3': data_sitting_training_10['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_10['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_10['var_rss13'].min(),'Max4': data_sitting_training_10['var_rss13'].max(),'Mean4': data_sitting_training_10['var_rss13'].mean(),'Median4': data_sitting_training_10['var_rss13'].median(),'SD4': data_sitting_training_10['var_rss13'].std(),'1st Quartile4': data_sitting_training_10['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_10['var_rss13'].quantile(0.75),'Min5': data_sitting_training_10['avg_rss23'].min(),'Max5': data_sitting_training_10['avg_rss23'].max(),'Mean5': data_sitting_training_10['avg_rss23'].mean(),'Median5': data_sitting_training_10['avg_rss23'].median(),'SD5': data_sitting_training_10['avg_rss23'].std(),'1st Quartile5': data_sitting_training_10['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_10['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_10['var_rss23'].min(),'Max6': data_sitting_training_10['var_rss23'].max(),'Mean6': data_sitting_training_10['var_rss23'].mean(),'Median6': data_sitting_training_10['var_rss23'].median(),'SD6': data_sitting_training_10['var_rss23'].std(),'1st Quartile6': data_sitting_training_10['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_10['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'63','Min1':data_sitting_training_11['avg_rss12'].min(),'Max1': data_sitting_training_11['avg_rss12'].max(),'Mean1': data_sitting_training_11['avg_rss12'].mean(),'Median1': data_sitting_training_11['avg_rss12'].median(),'SD1': data_sitting_training_11['avg_rss12'].std(),'1st Quartile1': data_sitting_training_11['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_11['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_11['var_rss12'].min(),'Max2': data_sitting_training_11['var_rss12'].max(),'Mean2': data_sitting_training_11['var_rss12'].mean(),'Median2': data_sitting_training_11['var_rss12'].median(),'SD2': data_sitting_training_11['var_rss12'].std(),'1st Quartile2': data_sitting_training_11['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_11['var_rss12'].quantile(0.75),'Min3': data_sitting_training_11['avg_rss13'].min(),'Max3': data_sitting_training_11['avg_rss13'].max(),'Mean3': data_sitting_training_11['avg_rss13'].mean(),'Median3': data_sitting_training_11['avg_rss13'].median(),'SD3': data_sitting_training_11['avg_rss13'].std(),'1st Quartile3': data_sitting_training_11['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_11['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_11['var_rss13'].min(),'Max4': data_sitting_training_11['var_rss13'].max(),'Mean4': data_sitting_training_11['var_rss13'].mean(),'Median4': data_sitting_training_11['var_rss13'].median(),'SD4': data_sitting_training_11['var_rss13'].std(),'1st Quartile4': data_sitting_training_11['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_11['var_rss13'].quantile(0.75),'Min5': data_sitting_training_11['avg_rss23'].min(),'Max5': data_sitting_training_11['avg_rss23'].max(),'Mean5': data_sitting_training_11['avg_rss23'].mean(),'Median5': data_sitting_training_11['avg_rss23'].median(),'SD5': data_sitting_training_11['avg_rss23'].std(),'1st Quartile5': data_sitting_training_11['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_11['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_11['var_rss23'].min(),'Max6': data_sitting_training_11['var_rss23'].max(),'Mean6': data_sitting_training_11['var_rss23'].mean(),'Median6': data_sitting_training_11['var_rss23'].median(),'SD6': data_sitting_training_11['var_rss23'].std(),'1st Quartile6': data_sitting_training_11['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_11['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'64','Min1':data_sitting_training_12['avg_rss12'].min(),'Max1': data_sitting_training_12['avg_rss12'].max(),'Mean1': data_sitting_training_12['avg_rss12'].mean(),'Median1': data_sitting_training_12['avg_rss12'].median(),'SD1': data_sitting_training_12['avg_rss12'].std(),'1st Quartile1': data_sitting_training_12['avg_rss12'].quantile(0.25),'3rd Quartile1': data_sitting_training_12['avg_rss12'].quantile(0.75),'Min2': data_sitting_training_12['var_rss12'].min(),'Max2': data_sitting_training_12['var_rss12'].max(),'Mean2': data_sitting_training_12['var_rss12'].mean(),'Median2': data_sitting_training_12['var_rss12'].median(),'SD2': data_sitting_training_12['var_rss12'].std(),'1st Quartile2': data_sitting_training_12['var_rss12'].quantile(0.25),'3rd Quartile2': data_sitting_training_12['var_rss12'].quantile(0.75),'Min3': data_sitting_training_12['avg_rss13'].min(),'Max3': data_sitting_training_12['avg_rss13'].max(),'Mean3': data_sitting_training_12['avg_rss13'].mean(),'Median3': data_sitting_training_12['avg_rss13'].median(),'SD3': data_sitting_training_12['avg_rss13'].std(),'1st Quartile3': data_sitting_training_12['avg_rss13'].quantile(0.25),'3rd Quartile3': data_sitting_training_12['avg_rss13'].quantile(0.75),'Min4': data_sitting_training_12['var_rss13'].min(),'Max4': data_sitting_training_12['var_rss13'].max(),'Mean4': data_sitting_training_12['var_rss13'].mean(),'Median4': data_sitting_training_12['var_rss13'].median(),'SD4': data_sitting_training_12['var_rss13'].std(),'1st Quartile4': data_sitting_training_12['var_rss13'].quantile(0.25),'3rd Quartile4': data_sitting_training_12['var_rss13'].quantile(0.75),'Min5': data_sitting_training_12['avg_rss23'].min(),'Max5': data_sitting_training_12['avg_rss23'].max(),'Mean5': data_sitting_training_12['avg_rss23'].mean(),'Median5': data_sitting_training_12['avg_rss23'].median(),'SD5': data_sitting_training_12['avg_rss23'].std(),'1st Quartile5': data_sitting_training_12['avg_rss23'].quantile(0.25),'3rd Quartile5': data_sitting_training_12['avg_rss23'].quantile(0.75),'Min6': data_sitting_training_12['var_rss23'].min(),'Max6': data_sitting_training_12['var_rss23'].max(),'Mean6': data_sitting_training_12['var_rss23'].mean(),'Median6': data_sitting_training_12['var_rss23'].median(),'SD6': data_sitting_training_12['var_rss23'].std(),'1st Quartile6': data_sitting_training_12['var_rss23'].quantile(0.25),'3rd Quartile6': data_sitting_training_12['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'65','Min1':data_standing_training_1['avg_rss12'].min(),'Max1': data_standing_training_1['avg_rss12'].max(),'Mean1': data_standing_training_1['avg_rss12'].mean(),'Median1': data_standing_training_1['avg_rss12'].median(),'SD1': data_standing_training_1['avg_rss12'].std(),'1st Quartile1': data_standing_training_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_1['avg_rss12'].quantile(0.75),'Min2': data_standing_training_1['var_rss12'].min(),'Max2': data_standing_training_1['var_rss12'].max(),'Mean2': data_standing_training_1['var_rss12'].mean(),'Median2': data_standing_training_1['var_rss12'].median(),'SD2': data_standing_training_1['var_rss12'].std(),'1st Quartile2': data_standing_training_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_1['var_rss12'].quantile(0.75),'Min3': data_standing_training_1['avg_rss13'].min(),'Max3': data_standing_training_1['avg_rss13'].max(),'Mean3': data_standing_training_1['avg_rss13'].mean(),'Median3': data_standing_training_1['avg_rss13'].median(),'SD3': data_standing_training_1['avg_rss13'].std(),'1st Quartile3': data_standing_training_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_1['avg_rss13'].quantile(0.75),'Min4': data_standing_training_1['var_rss13'].min(),'Max4': data_standing_training_1['var_rss13'].max(),'Mean4': data_standing_training_1['var_rss13'].mean(),'Median4': data_standing_training_1['var_rss13'].median(),'SD4': data_standing_training_1['var_rss13'].std(),'1st Quartile4': data_standing_training_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_1['var_rss13'].quantile(0.75),'Min5': data_standing_training_1['avg_rss23'].min(),'Max5': data_standing_training_1['avg_rss23'].max(),'Mean5': data_standing_training_1['avg_rss23'].mean(),'Median5': data_standing_training_1['avg_rss23'].median(),'SD5': data_standing_training_1['avg_rss23'].std(),'1st Quartile5': data_standing_training_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_1['avg_rss23'].quantile(0.75),'Min6': data_standing_training_1['var_rss23'].min(),'Max6': data_standing_training_1['var_rss23'].max(),'Mean6': data_standing_training_1['var_rss23'].mean(),'Median6': data_standing_training_1['var_rss23'].median(),'SD6': data_standing_training_1['var_rss23'].std(),'1st Quartile6': data_standing_training_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'66','Min1':data_standing_training_2['avg_rss12'].min(),'Max1': data_standing_training_2['avg_rss12'].max(),'Mean1': data_standing_training_2['avg_rss12'].mean(),'Median1': data_standing_training_2['avg_rss12'].median(),'SD1': data_standing_training_2['avg_rss12'].std(),'1st Quartile1': data_standing_training_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_2['avg_rss12'].quantile(0.75),'Min2': data_standing_training_2['var_rss12'].min(),'Max2': data_standing_training_2['var_rss12'].max(),'Mean2': data_standing_training_2['var_rss12'].mean(),'Median2': data_standing_training_2['var_rss12'].median(),'SD2': data_standing_training_2['var_rss12'].std(),'1st Quartile2': data_standing_training_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_2['var_rss12'].quantile(0.75),'Min3': data_standing_training_2['avg_rss13'].min(),'Max3': data_standing_training_2['avg_rss13'].max(),'Mean3': data_standing_training_2['avg_rss13'].mean(),'Median3': data_standing_training_2['avg_rss13'].median(),'SD3': data_standing_training_2['avg_rss13'].std(),'1st Quartile3': data_standing_training_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_2['avg_rss13'].quantile(0.75),'Min4': data_standing_training_2['var_rss13'].min(),'Max4': data_standing_training_2['var_rss13'].max(),'Mean4': data_standing_training_2['var_rss13'].mean(),'Median4': data_standing_training_2['var_rss13'].median(),'SD4': data_standing_training_2['var_rss13'].std(),'1st Quartile4': data_standing_training_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_2['var_rss13'].quantile(0.75),'Min5': data_standing_training_2['avg_rss23'].min(),'Max5': data_standing_training_2['avg_rss23'].max(),'Mean5': data_standing_training_2['avg_rss23'].mean(),'Median5': data_standing_training_2['avg_rss23'].median(),'SD5': data_standing_training_2['avg_rss23'].std(),'1st Quartile5': data_standing_training_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_2['avg_rss23'].quantile(0.75),'Min6': data_standing_training_2['var_rss23'].min(),'Max6': data_standing_training_2['var_rss23'].max(),'Mean6': data_standing_training_2['var_rss23'].mean(),'Median6': data_standing_training_2['var_rss23'].median(),'SD6': data_standing_training_2['var_rss23'].std(),'1st Quartile6': data_standing_training_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'67','Min1':data_standing_training_3['avg_rss12'].min(),'Max1': data_standing_training_3['avg_rss12'].max(),'Mean1': data_standing_training_3['avg_rss12'].mean(),'Median1': data_standing_training_3['avg_rss12'].median(),'SD1': data_standing_training_3['avg_rss12'].std(),'1st Quartile1': data_standing_training_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_3['avg_rss12'].quantile(0.75),'Min2': data_standing_training_3['var_rss12'].min(),'Max2': data_standing_training_3['var_rss12'].max(),'Mean2': data_standing_training_3['var_rss12'].mean(),'Median2': data_standing_training_3['var_rss12'].median(),'SD2': data_standing_training_3['var_rss12'].std(),'1st Quartile2': data_standing_training_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_3['var_rss12'].quantile(0.75),'Min3': data_standing_training_3['avg_rss13'].min(),'Max3': data_standing_training_3['avg_rss13'].max(),'Mean3': data_standing_training_3['avg_rss13'].mean(),'Median3': data_standing_training_3['avg_rss13'].median(),'SD3': data_standing_training_3['avg_rss13'].std(),'1st Quartile3': data_standing_training_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_3['avg_rss13'].quantile(0.75),'Min4': data_standing_training_3['var_rss13'].min(),'Max4': data_standing_training_3['var_rss13'].max(),'Mean4': data_standing_training_3['var_rss13'].mean(),'Median4': data_standing_training_3['var_rss13'].median(),'SD4': data_standing_training_3['var_rss13'].std(),'1st Quartile4': data_standing_training_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_3['var_rss13'].quantile(0.75),'Min5': data_standing_training_3['avg_rss23'].min(),'Max5': data_standing_training_3['avg_rss23'].max(),'Mean5': data_standing_training_3['avg_rss23'].mean(),'Median5': data_standing_training_3['avg_rss23'].median(),'SD5': data_standing_training_3['avg_rss23'].std(),'1st Quartile5': data_standing_training_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_3['avg_rss23'].quantile(0.75),'Min6': data_standing_training_3['var_rss23'].min(),'Max6': data_standing_training_3['var_rss23'].max(),'Mean6': data_standing_training_3['var_rss23'].mean(),'Median6': data_standing_training_3['var_rss23'].median(),'SD6': data_standing_training_3['var_rss23'].std(),'1st Quartile6': data_standing_training_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'68','Min1':data_standing_training_4['avg_rss12'].min(),'Max1': data_standing_training_4['avg_rss12'].max(),'Mean1': data_standing_training_4['avg_rss12'].mean(),'Median1': data_standing_training_4['avg_rss12'].median(),'SD1': data_standing_training_4['avg_rss12'].std(),'1st Quartile1': data_standing_training_4['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_4['avg_rss12'].quantile(0.75),'Min2': data_standing_training_4['var_rss12'].min(),'Max2': data_standing_training_4['var_rss12'].max(),'Mean2': data_standing_training_4['var_rss12'].mean(),'Median2': data_standing_training_4['var_rss12'].median(),'SD2': data_standing_training_4['var_rss12'].std(),'1st Quartile2': data_standing_training_4['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_4['var_rss12'].quantile(0.75),'Min3': data_standing_training_4['avg_rss13'].min(),'Max3': data_standing_training_4['avg_rss13'].max(),'Mean3': data_standing_training_4['avg_rss13'].mean(),'Median3': data_standing_training_4['avg_rss13'].median(),'SD3': data_standing_training_4['avg_rss13'].std(),'1st Quartile3': data_standing_training_4['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_4['avg_rss13'].quantile(0.75),'Min4': data_standing_training_4['var_rss13'].min(),'Max4': data_standing_training_4['var_rss13'].max(),'Mean4': data_standing_training_4['var_rss13'].mean(),'Median4': data_standing_training_4['var_rss13'].median(),'SD4': data_standing_training_4['var_rss13'].std(),'1st Quartile4': data_standing_training_4['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_4['var_rss13'].quantile(0.75),'Min5': data_standing_training_4['avg_rss23'].min(),'Max5': data_standing_training_4['avg_rss23'].max(),'Mean5': data_standing_training_4['avg_rss23'].mean(),'Median5': data_standing_training_4['avg_rss23'].median(),'SD5': data_standing_training_4['avg_rss23'].std(),'1st Quartile5': data_standing_training_4['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_4['avg_rss23'].quantile(0.75),'Min6': data_standing_training_4['var_rss23'].min(),'Max6': data_standing_training_4['var_rss23'].max(),'Mean6': data_standing_training_4['var_rss23'].mean(),'Median6': data_standing_training_4['var_rss23'].median(),'SD6': data_standing_training_4['var_rss23'].std(),'1st Quartile6': data_standing_training_4['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_4['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'69','Min1':data_standing_training_5['avg_rss12'].min(),'Max1': data_standing_training_5['avg_rss12'].max(),'Mean1': data_standing_training_5['avg_rss12'].mean(),'Median1': data_standing_training_5['avg_rss12'].median(),'SD1': data_standing_training_5['avg_rss12'].std(),'1st Quartile1': data_standing_training_5['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_5['avg_rss12'].quantile(0.75),'Min2': data_standing_training_5['var_rss12'].min(),'Max2': data_standing_training_5['var_rss12'].max(),'Mean2': data_standing_training_5['var_rss12'].mean(),'Median2': data_standing_training_5['var_rss12'].median(),'SD2': data_standing_training_5['var_rss12'].std(),'1st Quartile2': data_standing_training_5['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_5['var_rss12'].quantile(0.75),'Min3': data_standing_training_5['avg_rss13'].min(),'Max3': data_standing_training_5['avg_rss13'].max(),'Mean3': data_standing_training_5['avg_rss13'].mean(),'Median3': data_standing_training_5['avg_rss13'].median(),'SD3': data_standing_training_5['avg_rss13'].std(),'1st Quartile3': data_standing_training_5['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_5['avg_rss13'].quantile(0.75),'Min4': data_standing_training_5['var_rss13'].min(),'Max4': data_standing_training_5['var_rss13'].max(),'Mean4': data_standing_training_5['var_rss13'].mean(),'Median4': data_standing_training_5['var_rss13'].median(),'SD4': data_standing_training_5['var_rss13'].std(),'1st Quartile4': data_standing_training_5['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_5['var_rss13'].quantile(0.75),'Min5': data_standing_training_5['avg_rss23'].min(),'Max5': data_standing_training_5['avg_rss23'].max(),'Mean5': data_standing_training_5['avg_rss23'].mean(),'Median5': data_standing_training_5['avg_rss23'].median(),'SD5': data_standing_training_5['avg_rss23'].std(),'1st Quartile5': data_standing_training_5['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_5['avg_rss23'].quantile(0.75),'Min6': data_standing_training_5['var_rss23'].min(),'Max6': data_standing_training_5['var_rss23'].max(),'Mean6': data_standing_training_5['var_rss23'].mean(),'Median6': data_standing_training_5['var_rss23'].median(),'SD6': data_standing_training_5['var_rss23'].std(),'1st Quartile6': data_standing_training_5['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_5['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'70','Min1':data_standing_training_6['avg_rss12'].min(),'Max1': data_standing_training_6['avg_rss12'].max(),'Mean1': data_standing_training_6['avg_rss12'].mean(),'Median1': data_standing_training_6['avg_rss12'].median(),'SD1': data_standing_training_6['avg_rss12'].std(),'1st Quartile1': data_standing_training_6['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_6['avg_rss12'].quantile(0.75),'Min2': data_standing_training_6['var_rss12'].min(),'Max2': data_standing_training_6['var_rss12'].max(),'Mean2': data_standing_training_6['var_rss12'].mean(),'Median2': data_standing_training_6['var_rss12'].median(),'SD2': data_standing_training_6['var_rss12'].std(),'1st Quartile2': data_standing_training_6['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_6['var_rss12'].quantile(0.75),'Min3': data_standing_training_6['avg_rss13'].min(),'Max3': data_standing_training_6['avg_rss13'].max(),'Mean3': data_standing_training_6['avg_rss13'].mean(),'Median3': data_standing_training_6['avg_rss13'].median(),'SD3': data_standing_training_6['avg_rss13'].std(),'1st Quartile3': data_standing_training_6['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_6['avg_rss13'].quantile(0.75),'Min4': data_standing_training_6['var_rss13'].min(),'Max4': data_standing_training_6['var_rss13'].max(),'Mean4': data_standing_training_6['var_rss13'].mean(),'Median4': data_standing_training_6['var_rss13'].median(),'SD4': data_standing_training_6['var_rss13'].std(),'1st Quartile4': data_standing_training_6['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_6['var_rss13'].quantile(0.75),'Min5': data_standing_training_6['avg_rss23'].min(),'Max5': data_standing_training_6['avg_rss23'].max(),'Mean5': data_standing_training_6['avg_rss23'].mean(),'Median5': data_standing_training_6['avg_rss23'].median(),'SD5': data_standing_training_6['avg_rss23'].std(),'1st Quartile5': data_standing_training_6['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_6['avg_rss23'].quantile(0.75),'Min6': data_standing_training_6['var_rss23'].min(),'Max6': data_standing_training_6['var_rss23'].max(),'Mean6': data_standing_training_6['var_rss23'].mean(),'Median6': data_standing_training_6['var_rss23'].median(),'SD6': data_standing_training_6['var_rss23'].std(),'1st Quartile6': data_standing_training_6['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_6['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'71','Min1':data_standing_training_7['avg_rss12'].min(),'Max1': data_standing_training_7['avg_rss12'].max(),'Mean1': data_standing_training_7['avg_rss12'].mean(),'Median1': data_standing_training_7['avg_rss12'].median(),'SD1': data_standing_training_7['avg_rss12'].std(),'1st Quartile1': data_standing_training_7['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_7['avg_rss12'].quantile(0.75),'Min2': data_standing_training_7['var_rss12'].min(),'Max2': data_standing_training_7['var_rss12'].max(),'Mean2': data_standing_training_7['var_rss12'].mean(),'Median2': data_standing_training_7['var_rss12'].median(),'SD2': data_standing_training_7['var_rss12'].std(),'1st Quartile2': data_standing_training_7['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_7['var_rss12'].quantile(0.75),'Min3': data_standing_training_7['avg_rss13'].min(),'Max3': data_standing_training_7['avg_rss13'].max(),'Mean3': data_standing_training_7['avg_rss13'].mean(),'Median3': data_standing_training_7['avg_rss13'].median(),'SD3': data_standing_training_7['avg_rss13'].std(),'1st Quartile3': data_standing_training_7['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_7['avg_rss13'].quantile(0.75),'Min4': data_standing_training_7['var_rss13'].min(),'Max4': data_standing_training_7['var_rss13'].max(),'Mean4': data_standing_training_7['var_rss13'].mean(),'Median4': data_standing_training_7['var_rss13'].median(),'SD4': data_standing_training_7['var_rss13'].std(),'1st Quartile4': data_standing_training_7['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_7['var_rss13'].quantile(0.75),'Min5': data_standing_training_7['avg_rss23'].min(),'Max5': data_standing_training_7['avg_rss23'].max(),'Mean5': data_standing_training_7['avg_rss23'].mean(),'Median5': data_standing_training_7['avg_rss23'].median(),'SD5': data_standing_training_7['avg_rss23'].std(),'1st Quartile5': data_standing_training_7['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_7['avg_rss23'].quantile(0.75),'Min6': data_standing_training_7['var_rss23'].min(),'Max6': data_standing_training_7['var_rss23'].max(),'Mean6': data_standing_training_7['var_rss23'].mean(),'Median6': data_standing_training_7['var_rss23'].median(),'SD6': data_standing_training_7['var_rss23'].std(),'1st Quartile6': data_standing_training_7['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_7['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'72','Min1':data_standing_training_8['avg_rss12'].min(),'Max1': data_standing_training_8['avg_rss12'].max(),'Mean1': data_standing_training_8['avg_rss12'].mean(),'Median1': data_standing_training_8['avg_rss12'].median(),'SD1': data_standing_training_8['avg_rss12'].std(),'1st Quartile1': data_standing_training_8['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_8['avg_rss12'].quantile(0.75),'Min2': data_standing_training_8['var_rss12'].min(),'Max2': data_standing_training_8['var_rss12'].max(),'Mean2': data_standing_training_8['var_rss12'].mean(),'Median2': data_standing_training_8['var_rss12'].median(),'SD2': data_standing_training_8['var_rss12'].std(),'1st Quartile2': data_standing_training_8['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_8['var_rss12'].quantile(0.75),'Min3': data_standing_training_8['avg_rss13'].min(),'Max3': data_standing_training_8['avg_rss13'].max(),'Mean3': data_standing_training_8['avg_rss13'].mean(),'Median3': data_standing_training_8['avg_rss13'].median(),'SD3': data_standing_training_8['avg_rss13'].std(),'1st Quartile3': data_standing_training_8['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_8['avg_rss13'].quantile(0.75),'Min4': data_standing_training_8['var_rss13'].min(),'Max4': data_standing_training_8['var_rss13'].max(),'Mean4': data_standing_training_8['var_rss13'].mean(),'Median4': data_standing_training_8['var_rss13'].median(),'SD4': data_standing_training_8['var_rss13'].std(),'1st Quartile4': data_standing_training_8['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_8['var_rss13'].quantile(0.75),'Min5': data_standing_training_8['avg_rss23'].min(),'Max5': data_standing_training_8['avg_rss23'].max(),'Mean5': data_standing_training_8['avg_rss23'].mean(),'Median5': data_standing_training_8['avg_rss23'].median(),'SD5': data_standing_training_8['avg_rss23'].std(),'1st Quartile5': data_standing_training_8['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_8['avg_rss23'].quantile(0.75),'Min6': data_standing_training_8['var_rss23'].min(),'Max6': data_standing_training_8['var_rss23'].max(),'Mean6': data_standing_training_8['var_rss23'].mean(),'Median6': data_standing_training_8['var_rss23'].median(),'SD6': data_standing_training_8['var_rss23'].std(),'1st Quartile6': data_standing_training_8['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_8['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'73','Min1':data_standing_training_9['avg_rss12'].min(),'Max1': data_standing_training_9['avg_rss12'].max(),'Mean1': data_standing_training_9['avg_rss12'].mean(),'Median1': data_standing_training_9['avg_rss12'].median(),'SD1': data_standing_training_9['avg_rss12'].std(),'1st Quartile1': data_standing_training_9['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_9['avg_rss12'].quantile(0.75),'Min2': data_standing_training_9['var_rss12'].min(),'Max2': data_standing_training_9['var_rss12'].max(),'Mean2': data_standing_training_9['var_rss12'].mean(),'Median2': data_standing_training_9['var_rss12'].median(),'SD2': data_standing_training_9['var_rss12'].std(),'1st Quartile2': data_standing_training_9['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_9['var_rss12'].quantile(0.75),'Min3': data_standing_training_9['avg_rss13'].min(),'Max3': data_standing_training_9['avg_rss13'].max(),'Mean3': data_standing_training_9['avg_rss13'].mean(),'Median3': data_standing_training_9['avg_rss13'].median(),'SD3': data_standing_training_9['avg_rss13'].std(),'1st Quartile3': data_standing_training_9['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_9['avg_rss13'].quantile(0.75),'Min4': data_standing_training_9['var_rss13'].min(),'Max4': data_standing_training_9['var_rss13'].max(),'Mean4': data_standing_training_9['var_rss13'].mean(),'Median4': data_standing_training_9['var_rss13'].median(),'SD4': data_standing_training_9['var_rss13'].std(),'1st Quartile4': data_standing_training_9['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_9['var_rss13'].quantile(0.75),'Min5': data_standing_training_9['avg_rss23'].min(),'Max5': data_standing_training_9['avg_rss23'].max(),'Mean5': data_standing_training_9['avg_rss23'].mean(),'Median5': data_standing_training_9['avg_rss23'].median(),'SD5': data_standing_training_9['avg_rss23'].std(),'1st Quartile5': data_standing_training_9['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_9['avg_rss23'].quantile(0.75),'Min6': data_standing_training_9['var_rss23'].min(),'Max6': data_standing_training_9['var_rss23'].max(),'Mean6': data_standing_training_9['var_rss23'].mean(),'Median6': data_standing_training_9['var_rss23'].median(),'SD6': data_standing_training_9['var_rss23'].std(),'1st Quartile6': data_standing_training_9['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_9['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'74','Min1':data_standing_training_10['avg_rss12'].min(),'Max1': data_standing_training_10['avg_rss12'].max(),'Mean1': data_standing_training_10['avg_rss12'].mean(),'Median1': data_standing_training_10['avg_rss12'].median(),'SD1': data_standing_training_10['avg_rss12'].std(),'1st Quartile1': data_standing_training_10['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_10['avg_rss12'].quantile(0.75),'Min2': data_standing_training_10['var_rss12'].min(),'Max2': data_standing_training_10['var_rss12'].max(),'Mean2': data_standing_training_10['var_rss12'].mean(),'Median2': data_standing_training_10['var_rss12'].median(),'SD2': data_standing_training_10['var_rss12'].std(),'1st Quartile2': data_standing_training_10['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_10['var_rss12'].quantile(0.75),'Min3': data_standing_training_10['avg_rss13'].min(),'Max3': data_standing_training_10['avg_rss13'].max(),'Mean3': data_standing_training_10['avg_rss13'].mean(),'Median3': data_standing_training_10['avg_rss13'].median(),'SD3': data_standing_training_10['avg_rss13'].std(),'1st Quartile3': data_standing_training_10['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_10['avg_rss13'].quantile(0.75),'Min4': data_standing_training_10['var_rss13'].min(),'Max4': data_standing_training_10['var_rss13'].max(),'Mean4': data_standing_training_10['var_rss13'].mean(),'Median4': data_standing_training_10['var_rss13'].median(),'SD4': data_standing_training_10['var_rss13'].std(),'1st Quartile4': data_standing_training_10['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_10['var_rss13'].quantile(0.75),'Min5': data_standing_training_10['avg_rss23'].min(),'Max5': data_standing_training_10['avg_rss23'].max(),'Mean5': data_standing_training_10['avg_rss23'].mean(),'Median5': data_standing_training_10['avg_rss23'].median(),'SD5': data_standing_training_10['avg_rss23'].std(),'1st Quartile5': data_standing_training_10['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_10['avg_rss23'].quantile(0.75),'Min6': data_standing_training_10['var_rss23'].min(),'Max6': data_standing_training_10['var_rss23'].max(),'Mean6': data_standing_training_10['var_rss23'].mean(),'Median6': data_standing_training_10['var_rss23'].median(),'SD6': data_standing_training_10['var_rss23'].std(),'1st Quartile6': data_standing_training_10['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_10['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'75','Min1':data_standing_training_11['avg_rss12'].min(),'Max1': data_standing_training_11['avg_rss12'].max(),'Mean1': data_standing_training_11['avg_rss12'].mean(),'Median1': data_standing_training_11['avg_rss12'].median(),'SD1': data_standing_training_11['avg_rss12'].std(),'1st Quartile1': data_standing_training_11['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_11['avg_rss12'].quantile(0.75),'Min2': data_standing_training_11['var_rss12'].min(),'Max2': data_standing_training_11['var_rss12'].max(),'Mean2': data_standing_training_11['var_rss12'].mean(),'Median2': data_standing_training_11['var_rss12'].median(),'SD2': data_standing_training_11['var_rss12'].std(),'1st Quartile2': data_standing_training_11['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_11['var_rss12'].quantile(0.75),'Min3': data_standing_training_11['avg_rss13'].min(),'Max3': data_standing_training_11['avg_rss13'].max(),'Mean3': data_standing_training_11['avg_rss13'].mean(),'Median3': data_standing_training_11['avg_rss13'].median(),'SD3': data_standing_training_11['avg_rss13'].std(),'1st Quartile3': data_standing_training_11['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_11['avg_rss13'].quantile(0.75),'Min4': data_standing_training_11['var_rss13'].min(),'Max4': data_standing_training_11['var_rss13'].max(),'Mean4': data_standing_training_11['var_rss13'].mean(),'Median4': data_standing_training_11['var_rss13'].median(),'SD4': data_standing_training_11['var_rss13'].std(),'1st Quartile4': data_standing_training_11['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_11['var_rss13'].quantile(0.75),'Min5': data_standing_training_11['avg_rss23'].min(),'Max5': data_standing_training_11['avg_rss23'].max(),'Mean5': data_standing_training_11['avg_rss23'].mean(),'Median5': data_standing_training_11['avg_rss23'].median(),'SD5': data_standing_training_11['avg_rss23'].std(),'1st Quartile5': data_standing_training_11['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_11['avg_rss23'].quantile(0.75),'Min6': data_standing_training_11['var_rss23'].min(),'Max6': data_standing_training_11['var_rss23'].max(),'Mean6': data_standing_training_11['var_rss23'].mean(),'Median6': data_standing_training_11['var_rss23'].median(),'SD6': data_standing_training_11['var_rss23'].std(),'1st Quartile6': data_standing_training_11['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_11['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'76','Min1':data_standing_training_12['avg_rss12'].min(),'Max1': data_standing_training_12['avg_rss12'].max(),'Mean1': data_standing_training_12['avg_rss12'].mean(),'Median1': data_standing_training_12['avg_rss12'].median(),'SD1': data_standing_training_12['avg_rss12'].std(),'1st Quartile1': data_standing_training_12['avg_rss12'].quantile(0.25),'3rd Quartile1': data_standing_training_12['avg_rss12'].quantile(0.75),'Min2': data_standing_training_12['var_rss12'].min(),'Max2': data_standing_training_12['var_rss12'].max(),'Mean2': data_standing_training_12['var_rss12'].mean(),'Median2': data_standing_training_12['var_rss12'].median(),'SD2': data_standing_training_12['var_rss12'].std(),'1st Quartile2': data_standing_training_12['var_rss12'].quantile(0.25),'3rd Quartile2': data_standing_training_12['var_rss12'].quantile(0.75),'Min3': data_standing_training_12['avg_rss13'].min(),'Max3': data_standing_training_12['avg_rss13'].max(),'Mean3': data_standing_training_12['avg_rss13'].mean(),'Median3': data_standing_training_12['avg_rss13'].median(),'SD3': data_standing_training_12['avg_rss13'].std(),'1st Quartile3': data_standing_training_12['avg_rss13'].quantile(0.25),'3rd Quartile3': data_standing_training_12['avg_rss13'].quantile(0.75),'Min4': data_standing_training_12['var_rss13'].min(),'Max4': data_standing_training_12['var_rss13'].max(),'Mean4': data_standing_training_12['var_rss13'].mean(),'Median4': data_standing_training_12['var_rss13'].median(),'SD4': data_standing_training_12['var_rss13'].std(),'1st Quartile4': data_standing_training_12['var_rss13'].quantile(0.25),'3rd Quartile4': data_standing_training_12['var_rss13'].quantile(0.75),'Min5': data_standing_training_12['avg_rss23'].min(),'Max5': data_standing_training_12['avg_rss23'].max(),'Mean5': data_standing_training_12['avg_rss23'].mean(),'Median5': data_standing_training_12['avg_rss23'].median(),'SD5': data_standing_training_12['avg_rss23'].std(),'1st Quartile5': data_standing_training_12['avg_rss23'].quantile(0.25),'3rd Quartile5': data_standing_training_12['avg_rss23'].quantile(0.75),'Min6': data_standing_training_12['var_rss23'].min(),'Max6': data_standing_training_12['var_rss23'].max(),'Mean6': data_standing_training_12['var_rss23'].mean(),'Median6': data_standing_training_12['var_rss23'].median(),'SD6': data_standing_training_12['var_rss23'].std(),'1st Quartile6': data_standing_training_12['var_rss23'].quantile(0.25),'3rd Quartile6': data_standing_training_12['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'77','Min1':data_walking_training_1['avg_rss12'].min(),'Max1': data_walking_training_1['avg_rss12'].max(),'Mean1': data_walking_training_1['avg_rss12'].mean(),'Median1': data_walking_training_1['avg_rss12'].median(),'SD1': data_walking_training_1['avg_rss12'].std(),'1st Quartile1': data_walking_training_1['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_1['avg_rss12'].quantile(0.75),'Min2': data_walking_training_1['var_rss12'].min(),'Max2': data_walking_training_1['var_rss12'].max(),'Mean2': data_walking_training_1['var_rss12'].mean(),'Median2': data_walking_training_1['var_rss12'].median(),'SD2': data_walking_training_1['var_rss12'].std(),'1st Quartile2': data_walking_training_1['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_1['var_rss12'].quantile(0.75),'Min3': data_walking_training_1['avg_rss13'].min(),'Max3': data_walking_training_1['avg_rss13'].max(),'Mean3': data_walking_training_1['avg_rss13'].mean(),'Median3': data_walking_training_1['avg_rss13'].median(),'SD3': data_walking_training_1['avg_rss13'].std(),'1st Quartile3': data_walking_training_1['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_1['avg_rss13'].quantile(0.75),'Min4': data_walking_training_1['var_rss13'].min(),'Max4': data_walking_training_1['var_rss13'].max(),'Mean4': data_walking_training_1['var_rss13'].mean(),'Median4': data_walking_training_1['var_rss13'].median(),'SD4': data_walking_training_1['var_rss13'].std(),'1st Quartile4': data_walking_training_1['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_1['var_rss13'].quantile(0.75),'Min5': data_walking_training_1['avg_rss23'].min(),'Max5': data_walking_training_1['avg_rss23'].max(),'Mean5': data_walking_training_1['avg_rss23'].mean(),'Median5': data_walking_training_1['avg_rss23'].median(),'SD5': data_walking_training_1['avg_rss23'].std(),'1st Quartile5': data_walking_training_1['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_1['avg_rss23'].quantile(0.75),'Min6': data_walking_training_1['var_rss23'].min(),'Max6': data_walking_training_1['var_rss23'].max(),'Mean6': data_walking_training_1['var_rss23'].mean(),'Median6': data_walking_training_1['var_rss23'].median(),'SD6': data_walking_training_1['var_rss23'].std(),'1st Quartile6': data_walking_training_1['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_1['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'78','Min1':data_walking_training_2['avg_rss12'].min(),'Max1': data_walking_training_2['avg_rss12'].max(),'Mean1': data_walking_training_2['avg_rss12'].mean(),'Median1': data_walking_training_2['avg_rss12'].median(),'SD1': data_walking_training_2['avg_rss12'].std(),'1st Quartile1': data_walking_training_2['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_2['avg_rss12'].quantile(0.75),'Min2': data_walking_training_2['var_rss12'].min(),'Max2': data_walking_training_2['var_rss12'].max(),'Mean2': data_walking_training_2['var_rss12'].mean(),'Median2': data_walking_training_2['var_rss12'].median(),'SD2': data_walking_training_2['var_rss12'].std(),'1st Quartile2': data_walking_training_2['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_2['var_rss12'].quantile(0.75),'Min3': data_walking_training_2['avg_rss13'].min(),'Max3': data_walking_training_2['avg_rss13'].max(),'Mean3': data_walking_training_2['avg_rss13'].mean(),'Median3': data_walking_training_2['avg_rss13'].median(),'SD3': data_walking_training_2['avg_rss13'].std(),'1st Quartile3': data_walking_training_2['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_2['avg_rss13'].quantile(0.75),'Min4': data_walking_training_2['var_rss13'].min(),'Max4': data_walking_training_2['var_rss13'].max(),'Mean4': data_walking_training_2['var_rss13'].mean(),'Median4': data_walking_training_2['var_rss13'].median(),'SD4': data_walking_training_2['var_rss13'].std(),'1st Quartile4': data_walking_training_2['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_2['var_rss13'].quantile(0.75),'Min5': data_walking_training_2['avg_rss23'].min(),'Max5': data_walking_training_2['avg_rss23'].max(),'Mean5': data_walking_training_2['avg_rss23'].mean(),'Median5': data_walking_training_2['avg_rss23'].median(),'SD5': data_walking_training_2['avg_rss23'].std(),'1st Quartile5': data_walking_training_2['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_2['avg_rss23'].quantile(0.75),'Min6': data_walking_training_2['var_rss23'].min(),'Max6': data_walking_training_2['var_rss23'].max(),'Mean6': data_walking_training_2['var_rss23'].mean(),'Median6': data_walking_training_2['var_rss23'].median(),'SD6': data_walking_training_2['var_rss23'].std(),'1st Quartile6': data_walking_training_2['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_2['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'79','Min1':data_walking_training_3['avg_rss12'].min(),'Max1': data_walking_training_3['avg_rss12'].max(),'Mean1': data_walking_training_3['avg_rss12'].mean(),'Median1': data_walking_training_3['avg_rss12'].median(),'SD1': data_walking_training_3['avg_rss12'].std(),'1st Quartile1': data_walking_training_3['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_3['avg_rss12'].quantile(0.75),'Min2': data_walking_training_3['var_rss12'].min(),'Max2': data_walking_training_3['var_rss12'].max(),'Mean2': data_walking_training_3['var_rss12'].mean(),'Median2': data_walking_training_3['var_rss12'].median(),'SD2': data_walking_training_3['var_rss12'].std(),'1st Quartile2': data_walking_training_3['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_3['var_rss12'].quantile(0.75),'Min3': data_walking_training_3['avg_rss13'].min(),'Max3': data_walking_training_3['avg_rss13'].max(),'Mean3': data_walking_training_3['avg_rss13'].mean(),'Median3': data_walking_training_3['avg_rss13'].median(),'SD3': data_walking_training_3['avg_rss13'].std(),'1st Quartile3': data_walking_training_3['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_3['avg_rss13'].quantile(0.75),'Min4': data_walking_training_3['var_rss13'].min(),'Max4': data_walking_training_3['var_rss13'].max(),'Mean4': data_walking_training_3['var_rss13'].mean(),'Median4': data_walking_training_3['var_rss13'].median(),'SD4': data_walking_training_3['var_rss13'].std(),'1st Quartile4': data_walking_training_3['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_3['var_rss13'].quantile(0.75),'Min5': data_walking_training_3['avg_rss23'].min(),'Max5': data_walking_training_3['avg_rss23'].max(),'Mean5': data_walking_training_3['avg_rss23'].mean(),'Median5': data_walking_training_3['avg_rss23'].median(),'SD5': data_walking_training_3['avg_rss23'].std(),'1st Quartile5': data_walking_training_3['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_3['avg_rss23'].quantile(0.75),'Min6': data_walking_training_3['var_rss23'].min(),'Max6': data_walking_training_3['var_rss23'].max(),'Mean6': data_walking_training_3['var_rss23'].mean(),'Median6': data_walking_training_3['var_rss23'].median(),'SD6': data_walking_training_3['var_rss23'].std(),'1st Quartile6': data_walking_training_3['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_3['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'80','Min1':data_walking_training_4['avg_rss12'].min(),'Max1': data_walking_training_4['avg_rss12'].max(),'Mean1': data_walking_training_4['avg_rss12'].mean(),'Median1': data_walking_training_4['avg_rss12'].median(),'SD1': data_walking_training_4['avg_rss12'].std(),'1st Quartile1': data_walking_training_4['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_4['avg_rss12'].quantile(0.75),'Min2': data_walking_training_4['var_rss12'].min(),'Max2': data_walking_training_4['var_rss12'].max(),'Mean2': data_walking_training_4['var_rss12'].mean(),'Median2': data_walking_training_4['var_rss12'].median(),'SD2': data_walking_training_4['var_rss12'].std(),'1st Quartile2': data_walking_training_4['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_4['var_rss12'].quantile(0.75),'Min3': data_walking_training_4['avg_rss13'].min(),'Max3': data_walking_training_4['avg_rss13'].max(),'Mean3': data_walking_training_4['avg_rss13'].mean(),'Median3': data_walking_training_4['avg_rss13'].median(),'SD3': data_walking_training_4['avg_rss13'].std(),'1st Quartile3': data_walking_training_4['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_4['avg_rss13'].quantile(0.75),'Min4': data_walking_training_4['var_rss13'].min(),'Max4': data_walking_training_4['var_rss13'].max(),'Mean4': data_walking_training_4['var_rss13'].mean(),'Median4': data_walking_training_4['var_rss13'].median(),'SD4': data_walking_training_4['var_rss13'].std(),'1st Quartile4': data_walking_training_4['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_4['var_rss13'].quantile(0.75),'Min5': data_walking_training_4['avg_rss23'].min(),'Max5': data_walking_training_4['avg_rss23'].max(),'Mean5': data_walking_training_4['avg_rss23'].mean(),'Median5': data_walking_training_4['avg_rss23'].median(),'SD5': data_walking_training_4['avg_rss23'].std(),'1st Quartile5': data_walking_training_4['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_4['avg_rss23'].quantile(0.75),'Min6': data_walking_training_4['var_rss23'].min(),'Max6': data_walking_training_4['var_rss23'].max(),'Mean6': data_walking_training_4['var_rss23'].mean(),'Median6': data_walking_training_4['var_rss23'].median(),'SD6': data_walking_training_4['var_rss23'].std(),'1st Quartile6': data_walking_training_4['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_4['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'81','Min1':data_walking_training_5['avg_rss12'].min(),'Max1': data_walking_training_5['avg_rss12'].max(),'Mean1': data_walking_training_5['avg_rss12'].mean(),'Median1': data_walking_training_5['avg_rss12'].median(),'SD1': data_walking_training_5['avg_rss12'].std(),'1st Quartile1': data_walking_training_5['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_5['avg_rss12'].quantile(0.75),'Min2': data_walking_training_5['var_rss12'].min(),'Max2': data_walking_training_5['var_rss12'].max(),'Mean2': data_walking_training_5['var_rss12'].mean(),'Median2': data_walking_training_5['var_rss12'].median(),'SD2': data_walking_training_5['var_rss12'].std(),'1st Quartile2': data_walking_training_5['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_5['var_rss12'].quantile(0.75),'Min3': data_walking_training_5['avg_rss13'].min(),'Max3': data_walking_training_5['avg_rss13'].max(),'Mean3': data_walking_training_5['avg_rss13'].mean(),'Median3': data_walking_training_5['avg_rss13'].median(),'SD3': data_walking_training_5['avg_rss13'].std(),'1st Quartile3': data_walking_training_5['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_5['avg_rss13'].quantile(0.75),'Min4': data_walking_training_5['var_rss13'].min(),'Max4': data_walking_training_5['var_rss13'].max(),'Mean4': data_walking_training_5['var_rss13'].mean(),'Median4': data_walking_training_5['var_rss13'].median(),'SD4': data_walking_training_5['var_rss13'].std(),'1st Quartile4': data_walking_training_5['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_5['var_rss13'].quantile(0.75),'Min5': data_walking_training_5['avg_rss23'].min(),'Max5': data_walking_training_5['avg_rss23'].max(),'Mean5': data_walking_training_5['avg_rss23'].mean(),'Median5': data_walking_training_5['avg_rss23'].median(),'SD5': data_walking_training_5['avg_rss23'].std(),'1st Quartile5': data_walking_training_5['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_5['avg_rss23'].quantile(0.75),'Min6': data_walking_training_5['var_rss23'].min(),'Max6': data_walking_training_5['var_rss23'].max(),'Mean6': data_walking_training_5['var_rss23'].mean(),'Median6': data_walking_training_5['var_rss23'].median(),'SD6': data_walking_training_5['var_rss23'].std(),'1st Quartile6': data_walking_training_5['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_5['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'82','Min1':data_walking_training_6['avg_rss12'].min(),'Max1': data_walking_training_6['avg_rss12'].max(),'Mean1': data_walking_training_6['avg_rss12'].mean(),'Median1': data_walking_training_6['avg_rss12'].median(),'SD1': data_walking_training_6['avg_rss12'].std(),'1st Quartile1': data_walking_training_6['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_6['avg_rss12'].quantile(0.75),'Min2': data_walking_training_6['var_rss12'].min(),'Max2': data_walking_training_6['var_rss12'].max(),'Mean2': data_walking_training_6['var_rss12'].mean(),'Median2': data_walking_training_6['var_rss12'].median(),'SD2': data_walking_training_6['var_rss12'].std(),'1st Quartile2': data_walking_training_6['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_6['var_rss12'].quantile(0.75),'Min3': data_walking_training_6['avg_rss13'].min(),'Max3': data_walking_training_6['avg_rss13'].max(),'Mean3': data_walking_training_6['avg_rss13'].mean(),'Median3': data_walking_training_6['avg_rss13'].median(),'SD3': data_walking_training_6['avg_rss13'].std(),'1st Quartile3': data_walking_training_6['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_6['avg_rss13'].quantile(0.75),'Min4': data_walking_training_6['var_rss13'].min(),'Max4': data_walking_training_6['var_rss13'].max(),'Mean4': data_walking_training_6['var_rss13'].mean(),'Median4': data_walking_training_6['var_rss13'].median(),'SD4': data_walking_training_6['var_rss13'].std(),'1st Quartile4': data_walking_training_6['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_6['var_rss13'].quantile(0.75),'Min5': data_walking_training_6['avg_rss23'].min(),'Max5': data_walking_training_6['avg_rss23'].max(),'Mean5': data_walking_training_6['avg_rss23'].mean(),'Median5': data_walking_training_6['avg_rss23'].median(),'SD5': data_walking_training_6['avg_rss23'].std(),'1st Quartile5': data_walking_training_6['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_6['avg_rss23'].quantile(0.75),'Min6': data_walking_training_6['var_rss23'].min(),'Max6': data_walking_training_6['var_rss23'].max(),'Mean6': data_walking_training_6['var_rss23'].mean(),'Median6': data_walking_training_6['var_rss23'].median(),'SD6': data_walking_training_6['var_rss23'].std(),'1st Quartile6': data_walking_training_6['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_6['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'83','Min1':data_walking_training_7['avg_rss12'].min(),'Max1': data_walking_training_7['avg_rss12'].max(),'Mean1': data_walking_training_7['avg_rss12'].mean(),'Median1': data_walking_training_7['avg_rss12'].median(),'SD1': data_walking_training_7['avg_rss12'].std(),'1st Quartile1': data_walking_training_7['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_7['avg_rss12'].quantile(0.75),'Min2': data_walking_training_7['var_rss12'].min(),'Max2': data_walking_training_7['var_rss12'].max(),'Mean2': data_walking_training_7['var_rss12'].mean(),'Median2': data_walking_training_7['var_rss12'].median(),'SD2': data_walking_training_7['var_rss12'].std(),'1st Quartile2': data_walking_training_7['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_7['var_rss12'].quantile(0.75),'Min3': data_walking_training_7['avg_rss13'].min(),'Max3': data_walking_training_7['avg_rss13'].max(),'Mean3': data_walking_training_7['avg_rss13'].mean(),'Median3': data_walking_training_7['avg_rss13'].median(),'SD3': data_walking_training_7['avg_rss13'].std(),'1st Quartile3': data_walking_training_7['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_7['avg_rss13'].quantile(0.75),'Min4': data_walking_training_7['var_rss13'].min(),'Max4': data_walking_training_7['var_rss13'].max(),'Mean4': data_walking_training_7['var_rss13'].mean(),'Median4': data_walking_training_7['var_rss13'].median(),'SD4': data_walking_training_7['var_rss13'].std(),'1st Quartile4': data_walking_training_7['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_7['var_rss13'].quantile(0.75),'Min5': data_walking_training_7['avg_rss23'].min(),'Max5': data_walking_training_7['avg_rss23'].max(),'Mean5': data_walking_training_7['avg_rss23'].mean(),'Median5': data_walking_training_7['avg_rss23'].median(),'SD5': data_walking_training_7['avg_rss23'].std(),'1st Quartile5': data_walking_training_7['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_7['avg_rss23'].quantile(0.75),'Min6': data_walking_training_7['var_rss23'].min(),'Max6': data_walking_training_7['var_rss23'].max(),'Mean6': data_walking_training_7['var_rss23'].mean(),'Median6': data_walking_training_7['var_rss23'].median(),'SD6': data_walking_training_7['var_rss23'].std(),'1st Quartile6': data_walking_training_7['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_7['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'84','Min1':data_walking_training_8['avg_rss12'].min(),'Max1': data_walking_training_8['avg_rss12'].max(),'Mean1': data_walking_training_8['avg_rss12'].mean(),'Median1': data_walking_training_8['avg_rss12'].median(),'SD1': data_walking_training_8['avg_rss12'].std(),'1st Quartile1': data_walking_training_8['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_8['avg_rss12'].quantile(0.75),'Min2': data_walking_training_8['var_rss12'].min(),'Max2': data_walking_training_8['var_rss12'].max(),'Mean2': data_walking_training_8['var_rss12'].mean(),'Median2': data_walking_training_8['var_rss12'].median(),'SD2': data_walking_training_8['var_rss12'].std(),'1st Quartile2': data_walking_training_8['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_8['var_rss12'].quantile(0.75),'Min3': data_walking_training_8['avg_rss13'].min(),'Max3': data_walking_training_8['avg_rss13'].max(),'Mean3': data_walking_training_8['avg_rss13'].mean(),'Median3': data_walking_training_8['avg_rss13'].median(),'SD3': data_walking_training_8['avg_rss13'].std(),'1st Quartile3': data_walking_training_8['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_8['avg_rss13'].quantile(0.75),'Min4': data_walking_training_8['var_rss13'].min(),'Max4': data_walking_training_8['var_rss13'].max(),'Mean4': data_walking_training_8['var_rss13'].mean(),'Median4': data_walking_training_8['var_rss13'].median(),'SD4': data_walking_training_8['var_rss13'].std(),'1st Quartile4': data_walking_training_8['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_8['var_rss13'].quantile(0.75),'Min5': data_walking_training_8['avg_rss23'].min(),'Max5': data_walking_training_8['avg_rss23'].max(),'Mean5': data_walking_training_8['avg_rss23'].mean(),'Median5': data_walking_training_8['avg_rss23'].median(),'SD5': data_walking_training_8['avg_rss23'].std(),'1st Quartile5': data_walking_training_8['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_8['avg_rss23'].quantile(0.75),'Min6': data_walking_training_8['var_rss23'].min(),'Max6': data_walking_training_8['var_rss23'].max(),'Mean6': data_walking_training_8['var_rss23'].mean(),'Median6': data_walking_training_8['var_rss23'].median(),'SD6': data_walking_training_8['var_rss23'].std(),'1st Quartile6': data_walking_training_8['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_8['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'85','Min1':data_walking_training_9['avg_rss12'].min(),'Max1': data_walking_training_9['avg_rss12'].max(),'Mean1': data_walking_training_9['avg_rss12'].mean(),'Median1': data_walking_training_9['avg_rss12'].median(),'SD1': data_walking_training_9['avg_rss12'].std(),'1st Quartile1': data_walking_training_9['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_9['avg_rss12'].quantile(0.75),'Min2': data_walking_training_9['var_rss12'].min(),'Max2': data_walking_training_9['var_rss12'].max(),'Mean2': data_walking_training_9['var_rss12'].mean(),'Median2': data_walking_training_9['var_rss12'].median(),'SD2': data_walking_training_9['var_rss12'].std(),'1st Quartile2': data_walking_training_9['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_9['var_rss12'].quantile(0.75),'Min3': data_walking_training_9['avg_rss13'].min(),'Max3': data_walking_training_9['avg_rss13'].max(),'Mean3': data_walking_training_9['avg_rss13'].mean(),'Median3': data_walking_training_9['avg_rss13'].median(),'SD3': data_walking_training_9['avg_rss13'].std(),'1st Quartile3': data_walking_training_9['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_9['avg_rss13'].quantile(0.75),'Min4': data_walking_training_9['var_rss13'].min(),'Max4': data_walking_training_9['var_rss13'].max(),'Mean4': data_walking_training_9['var_rss13'].mean(),'Median4': data_walking_training_9['var_rss13'].median(),'SD4': data_walking_training_9['var_rss13'].std(),'1st Quartile4': data_walking_training_9['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_9['var_rss13'].quantile(0.75),'Min5': data_walking_training_9['avg_rss23'].min(),'Max5': data_walking_training_9['avg_rss23'].max(),'Mean5': data_walking_training_9['avg_rss23'].mean(),'Median5': data_walking_training_9['avg_rss23'].median(),'SD5': data_walking_training_9['avg_rss23'].std(),'1st Quartile5': data_walking_training_9['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_9['avg_rss23'].quantile(0.75),'Min6': data_walking_training_9['var_rss23'].min(),'Max6': data_walking_training_9['var_rss23'].max(),'Mean6': data_walking_training_9['var_rss23'].mean(),'Median6': data_walking_training_9['var_rss23'].median(),'SD6': data_walking_training_9['var_rss23'].std(),'1st Quartile6': data_walking_training_9['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_9['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'86','Min1':data_walking_training_10['avg_rss12'].min(),'Max1': data_walking_training_10['avg_rss12'].max(),'Mean1': data_walking_training_10['avg_rss12'].mean(),'Median1': data_walking_training_10['avg_rss12'].median(),'SD1': data_walking_training_10['avg_rss12'].std(),'1st Quartile1': data_walking_training_10['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_10['avg_rss12'].quantile(0.75),'Min2': data_walking_training_10['var_rss12'].min(),'Max2': data_walking_training_10['var_rss12'].max(),'Mean2': data_walking_training_10['var_rss12'].mean(),'Median2': data_walking_training_10['var_rss12'].median(),'SD2': data_walking_training_10['var_rss12'].std(),'1st Quartile2': data_walking_training_10['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_10['var_rss12'].quantile(0.75),'Min3': data_walking_training_10['avg_rss13'].min(),'Max3': data_walking_training_10['avg_rss13'].max(),'Mean3': data_walking_training_10['avg_rss13'].mean(),'Median3': data_walking_training_10['avg_rss13'].median(),'SD3': data_walking_training_10['avg_rss13'].std(),'1st Quartile3': data_walking_training_10['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_10['avg_rss13'].quantile(0.75),'Min4': data_walking_training_10['var_rss13'].min(),'Max4': data_walking_training_10['var_rss13'].max(),'Mean4': data_walking_training_10['var_rss13'].mean(),'Median4': data_walking_training_10['var_rss13'].median(),'SD4': data_walking_training_10['var_rss13'].std(),'1st Quartile4': data_walking_training_10['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_10['var_rss13'].quantile(0.75),'Min5': data_walking_training_10['avg_rss23'].min(),'Max5': data_walking_training_10['avg_rss23'].max(),'Mean5': data_walking_training_10['avg_rss23'].mean(),'Median5': data_walking_training_10['avg_rss23'].median(),'SD5': data_walking_training_10['avg_rss23'].std(),'1st Quartile5': data_walking_training_10['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_10['avg_rss23'].quantile(0.75),'Min6': data_walking_training_10['var_rss23'].min(),'Max6': data_walking_training_10['var_rss23'].max(),'Mean6': data_walking_training_10['var_rss23'].mean(),'Median6': data_walking_training_10['var_rss23'].median(),'SD6': data_walking_training_10['var_rss23'].std(),'1st Quartile6': data_walking_training_10['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_10['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'87','Min1':data_walking_training_11['avg_rss12'].min(),'Max1': data_walking_training_11['avg_rss12'].max(),'Mean1': data_walking_training_11['avg_rss12'].mean(),'Median1': data_walking_training_11['avg_rss12'].median(),'SD1': data_walking_training_11['avg_rss12'].std(),'1st Quartile1': data_walking_training_11['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_11['avg_rss12'].quantile(0.75),'Min2': data_walking_training_11['var_rss12'].min(),'Max2': data_walking_training_11['var_rss12'].max(),'Mean2': data_walking_training_11['var_rss12'].mean(),'Median2': data_walking_training_11['var_rss12'].median(),'SD2': data_walking_training_11['var_rss12'].std(),'1st Quartile2': data_walking_training_11['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_11['var_rss12'].quantile(0.75),'Min3': data_walking_training_11['avg_rss13'].min(),'Max3': data_walking_training_11['avg_rss13'].max(),'Mean3': data_walking_training_11['avg_rss13'].mean(),'Median3': data_walking_training_11['avg_rss13'].median(),'SD3': data_walking_training_11['avg_rss13'].std(),'1st Quartile3': data_walking_training_11['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_11['avg_rss13'].quantile(0.75),'Min4': data_walking_training_11['var_rss13'].min(),'Max4': data_walking_training_11['var_rss13'].max(),'Mean4': data_walking_training_11['var_rss13'].mean(),'Median4': data_walking_training_11['var_rss13'].median(),'SD4': data_walking_training_11['var_rss13'].std(),'1st Quartile4': data_walking_training_11['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_11['var_rss13'].quantile(0.75),'Min5': data_walking_training_11['avg_rss23'].min(),'Max5': data_walking_training_11['avg_rss23'].max(),'Mean5': data_walking_training_11['avg_rss23'].mean(),'Median5': data_walking_training_11['avg_rss23'].median(),'SD5': data_walking_training_11['avg_rss23'].std(),'1st Quartile5': data_walking_training_11['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_11['avg_rss23'].quantile(0.75),'Min6': data_walking_training_11['var_rss23'].min(),'Max6': data_walking_training_11['var_rss23'].max(),'Mean6': data_walking_training_11['var_rss23'].mean(),'Median6': data_walking_training_11['var_rss23'].median(),'SD6': data_walking_training_11['var_rss23'].std(),'1st Quartile6': data_walking_training_11['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_11['var_rss23'].quantile(0.75)}, ignore_index=True)
new_dataset=new_dataset.append({'Instance':'88','Min1':data_walking_training_12['avg_rss12'].min(),'Max1': data_walking_training_12['avg_rss12'].max(),'Mean1': data_walking_training_12['avg_rss12'].mean(),'Median1': data_walking_training_12['avg_rss12'].median(),'SD1': data_walking_training_12['avg_rss12'].std(),'1st Quartile1': data_walking_training_12['avg_rss12'].quantile(0.25),'3rd Quartile1': data_walking_training_12['avg_rss12'].quantile(0.75),'Min2': data_walking_training_12['var_rss12'].min(),'Max2': data_walking_training_12['var_rss12'].max(),'Mean2': data_walking_training_12['var_rss12'].mean(),'Median2': data_walking_training_12['var_rss12'].median(),'SD2': data_walking_training_12['var_rss12'].std(),'1st Quartile2': data_walking_training_12['var_rss12'].quantile(0.25),'3rd Quartile2': data_walking_training_12['var_rss12'].quantile(0.75),'Min3': data_walking_training_12['avg_rss13'].min(),'Max3': data_walking_training_12['avg_rss13'].max(),'Mean3': data_walking_training_12['avg_rss13'].mean(),'Median3': data_walking_training_12['avg_rss13'].median(),'SD3': data_walking_training_12['avg_rss13'].std(),'1st Quartile3': data_walking_training_12['avg_rss13'].quantile(0.25),'3rd Quartile3': data_walking_training_12['avg_rss13'].quantile(0.75),'Min4': data_walking_training_12['var_rss13'].min(),'Max4': data_walking_training_12['var_rss13'].max(),'Mean4': data_walking_training_12['var_rss13'].mean(),'Median4': data_walking_training_12['var_rss13'].median(),'SD4': data_walking_training_12['var_rss13'].std(),'1st Quartile4': data_walking_training_12['var_rss13'].quantile(0.25),'3rd Quartile4': data_walking_training_12['var_rss13'].quantile(0.75),'Min5': data_walking_training_12['avg_rss23'].min(),'Max5': data_walking_training_12['avg_rss23'].max(),'Mean5': data_walking_training_12['avg_rss23'].mean(),'Median5': data_walking_training_12['avg_rss23'].median(),'SD5': data_walking_training_12['avg_rss23'].std(),'1st Quartile5': data_walking_training_12['avg_rss23'].quantile(0.25),'3rd Quartile5': data_walking_training_12['avg_rss23'].quantile(0.75),'Min6': data_walking_training_12['var_rss23'].min(),'Max6': data_walking_training_12['var_rss23'].max(),'Mean6': data_walking_training_12['var_rss23'].mean(),'Median6': data_walking_training_12['var_rss23'].median(),'SD6': data_walking_training_12['var_rss23'].std(),'1st Quartile6': data_walking_training_12['var_rss23'].quantile(0.25),'3rd Quartile6': data_walking_training_12['var_rss23'].quantile(0.75)}, ignore_index=True)

# %% [markdown]
# Extracting time domain features and displaying the values in the dataframe

# %%
new_dataset
# Out:
#    Instance   Min1   Max1      Mean1  Median1       SD1  1st Quartile1  \
# 0         1  37.25  45.00  40.624792   40.500  1.476967        39.2500
# 1         2  38.00  45.67  42.812812   42.500  1.435550        42.0000
# 2         3  12.75  51.00  24.562958   24.250  3.737514        23.1875
# 3         4   0.00  42.75  27.464604   28.000  3.583582        25.5000
# 4         5  24.25  45.00  37.177042   36.250  3.581301        34.5000
# 5         6  28.75  44.75  37.561188   36.875  3.226507        35.2500
# 6         7  22.00  44.67  37.058708   36.000  3.710180        34.5000
# 7         8  23.50  30.00  27.716375   27.500  1.442253        27.0000
# 8         9  24.75  48.33  44.182937   48.000  7.495615        48.0000
# 9        10  48.00  48.25  48.004167   48.000  0.032038        48.0000
# 10       11  33.25  48.00  42.363563   43.000  2.068247        42.0000
# 11       12  37.00  50.75  45.917667   45.635  1.089027        45.0000
# ...

# %% [markdown]
# 90% bootsrap confidence interval for the standard deviation of each feature

# %%
table_Min=[new_dataset['Min1'].std(),new_dataset['Min2'].std(),new_dataset['Min3'].std(),new_dataset['Min4'].std(),new_dataset['Min5'].std(),new_dataset['Min6'].std()]
st.t.interval(0.90, len(table_Min)-1, loc=np.std(table_Min), scale=st.sem(table_Min))
# Out:
# (0.3599570269645862, 6.92345461326823)

# %%
table_Max=[new_dataset['Max1'].std(),new_dataset['Max2'].std(),new_dataset['Max3'].std(),new_dataset['Max4'].std(),new_dataset['Max5'].std(),new_dataset['Max6'].std()]
st.t.interval(0.90, len(table_Max)-1, loc=np.std(table_Max), scale=st.sem(table_Max))
# Out:
# (0.13060205021809712, 2.512014766623053)

# %%
table_Mean=[new_dataset['Mean1'].std(),new_dataset['Mean2'].std(),new_dataset['Mean3'].std(),new_dataset['Mean4'].std(),new_dataset['Mean5'].std(),new_dataset['Mean6'].std()]
st.t.interval(0.90, len(table_Mean)-1, loc=np.std(table_Mean), scale=st.sem(table_Mean))
# Out:
# (0.19051901693737094, 3.6644645552652064)

# %%
table_Median=[new_dataset['Median1'].std(),new_dataset['Median2'].std(),new_dataset['Median3'].std(),new_dataset['Median4'].std(),new_dataset['Median5'].std(),new_dataset['Median6'].std()]
st.t.interval(0.90, len(table_Median)-1, loc=np.std(table_Median), scale=st.sem(table_Median))
# Out:
# (0.1994058194500965, 3.835394330890862)

# %%
table_SD=[new_dataset['SD1'].std(),new_dataset['SD2'].std(),new_dataset['SD3'].std(),new_dataset['SD4'].std(),new_dataset['SD5'].std(),new_dataset['SD6'].std()]
st.t.interval(0.90, len(table_SD)-1, loc=np.std(table_SD), scale=st.sem(table_SD))
# Out:
# (0.04257369199504635, 0.8188672596075304)

# %%
table_1st_Quartile=[new_dataset['1st Quartile1'].std(),new_dataset['1st Quartile2'].std(),new_dataset['1st Quartile3'].std(),new_dataset['1st Quartile4'].std(),new_dataset['1st Quartile5'].std(),new_dataset['1st Quartile6'].std()]
st.t.interval(0.90, len(table_1st_Quartile)-1, loc=np.std(table_1st_Quartile), scale=st.sem(table_1st_Quartile))
# Out:
# (0.23785213370672764, 4.57487513516315)

# %%
table_3rd_Quartile=[new_dataset['3rd Quartile1'].std(),new_dataset['3rd Quartile2'].std(),new_dataset['3rd Quartile3'].std(),new_dataset['3rd Quartile4'].std(),new_dataset['3rd Quartile5'].std(),new_dataset['3rd Quartile6'].std()]
st.t.interval(0.90, len(table_3rd_Quartile)-1, loc=np.std(table_3rd_Quartile), scale=st.sem(table_3rd_Quartile))
# Out:
# (0.16490575735632507, 3.171816191924113)

# %%
data_test_min_1=data_bending1_test_1.min()
data_test_min_2=data_bending1_test_2.min()
data_test_min_3=data_bending2_test_1.min()
data_test_min_4=data_bending2_test_2.min()
data_test_min_5=data_cycling_test_1.min()
data_test_min_6=data_cycling_test_2.min()
data_test_min_7=data_cycling_test_3.min()
data_test_min_8=data_lying_test_1.min()
data_test_min_9=data_lying_test_2.min()
data_test_min_10=data_lying_test_3.min()
data_test_min_11=data_sitting_test_1.min()
data_test_min_12=data_sitting_test_2.min()
data_test_min_13=data_sitting_test_3.min()
data_test_min_14=data_standing_test_1.min()
data_test_min_15=data_standing_test_2.min()
data_test_min_16=data_standing_test_3.min()
data_test_min_17=data_walking_test_1.min()
data_test_min_18=data_walking_test_2.min()
data_test_min_19=data_walking_test_3.min()

# %%
data_test_max_1=data_bending1_test_1.max()
data_test_max_2=data_bending1_test_2.max()
data_test_max_3=data_bending2_test_1.max()
data_test_max_4=data_bending2_test_2.max()
data_test_max_5=data_cycling_test_1.max()
data_test_max_6=data_cycling_test_2.max()
data_test_max_7=data_cycling_test_3.max()
data_test_max_8=data_lying_test_1.max()
data_test_max_9=data_lying_test_2.max()
data_test_max_10=data_lying_test_3.max()
data_test_max_11=data_sitting_test_1.max()
data_test_max_12=data_sitting_test_2.max()
data_test_max_13=data_sitting_test_3.max()
data_test_max_14=data_standing_test_1.max()
data_test_max_15=data_standing_test_2.max()
data_test_max_16=data_standing_test_3.max()
data_test_max_17=data_walking_test_1.max()
data_test_max_18=data_walking_test_2.max()
data_test_max_19=data_walking_test_3.max()

# %%
data_test_mean_1=data_bending1_test_1.mean()
data_test_mean_2=data_bending1_test_2.mean()
data_test_mean_3=data_bending2_test_1.mean()
data_test_mean_4=data_bending2_test_2.mean()
data_test_mean_5=data_cycling_test_1.mean()
data_test_mean_6=data_cycling_test_2.mean()
data_test_mean_7=data_cycling_test_3.mean()
data_test_mean_8=data_lying_test_1.mean()
data_test_mean_9=data_lying_test_2.mean()
data_test_mean_10=data_lying_test_3.mean()
data_test_mean_11=data_sitting_test_1.mean()
data_test_mean_12=data_sitting_test_2.mean()
data_test_mean_13=data_sitting_test_3.mean()
data_test_mean_14=data_standing_test_1.mean()
data_test_mean_15=data_standing_test_2.mean()
data_test_mean_16=data_standing_test_3.mean()
data_test_mean_17=data_walking_test_1.mean()
data_test_mean_18=data_walking_test_2.mean()
data_test_mean_19=data_walking_test_3.mean()

# %%
array2 = [[(eval('data_test_min_'+str(x)))[1:],eval('data_test_max_'+str(x))[1:],eval('data_test_mean_'+str(x))[1:]] for x in range(1,20)]

# %%
total_columns =['min_avg_rss12','min_var_rss12','min_avg_rss13','min_var_rss13','min_avg_rss23','min_var_rss23','max_avg_rss12','max_var_rss12','max_avg_rss13','max_var_rss13','max_avg_rss23','max_var_rss23','mean_avg_rss12','mean_var_rss12','mean_avg_rss13','mean_var_rss13','mean_avg_rss23','mean_var_rss23']

# %%
Test_data= pd.DataFrame(columns=total_columns)

# %%
for i in range(0,19):
    Test_data.loc[i] = list(itertools.chain.from_iterable(array2[i]))

# %%
data_training_min_1=data_bending1_training_1.min()
data_training_min_2=data_bending1_training_2.min()
data_training_min_3=data_bending1_training_3.min()
data_training_min_4=data_bending1_training_4.min()
data_training_min_5=data_bending1_training_5.min()
data_training_min_6=data_bending2_training_1.min()
data_training_min_7=data_bending2_training_2.min()
data_training_min_8=data_bending2_training_3.min()
data_training_min_9=data_bending2_training_4.min()
data_training_min_10=data_cycling_training_1.min()
data_training_min_11=data_cycling_training_2.min()
data_training_min_12=data_cycling_training_3.min()
data_training_min_13=data_cycling_training_4.min()
data_training_min_14=data_cycling_training_5.min()
data_training_min_15=data_cycling_training_6.min()
data_training_min_16=data_cycling_training_7.min()
data_training_min_17=data_cycling_training_8.min()
data_training_min_18=data_cycling_training_9.min()
data_training_min_19=data_cycling_training_10.min()
data_training_min_20=data_cycling_training_11.min()
data_training_min_21=data_cycling_training_12.min()
data_training_min_22=data_lying_training_1.min()
data_training_min_23=data_lying_training_2.min()
data_training_min_24=data_lying_training_3.min()
data_training_min_25=data_lying_training_4.min()
data_training_min_26=data_lying_training_5.min()
data_training_min_27=data_lying_training_6.min()
data_training_min_28=data_lying_training_7.min()
data_training_min_29=data_lying_training_8.min()
data_training_min_30=data_lying_training_9.min()
data_training_min_31=data_lying_training_10.min()
data_training_min_32=data_lying_training_11.min()
data_training_min_33=data_lying_training_12.min()
data_training_min_34=data_sitting_training_1.min()
data_training_min_35=data_sitting_training_2.min()
data_training_min_36=data_sitting_training_3.min()
data_training_min_37=data_sitting_training_4.min()
data_training_min_38=data_sitting_training_5.min()
data_training_min_39=data_sitting_training_6.min()
data_training_min_40=data_sitting_training_7.min()
data_training_min_41=data_sitting_training_8.min()
data_training_min_42=data_sitting_training_9.min()
data_training_min_43=data_sitting_training_10.min()
data_training_min_44=data_sitting_training_11.min()
data_training_min_45=data_sitting_training_12.min()
data_training_min_46=data_standing_training_1.min()
data_training_min_47=data_standing_training_2.min()
data_training_min_48=data_standing_training_3.min()
data_training_min_49=data_standing_training_4.min()
data_training_min_50=data_standing_training_5.min()
data_training_min_51=data_standing_training_6.min()
data_training_min_52=data_standing_training_7.min()
data_training_min_53=data_standing_training_8.min()
data_training_min_54=data_standing_training_9.min()
data_training_min_55=data_standing_training_10.min()
data_training_min_56=data_standing_training_11.min()
data_training_min_57=data_standing_training_12.min()
data_training_min_58=data_walking_training_1.min()
data_training_min_59=data_walking_training_2.min()
data_training_min_60=data_walking_training_3.min()
data_training_min_61=data_walking_training_4.min()
data_training_min_62=data_walking_training_5.min()
data_training_min_63=data_walking_training_6.min()
data_training_min_64=data_walking_training_7.min()
data_training_min_65=data_walking_training_8.min()
data_training_min_66=data_walking_training_9.min()
data_training_min_67=data_walking_training_10.min()
data_training_min_68=data_walking_training_11.min()
data_training_min_69=data_walking_training_12.min()

# %%
data_training_max_1=data_bending1_training_1.max()
data_training_max_2=data_bending1_training_2.max()
data_training_max_3=data_bending1_training_3.max()
data_training_max_4=data_bending1_training_4.max()
data_training_max_5=data_bending1_training_5.max()
data_training_max_6=data_bending2_training_1.max()
data_training_max_7=data_bending2_training_2.max()
data_training_max_8=data_bending2_training_3.max()
data_training_max_9=data_bending2_training_4.max()
data_training_max_10=data_cycling_training_1.max()
data_training_max_11=data_cycling_training_2.max()
data_training_max_12=data_cycling_training_3.max()
data_training_max_13=data_cycling_training_4.max()
data_training_max_14=data_cycling_training_5.max()
data_training_max_15=data_cycling_training_6.max()
data_training_max_16=data_cycling_training_7.max()
data_training_max_17=data_cycling_training_8.max()
data_training_max_18=data_cycling_training_9.max()
data_training_max_19=data_cycling_training_10.max()
data_training_max_20=data_cycling_training_11.max()
data_training_max_21=data_cycling_training_12.max()
data_training_max_22=data_lying_training_1.max()
data_training_max_23=data_lying_training_2.max()
data_training_max_24=data_lying_training_3.max()
data_training_max_25=data_lying_training_4.max()
data_training_max_26=data_lying_training_5.max()
data_training_max_27=data_lying_training_6.max()
data_training_max_28=data_lying_training_7.max()
data_training_max_29=data_lying_training_8.max()
data_training_max_30=data_lying_training_9.max()
data_training_max_31=data_lying_training_10.max()
data_training_max_32=data_lying_training_11.max()
data_training_max_33=data_lying_training_12.max()
data_training_max_34=data_sitting_training_1.max()
data_training_max_35=data_sitting_training_2.max()
data_training_max_36=data_sitting_training_3.max()
data_training_max_37=data_sitting_training_4.max()
data_training_max_38=data_sitting_training_5.max()
data_training_max_39=data_sitting_training_6.max()
data_training_max_40=data_sitting_training_7.max()
data_training_max_41=data_sitting_training_8.max()
data_training_max_42=data_sitting_training_9.max()
data_training_max_43=data_sitting_training_10.max()
data_training_max_44=data_sitting_training_11.max()
data_training_max_45=data_sitting_training_12.max()
data_training_max_46=data_standing_training_1.max()
data_training_max_47=data_standing_training_2.max()
data_training_max_48=data_standing_training_3.max()
data_training_max_49=data_standing_training_4.max()
data_training_max_50=data_standing_training_5.max()
data_training_max_51=data_standing_training_6.max()
data_training_max_52=data_standing_training_7.max()
data_training_max_53=data_standing_training_8.max()
data_training_max_54=data_standing_training_9.max()
data_training_max_55=data_standing_training_10.max()
data_training_max_56=data_standing_training_11.max()
data_training_max_57=data_standing_training_12.max()
data_training_max_58=data_walking_training_1.max()
data_training_max_59=data_walking_training_2.max()
data_training_max_60=data_walking_training_3.max()
data_training_max_61=data_walking_training_4.max()
data_training_max_62=data_walking_training_5.max()
data_training_max_63=data_walking_training_6.max()
data_training_max_64=data_walking_training_7.max()
data_training_max_65=data_walking_training_8.max()
data_training_max_66=data_walking_training_9.max()
data_training_max_67=data_walking_training_10.max()
data_training_max_68=data_walking_training_11.max()
data_training_max_69=data_walking_training_12.max()

# %%
data_training_mean_1=data_bending1_training_1.mean()
data_training_mean_2=data_bending1_training_2.mean()
data_training_mean_3=data_bending1_training_3.mean()
data_training_mean_4=data_bending1_training_4.mean()
data_training_mean_5=data_bending1_training_5.mean()
data_training_mean_6=data_bending2_training_1.mean()
data_training_mean_7=data_bending2_training_2.mean()
data_training_mean_8=data_bending2_training_3.mean()
data_training_mean_9=data_bending2_training_4.mean()
data_training_mean_10=data_cycling_training_1.mean()
data_training_mean_11=data_cycling_training_2.mean()
data_training_mean_12=data_cycling_training_3.mean()
data_training_mean_13=data_cycling_training_4.mean()
data_training_mean_14=data_cycling_training_5.mean()
data_training_mean_15=data_cycling_training_6.mean()
data_training_mean_16=data_cycling_training_7.mean()
data_training_mean_17=data_cycling_training_8.mean()
data_training_mean_18=data_cycling_training_9.mean()
data_training_mean_19=data_cycling_training_10.mean()
data_training_mean_20=data_cycling_training_11.mean()
data_training_mean_21=data_cycling_training_12.mean()
data_training_mean_22=data_lying_training_1.mean()
data_training_mean_23=data_lying_training_2.mean()
data_training_mean_24=data_lying_training_3.mean()
data_training_mean_25=data_lying_training_4.mean()
data_training_mean_26=data_lying_training_5.mean()
data_training_mean_27=data_lying_training_6.mean()
data_training_mean_28=data_lying_training_7.mean()
data_training_mean_29=data_lying_training_8.mean()
data_training_mean_30=data_lying_training_9.mean()
data_training_mean_31=data_lying_training_10.mean()
data_training_mean_32=data_lying_training_11.mean()
data_training_mean_33=data_lying_training_12.mean()
data_training_mean_34=data_sitting_training_1.mean()
data_training_mean_35=data_sitting_training_2.mean()
data_training_mean_36=data_sitting_training_3.mean()
data_training_mean_37=data_sitting_training_4.mean()
data_training_mean_38=data_sitting_training_5.mean()
data_training_mean_39=data_sitting_training_6.mean()
data_training_mean_40=data_sitting_training_7.mean()
data_training_mean_41=data_sitting_training_8.mean()
data_training_mean_42=data_sitting_training_9.mean()
data_training_mean_43=data_sitting_training_10.mean()
data_training_mean_44=data_sitting_training_11.mean()
data_training_mean_45=data_sitting_training_12.mean()
data_training_mean_46=data_standing_training_1.mean()
data_training_mean_47=data_standing_training_2.mean()
data_training_mean_48=data_standing_training_3.mean()
data_training_mean_49=data_standing_training_4.mean()
data_training_mean_50=data_standing_training_5.mean()
data_training_mean_51=data_standing_training_6.mean()
data_training_mean_52=data_standing_training_7.mean()
data_training_mean_53=data_standing_training_8.mean()
data_training_mean_54=data_standing_training_9.mean()
data_training_mean_55=data_standing_training_10.mean()
data_training_mean_56=data_standing_training_11.mean()
data_training_mean_57=data_standing_training_12.mean()
data_training_mean_58=data_walking_training_1.mean()
data_training_mean_59=data_walking_training_2.mean()
data_training_mean_60=data_walking_training_3.mean()
data_training_mean_61=data_walking_training_4.mean()
data_training_mean_62=data_walking_training_5.mean()
data_training_mean_63=data_walking_training_6.mean()
data_training_mean_64=data_walking_training_7.mean()
data_training_mean_65=data_walking_training_8.mean()
data_training_mean_66=data_walking_training_9.mean()
data_training_mean_67=data_walking_training_10.mean()
data_training_mean_68=data_walking_training_11.mean()
data_training_mean_69=data_walking_training_12.mean()

# %%
array2 = [[(eval('data_training_min_'+str(x)))[1:],eval('data_training_max_'+str(x))[1:],eval('data_training_mean_'+str(x))[1:]] for x in range(1,70)]

# %%
total_columns =['min_avg_rss12','min_var_rss12','min_avg_rss13','min_var_rss13','min_avg_rss23','min_var_rss23','max_avg_rss12','max_var_rss12','max_avg_rss13','max_var_rss13','max_avg_rss23','max_var_rss23','mean_avg_rss12','mean_var_rss12','mean_avg_rss13','mean_var_rss13','mean_avg_rss23','mean_var_rss23']

# %%
Training_data= pd.DataFrame(columns=total_columns)

# %%
for i in range(0,69):
    Training_data.loc[i] = list(itertools.chain.from_iterable(array2[i]))

# %% [markdown]
# Depicting scatter plots of the features extracted from time series 1, 2, and 6 of each instance

# %%
bending_data_min=Training_data.iloc[0:9,[0,1,5]]
other_data_min=Training_data.iloc[9:70,[0,1,5]]
ax = bending_data_min.plot(style='ro',legend=False)
other_data_min.plot(style='bo',ax=ax, legend=False)
plt.show()
print("Red is for bending data and blue is for other activities")
# Out:
# Red is for bending data and blue is for other activities

# %%
bending_data_max=Training_data.iloc[0:9,[6,7,11]]
other_data_max=Training_data.iloc[9:70,[6,7,11]]
ax = bending_data_max.plot(style='ro', legend=False)
other_data_max.plot(style='bo',ax=ax, legend=False)
plt.show()
print("Red is for bending data and blue is for other activities")
# Out:
# Red is for bending data and blue is for other activities

# %%
bending_data_mean=Training_data.iloc[0:9,[12,13,17]]
other_data_mean=Training_data.iloc[9:70,[12,13,17]]
ax = bending_data_mean.plot(style='ro', legend=False)
other_data_mean.plot(style='bo',ax=ax, legend=False)
plt.show()
print("Red is for bending data and blue is for other activities")
# Out:
# Red is for bending data and blue is for other activities

# %%
training_data1 = pd.concat([data_bending1_training_1.iloc[0:240,1:7],data_bending1_training_1.iloc[240:].reset_index()],axis=1)
training_data2 = pd.concat([data_bending1_training_2.iloc[0:240,1:7],data_bending1_training_2.iloc[240:].reset_index()],axis=1)
training_data3 = pd.concat([data_bending1_training_3.iloc[0:240,1:7],data_bending1_training_3.iloc[240:].reset_index()],axis=1)
training_data4 = pd.concat([data_bending1_training_4.iloc[0:240,1:7],data_bending1_training_4.iloc[240:].reset_index()],axis=1)
training_data5 = pd.concat([data_bending1_training_5.iloc[0:240,1:7],data_bending1_training_5.iloc[240:].reset_index()],axis=1)
training_data6 = pd.concat([data_bending2_training_1.iloc[0:240,1:7],data_bending2_training_1.iloc[240:].reset_index()],axis=1)
training_data7 = pd.concat([data_bending2_training_2.iloc[0:240,1:7],data_bending2_training_2.iloc[240:].reset_index()],axis=1)
training_data8 = pd.concat([data_bending2_training_3.iloc[0:240,1:7],data_bending2_training_3.iloc[240:].reset_index()],axis=1)
training_data9 = pd.concat([data_bending2_training_4.iloc[0:240,1:7],data_bending2_training_4.iloc[240:].reset_index()],axis=1)
training_data10 = pd.concat([data_cycling_training_1.iloc[0:240,1:7],data_cycling_training_1.iloc[240:].reset_index()],axis=1)
training_data11 = pd.concat([data_cycling_training_2.iloc[0:240,1:7],data_cycling_training_2.iloc[240:].reset_index()],axis=1)
training_data12 = pd.concat([data_cycling_training_3.iloc[0:240,1:7],data_cycling_training_3.iloc[240:].reset_index()],axis=1)
training_data13 = pd.concat([data_cycling_training_4.iloc[0:240,1:7],data_cycling_training_4.iloc[240:].reset_index()],axis=1)
training_data14 = pd.concat([data_cycling_training_5.iloc[0:240,1:7],data_cycling_training_5.iloc[240:].reset_index()],axis=1)
training_data15 = pd.concat([data_cycling_training_6.iloc[0:240,1:7],data_cycling_training_6.iloc[240:].reset_index()],axis=1)
training_data16 = pd.concat([data_cycling_training_7.iloc[0:240,1:7],data_cycling_training_7.iloc[240:].reset_index()],axis=1)
training_data17 = pd.concat([data_cycling_training_8.iloc[0:240,1:7],data_cycling_training_8.iloc[240:].reset_index()],axis=1)
training_data18 = pd.concat([data_cycling_training_9.iloc[0:240,1:7],data_cycling_training_9.iloc[240:].reset_index()],axis=1)
training_data19 = pd.concat([data_cycling_training_10.iloc[0:240,1:7],data_cycling_training_10.iloc[240:].reset_index()],axis=1)
training_data20 = pd.concat([data_cycling_training_11.iloc[0:240,1:7],data_cycling_training_11.iloc[240:].reset_index()],axis=1)
training_data21 = pd.concat([data_cycling_training_12.iloc[0:240,1:7],data_cycling_training_12.iloc[240:].reset_index()],axis=1)
training_data22 = pd.concat([data_lying_training_1.iloc[0:240,1:7],data_lying_training_1.iloc[240:].reset_index()],axis=1)
training_data23 = pd.concat([data_lying_training_2.iloc[0:240,1:7],data_lying_training_2.iloc[240:].reset_index()],axis=1)
training_data24 = pd.concat([data_lying_training_3.iloc[0:240,1:7],data_lying_training_3.iloc[240:].reset_index()],axis=1)
training_data25 = pd.concat([data_lying_training_4.iloc[0:240,1:7],data_lying_training_4.iloc[240:].reset_index()],axis=1)
training_data26 = pd.concat([data_lying_training_5.iloc[0:240,1:7],data_lying_training_5.iloc[240:].reset_index()],axis=1)
training_data27 = pd.concat([data_lying_training_6.iloc[0:240,1:7],data_lying_training_6.iloc[240:].reset_index()],axis=1)
training_data28 = pd.concat([data_lying_training_7.iloc[0:240,1:7],data_lying_training_7.iloc[240:].reset_index()],axis=1)
training_data29 = pd.concat([data_lying_training_8.iloc[0:240,1:7],data_lying_training_8.iloc[240:].reset_index()],axis=1)
training_data30 = pd.concat([data_lying_training_9.iloc[0:240,1:7],data_lying_training_9.iloc[240:].reset_index()],axis=1)
training_data31 = pd.concat([data_lying_training_10.iloc[0:240,1:7],data_lying_training_10.iloc[240:].reset_index()],axis=1)
training_data32 = pd.concat([data_lying_training_11.iloc[0:240,1:7],data_lying_training_11.iloc[240:].reset_index()],axis=1)
training_data33 = pd.concat([data_lying_training_12.iloc[0:240,1:7],data_lying_training_12.iloc[240:].reset_index()],axis=1)
training_data34 = pd.concat([data_sitting_training_1.iloc[0:240,1:7],data_sitting_training_1.iloc[240:].reset_index()],axis=1)
training_data35 = pd.concat([data_sitting_training_2.iloc[0:240,1:7],data_sitting_training_2.iloc[240:].reset_index()],axis=1)
training_data36 = pd.concat([data_sitting_training_3.iloc[0:240,1:7],data_sitting_training_3.iloc[240:].reset_index()],axis=1)
training_data37 = pd.concat([data_sitting_training_4.iloc[0:240,1:7],data_sitting_training_4.iloc[240:].reset_index()],axis=1)
training_data38 = pd.concat([data_sitting_training_5.iloc[0:240,1:7],data_sitting_training_5.iloc[240:].reset_index()],axis=1)
training_data39 = pd.concat([data_sitting_training_6.iloc[0:240,1:7],data_sitting_training_6.iloc[240:].reset_index()],axis=1)
training_data40 = pd.concat([data_sitting_training_7.iloc[0:240,1:7],data_sitting_training_7.iloc[240:].reset_index()],axis=1)
training_data41 = pd.concat([data_sitting_training_8.iloc[0:240,1:7],data_sitting_training_8.iloc[240:].reset_index()],axis=1)
training_data42 = pd.concat([data_sitting_training_9.iloc[0:240,1:7],data_sitting_training_9.iloc[240:].reset_index()],axis=1)
training_data43 = pd.concat([data_sitting_training_10.iloc[0:240,1:7],data_sitting_training_10.iloc[240:].reset_index()],axis=1)
training_data44 = pd.concat([data_sitting_training_11.iloc[0:240,1:7],data_sitting_training_11.iloc[240:].reset_index()],axis=1)
training_data45 = pd.concat([data_sitting_training_12.iloc[0:240,1:7],data_sitting_training_12.iloc[240:].reset_index()],axis=1)
training_data46 = pd.concat([data_standing_training_1.iloc[0:240,1:7],data_standing_training_1.iloc[240:].reset_index()],axis=1)
training_data47 = pd.concat([data_standing_training_2.iloc[0:240,1:7],data_standing_training_2.iloc[240:].reset_index()],axis=1)
training_data48 = pd.concat([data_standing_training_3.iloc[0:240,1:7],data_standing_training_3.iloc[240:].reset_index()],axis=1)
training_data49 = pd.concat([data_standing_training_4.iloc[0:240,1:7],data_standing_training_4.iloc[240:].reset_index()],axis=1)
training_data50 = pd.concat([data_standing_training_5.iloc[0:240,1:7],data_standing_training_5.iloc[240:].reset_index()],axis=1)
training_data51 = pd.concat([data_standing_training_6.iloc[0:240,1:7],data_standing_training_6.iloc[240:].reset_index()],axis=1)
training_data52 = pd.concat([data_standing_training_7.iloc[0:240,1:7],data_standing_training_7.iloc[240:].reset_index()],axis=1)
training_data53 = pd.concat([data_standing_training_8.iloc[0:240,1:7],data_standing_training_8.iloc[240:].reset_index()],axis=1)
training_data54 = pd.concat([data_standing_training_9.iloc[0:240,1:7],data_standing_training_9.iloc[240:].reset_index()],axis=1)
training_data55 = pd.concat([data_standing_training_10.iloc[0:240,1:7],data_standing_training_10.iloc[240:].reset_index()],axis=1)
training_data56 = pd.concat([data_standing_training_11.iloc[0:240,1:7],data_standing_training_11.iloc[240:].reset_index()],axis=1)
training_data57 = pd.concat([data_standing_training_12.iloc[0:240,1:7],data_standing_training_12.iloc[240:].reset_index()],axis=1)
training_data58 = pd.concat([data_walking_training_1.iloc[0:240,1:7],data_walking_training_1.iloc[240:].reset_index()],axis=1)
training_data59 = pd.concat([data_walking_training_2.iloc[0:240,1:7],data_walking_training_2.iloc[240:].reset_index()],axis=1)
training_data60 = pd.concat([data_walking_training_3.iloc[0:240,1:7],data_walking_training_3.iloc[240:].reset_index()],axis=1)
training_data61 = pd.concat([data_walking_training_4.iloc[0:240,1:7],data_walking_training_4.iloc[240:].reset_index()],axis=1)
training_data62 = pd.concat([data_walking_training_5.iloc[0:240,1:7],data_walking_training_5.iloc[240:].reset_index()],axis=1)
training_data63 = pd.concat([data_walking_training_6.iloc[0:240,1:7],data_walking_training_6.iloc[240:].reset_index()],axis=1)
training_data64 = pd.concat([data_walking_training_7.iloc[0:240,1:7],data_walking_training_7.iloc[240:].reset_index()],axis=1)
training_data65 = pd.concat([data_walking_training_8.iloc[0:240,1:7],data_walking_training_8.iloc[240:].reset_index()],axis=1)
training_data66 = pd.concat([data_walking_training_9.iloc[0:240,1:7],data_walking_training_9.iloc[240:].reset_index()],axis=1)
training_data67 = pd.concat([data_walking_training_10.iloc[0:240,1:7],data_walking_training_10.iloc[240:].reset_index()],axis=1)
training_data68 = pd.concat([data_walking_training_11.iloc[0:240,1:7],data_walking_training_11.iloc[240:].reset_index()],axis=1)
training_data69 = pd.concat([data_walking_training_12.iloc[0:240,1:7],data_walking_training_12.iloc[240:].reset_index()],axis=1)

# %%
training_data1=training_data1.drop(columns=['index','# Columns: time'])
training_data2=training_data2.drop(columns=['index','# Columns: time'])
training_data3=training_data3.drop(columns=['index','# Columns: time'])
training_data4=training_data4.drop(columns=['index','# Columns: time'])
training_data5=training_data5.drop(columns=['index','# Columns: time'])
training_data6=training_data6.drop(columns=['index','# Columns: time'])
training_data7=training_data7.drop(columns=['index','# Columns: time'])
training_data8=training_data8.drop(columns=['index','# Columns: time'])
training_data9=training_data9.drop(columns=['index','# Columns: time'])
training_data10=training_data10.drop(columns=['index','# Columns: time'])
training_data11=training_data11.drop(columns=['index','# Columns: time'])
training_data12=training_data12.drop(columns=['index','# Columns: time'])
training_data13=training_data13.drop(columns=['index','# Columns: time'])
training_data14=training_data14.drop(columns=['index','# Columns: time'])
training_data15=training_data15.drop(columns=['index','# Columns: time'])
training_data16=training_data16.drop(columns=['index','# Columns: time'])
training_data17=training_data17.drop(columns=['index','# Columns: time'])
training_data18=training_data18.drop(columns=['index','# Columns: time'])
training_data19=training_data19.drop(columns=['index','# Columns: time'])
training_data20=training_data20.drop(columns=['index','# Columns: time'])
training_data21=training_data21.drop(columns=['index','# Columns: time'])
training_data22=training_data22.drop(columns=['index','# Columns: time'])
training_data23=training_data23.drop(columns=['index','# Columns: time'])
training_data24=training_data24.drop(columns=['index','# Columns: time'])
training_data25=training_data25.drop(columns=['index','# Columns: time'])
training_data26=training_data26.drop(columns=['index','# Columns: time'])
training_data27=training_data27.drop(columns=['index','# Columns: time'])
training_data28=training_data28.drop(columns=['index','# Columns: time'])
training_data29=training_data29.drop(columns=['index','# Columns: time'])
training_data30=training_data30.drop(columns=['index','# Columns: time'])
training_data31=training_data31.drop(columns=['index','# Columns: time'])
training_data32=training_data32.drop(columns=['index','# Columns: time'])
training_data33=training_data33.drop(columns=['index','# Columns: time'])
training_data34=training_data34.drop(columns=['index','# Columns: time'])
training_data35=training_data35.drop(columns=['index','# Columns: time'])
training_data36=training_data36.drop(columns=['index','# Columns: time'])
training_data37=training_data37.drop(columns=['index','# Columns: time'])
training_data38=training_data38.drop(columns=['index','# Columns: time'])
training_data39=training_data39.drop(columns=['index','# Columns: time'])
training_data40=training_data40.drop(columns=['index','# Columns: time'])
training_data41=training_data41.drop(columns=['index','# Columns: time'])
training_data42=training_data42.drop(columns=['index','# Columns: time'])
training_data43=training_data43.drop(columns=['index','# Columns: time'])
training_data44=training_data44.drop(columns=['index','# Columns: time'])
training_data45=training_data45.drop(columns=['index','# Columns: time'])
training_data46=training_data46.drop(columns=['index','# Columns: time'])
training_data47=training_data47.drop(columns=['index','# Columns: time'])
training_data48=training_data48.drop(columns=['index','# Columns: time'])
training_data49=training_data49.drop(columns=['index','# Columns: time'])
training_data50=training_data50.drop(columns=['index','# Columns: time'])
training_data51=training_data51.drop(columns=['index','# Columns: time'])
training_data52=training_data52.drop(columns=['index','# Columns: time'])
training_data53=training_data53.drop(columns=['index','# Columns: time'])
training_data54=training_data54.drop(columns=['index','# Columns: time'])
training_data55=training_data55.drop(columns=['index','# Columns: time'])
training_data56=training_data56.drop(columns=['index','# Columns: time'])
training_data57=training_data57.drop(columns=['index','# Columns: time'])
training_data58=training_data58.drop(columns=['index','# Columns: time'])
training_data59=training_data59.drop(columns=['index','# Columns: time'])
training_data60=training_data60.drop(columns=['index','# Columns: time'])
training_data61=training_data61.drop(columns=['index','# Columns: time'])
training_data62=training_data62.drop(columns=['index','# Columns: time'])
training_data63=training_data63.drop(columns=['index','# Columns: time'])
training_data64=training_data64.drop(columns=['index','# Columns: time'])
training_data65=training_data65.drop(columns=['index','# Columns: time'])
training_data66=training_data66.drop(columns=['index','# Columns: time'])
training_data67=training_data67.drop(columns=['index','# Columns: time'])
training_data68=training_data68.drop(columns=['index','# Columns: time'])
training_data69=training_data69.drop(columns=['index','# Columns: time'])

# %%
data_training_min_1=training_data1.min()
data_training_min_2=training_data2.min()
data_training_min_3=training_data3.min()
data_training_min_4=training_data4.min()
data_training_min_5=training_data5.min()
data_training_min_6=training_data6.min()
data_training_min_7=training_data7.min()
data_training_min_8=training_data8.min()
data_training_min_9=training_data9.min()
data_training_min_10=training_data10.min()
data_training_min_11=training_data11.min()
data_training_min_12=training_data12.min()
data_training_min_13=training_data13.min()
data_training_min_14=training_data14.min()
data_training_min_15=training_data15.min()
data_training_min_16=training_data16.min()
data_training_min_17=training_data17.min()
data_training_min_18=training_data18.min()
data_training_min_19=training_data19.min()
data_training_min_20=training_data20.min()
data_training_min_21=training_data21.min()
data_training_min_22=training_data22.min()
data_training_min_23=training_data23.min()
data_training_min_24=training_data24.min()
data_training_min_25=training_data25.min()
data_training_min_26=training_data26.min()
data_training_min_27=training_data27.min()
data_training_min_28=training_data28.min()
data_training_min_29=training_data29.min()
data_training_min_30=training_data30.min()
data_training_min_31=training_data31.min()
data_training_min_32=training_data32.min()
data_training_min_33=training_data33.min()
data_training_min_34=training_data34.min()
data_training_min_35=training_data35.min()
data_training_min_36=training_data36.min()
data_training_min_37=training_data37.min()
data_training_min_38=training_data38.min()
data_training_min_39=training_data39.min()
data_training_min_40=training_data40.min()
data_training_min_41=training_data41.min()
data_training_min_42=training_data42.min()
data_training_min_43=training_data43.min()
data_training_min_44=training_data44.min()
data_training_min_45=training_data45.min()
data_training_min_46=training_data46.min()
data_training_min_47=training_data47.min()
data_training_min_48=training_data48.min()
data_training_min_49=training_data49.min()
data_training_min_50=training_data50.min()
data_training_min_51=training_data51.min()
data_training_min_52=training_data52.min()
data_training_min_53=training_data53.min()
data_training_min_54=training_data54.min()
data_training_min_55=training_data55.min()
data_training_min_56=training_data56.min()
data_training_min_57=training_data57.min()
data_training_min_58=training_data58.min()
data_training_min_59=training_data59.min()
data_training_min_60=training_data60.min()
data_training_min_61=training_data61.min()
data_training_min_62=training_data62.min()
data_training_min_63=training_data63.min()
data_training_min_64=training_data64.min()
data_training_min_65=training_data65.min()
data_training_min_66=training_data66.min()
data_training_min_67=training_data67.min()
data_training_min_68=training_data68.min()
data_training_min_69=training_data69.min()

# %%
data_training_max_1=training_data1.max()
data_training_max_2=training_data2.max()
data_training_max_3=training_data3.max()
data_training_max_4=training_data4.max()
data_training_max_5=training_data5.max()
data_training_max_6=training_data6.max()
data_training_max_7=training_data7.max()
data_training_max_8=training_data8.max()
data_training_max_9=training_data9.max()
data_training_max_10=training_data10.max()
data_training_max_11=training_data11.max()
data_training_max_12=training_data12.max()
data_training_max_13=training_data13.max()
data_training_max_14=training_data14.max()
data_training_max_15=training_data15.max()
data_training_max_16=training_data16.max()
data_training_max_17=training_data17.max()
data_training_max_18=training_data18.max()
data_training_max_19=training_data19.max()
data_training_max_20=training_data20.max()
data_training_max_21=training_data21.max()
data_training_max_22=training_data22.max()
data_training_max_23=training_data23.max()
data_training_max_24=training_data24.max()
data_training_max_25=training_data25.max()
data_training_max_26=training_data26.max()
data_training_max_27=training_data27.max()
data_training_max_28=training_data28.max()
data_training_max_29=training_data29.max()
data_training_max_30=training_data30.max()
data_training_max_31=training_data31.max()
data_training_max_32=training_data32.max()
data_training_max_33=training_data33.max()
data_training_max_34=training_data34.max()
data_training_max_35=training_data35.max()
data_training_max_36=training_data36.max()
data_training_max_37=training_data37.max()
data_training_max_38=training_data38.max()
data_training_max_39=training_data39.max()
data_training_max_40=training_data40.max()
data_training_max_41=training_data41.max()
data_training_max_42=training_data42.max()
data_training_max_43=training_data43.max()
data_training_max_44=training_data44.max()
data_training_max_45=training_data45.max()
data_training_max_46=training_data46.max()
data_training_max_47=training_data47.max()
data_training_max_48=training_data48.max()
data_training_max_49=training_data49.max()
data_training_max_50=training_data50.max()
data_training_max_51=training_data51.max()
data_training_max_52=training_data52.max()
data_training_max_53=training_data53.max()
data_training_max_54=training_data54.max()
data_training_max_55=training_data55.max()
data_training_max_56=training_data56.max()
data_training_max_57=training_data57.max()
data_training_max_58=training_data58.max()
data_training_max_59=training_data59.max()
data_training_max_60=training_data60.max()
data_training_max_61=training_data61.max()
data_training_max_62=training_data62.max()
data_training_max_63=training_data63.max()
data_training_max_64=training_data64.max()
data_training_max_65=training_data65.max()
data_training_max_66=training_data66.max()
data_training_max_67=training_data67.max()
data_training_max_68=training_data68.max()
data_training_max_69=training_data69.max()

# %%
data_training_mean_1=training_data1.mean()
data_training_mean_2=training_data2.mean()
data_training_mean_3=training_data3.mean()
data_training_mean_4=training_data4.mean()
data_training_mean_5=training_data5.mean()
data_training_mean_6=training_data6.mean()
data_training_mean_7=training_data7.mean()
data_training_mean_8=training_data8.mean()
data_training_mean_9=training_data9.mean()
data_training_mean_10=training_data10.mean()
data_training_mean_11=training_data11.mean()
data_training_mean_12=training_data12.mean()
data_training_mean_13=training_data13.mean()
data_training_mean_14=training_data14.mean()
data_training_mean_15=training_data15.mean()
data_training_mean_16=training_data16.mean()
data_training_mean_17=training_data17.mean()
data_training_mean_18=training_data18.mean()
data_training_mean_19=training_data19.mean()
data_training_mean_20=training_data20.mean()
data_training_mean_21=training_data21.mean()
data_training_mean_22=training_data22.mean()
data_training_mean_23=training_data23.mean()
data_training_mean_24=training_data24.mean()
data_training_mean_25=training_data25.mean()
data_training_mean_26=training_data26.mean()
data_training_mean_27=training_data27.mean()
data_training_mean_28=training_data28.mean()
data_training_mean_29=training_data29.mean()
data_training_mean_30=training_data30.mean()
data_training_mean_31=training_data31.mean()
data_training_mean_32=training_data32.mean()
data_training_mean_33=training_data33.mean()
data_training_mean_34=training_data34.mean()
data_training_mean_35=training_data35.mean()
data_training_mean_36=training_data36.mean()
data_training_mean_37=training_data37.mean()
data_training_mean_38=training_data38.mean()
data_training_mean_39=training_data39.mean()
data_training_mean_40=training_data40.mean()
data_training_mean_41=training_data41.mean()
data_training_mean_42=training_data42.mean()
data_training_mean_43=training_data43.mean()
data_training_mean_44=training_data44.mean()
data_training_mean_45=training_data45.mean()
data_training_mean_46=training_data46.mean()
data_training_mean_47=training_data47.mean()
data_training_mean_48=training_data48.mean()
data_training_mean_49=training_data49.mean()
data_training_mean_50=training_data50.mean()
data_training_mean_51=training_data51.mean()
data_training_mean_52=training_data52.mean()
data_training_mean_53=training_data53.mean()
data_training_mean_54=training_data54.mean()
data_training_mean_55=training_data55.mean()
data_training_mean_56=training_data56.mean()
data_training_mean_57=training_data57.mean()
data_training_mean_58=training_data58.mean()
data_training_mean_59=training_data59.mean()
data_training_mean_60=training_data60.mean()
data_training_mean_61=training_data61.mean()
data_training_mean_62=training_data62.mean()
data_training_mean_63=training_data63.mean()
data_training_mean_64=training_data64.mean()
data_training_mean_65=training_data65.mean()
data_training_mean_66=training_data66.mean()
data_training_mean_67=training_data67.mean()
data_training_mean_68=training_data68.mean()
data_training_mean_69=training_data69.mean()

# %%
array2 = [[(eval('data_training_min_'+str(x)))[0:],eval('data_training_max_'+str(x))[0:],eval('data_training_mean_'+str(x))[0:]] for x in range(1,70)]

# %%
total_columns =['min_avg_rss12','min_var_rss12','min_avg_rss13','min_var_rss13','min_avg_rss23','min_var_rss23','min1_avg_rss12','min1_var_rss12','min1_avg_rss13','min1_var_rss13','min1_avg_rss23','min1_var_rss23','max_avg_rss12','max_var_rss12','max_avg_rss13','max_var_rss13','max_avg_rss23','max_var_rss23','max1_avg_rss12','max1_var_rss12','max1_avg_rss13','max1_var_rss13','max1_avg_rss23','max1_var_rss23','mean_avg_rss12','mean_var_rss12','mean_avg_rss13','mean_var_rss13','mean_avg_rss23','mean_var_rss23','mean1_avg_rss12','mean1_var_rss12','mean1_avg_rss13','mean1_var_rss13','mean1_avg_rss23','mean1_var_rss23']

# %%
Training_data= pd.DataFrame(columns=total_columns)

# %%
for i in range(0,69):
    Training_data.loc[i] = list(itertools.chain.from_iterable(array2[i]))

# %% [markdown]
# Depicting scatter plots of the features extracted from both parts of the time series 1,2, and 12

# %%
bending_data_min=Training_data.iloc[0:9,[0,1,11]]
other_data_min=Training_data.iloc[9:70,[0,1,11]]
ax = bending_data_min.plot(style='ro', legend=False)
other_data_min.plot(style='bo',ax=ax, legend=False)
plt.show()
print("Red is for bending data and blue is for other activities")
# Out:
# Red is for bending data and blue is for other activities

# %%
bending_data_max=Training_data.iloc[0:9,[12,13,23]]
other_data_max=Training_data.iloc[9:70,[12,13,23]]
ax = bending_data_max.plot(style='ro', legend=False)
other_data_max.plot(style='bo',ax=ax, legend=False)
plt.show()
print("Red is for bending data and blue is for other activities")
# Out:
# Red is for bending data and blue is for other activities

# %%
bending_data_mean=Training_data.iloc[0:9,[24,25,35]]
other_data_mean=Training_data.iloc[9:70,[24,25,35]]
ax = bending_data_mean.plot(style='ro', legend=False)
other_data_mean.plot(style='bo',ax=ax, legend=False)
plt.show()
print("Red is for bending data and blue is for other activities")
# Out:
# Red is for bending data and blue is for other activities

# %%
mylist = [data_bending1_training_1,data_bending1_training_2,data_bending1_training_3,data_bending1_training_4,data_bending1_training_5,data_bending2_training_1,data_bending2_training_2,data_bending2_training_3,
data_bending2_training_4,data_cycling_training_1,data_cycling_training_2,data_cycling_training_3,data_cycling_training_4,data_cycling_training_5,
data_cycling_training_6,data_cycling_training_7,data_cycling_training_8,data_cycling_training_9,data_cycling_training_10,data_cycling_training_11,
data_cycling_training_12,data_lying_training_1,data_lying_training_2,data_lying_training_3,data_lying_training_4,data_lying_training_5,
data_lying_training_6,data_lying_training_7,data_lying_training_8,data_lying_training_9,data_lying_training_10,data_lying_training_11,data_lying_training_12,
data_sitting_training_1,data_sitting_training_2,data_sitting_training_3,data_sitting_training_4,data_sitting_training_5,data_sitting_training_6,
data_sitting_training_7,data_sitting_training_8,data_sitting_training_9,data_sitting_training_10,data_sitting_training_11,data_sitting_training_12,
data_standing_training_1,data_standing_training_2,data_standing_training_3,data_standing_training_4,data_standing_training_5,data_standing_training_6,
data_standing_training_7,data_standing_training_8,data_standing_training_9,data_standing_training_10,data_standing_training_11,data_standing_training_12,data_walking_training_1,data_walking_training_2,
data_walking_training_3,data_walking_training_4,data_walking_training_5,data_walking_training_6,data_walking_training_7,data_walking_training_8,data_walking_training_9,data_walking_training_10,
data_walking_training_11,data_walking_training_12]

# %%
Train_1=pd.DataFrame()
Train_2=pd.DataFrame()
Train_3=pd.DataFrame()
Train_4=pd.DataFrame()
Train_5=pd.DataFrame()
Train_6=pd.DataFrame()
Train_7=pd.DataFrame()
Train_8=pd.DataFrame()
Train_9=pd.DataFrame()
Train_10=pd.DataFrame()
Train_11=pd.DataFrame()
Train_12=pd.DataFrame()
Train_13=pd.DataFrame()
Train_14=pd.DataFrame()
Train_15=pd.DataFrame()
Train_16=pd.DataFrame()
Train_17=pd.DataFrame()
Train_18=pd.DataFrame()
Train_19=pd.DataFrame()
Train_20=pd.DataFrame()

dataframe_train=[Train_1,Train_2,Train_3,Train_4,Train_5,Train_6,Train_7,Train_8,Train_9,Train_10,Train_11,Train_12,Train_13,Train_14,Train_15,Train_16,Train_17,Train_18,Train_19,Train_20]

# %%
total_columns =['min_avg_rss12','min_var_rss12','min_avg_rss13','min_var_rss13','min_avg_rss23',
                'min_var_rss23','max_avg_rss12','max_var_rss12','max_avg_rss13','max_var_rss13',
                'max_avg_rss23','max_var_rss23','mean_avg_rss12','mean_var_rss12','mean_avg_rss13',
                'mean_var_rss13','mean_avg_rss23','mean_var_rss23','median_avg_rss12','median_var_rss12',
                'median_avg_rss13','median_var_rss13','median_avg_rss23','median_var_rss23','std_avg_rss12',
                'std_var_rss12','std_avg_rss13','std_var_rss13','std_avg_rss23','std_var_rss23','q25_avg_rss12',
                'q25_var_rss12','q25_avg_rss13','q25_var_rss13','q25_avg_rss23','q25_var_rss23','q75_avg_rss12',
                'q75_var_rss12','q75_avg_rss13','q75_var_rss13','q75_avg_rss23','q75_var_rss23']

# %% [markdown]
# Spliting the data into l=(1,2,20)

# %%
for i in range(0,20):
    dataframe_train[i] = pd.DataFrame(columns=total_columns)
    for j in range(0,69):
        training_data_split = np.array_split(mylist[j],i+1)
        for a in range(0,i+1):   
            df_mean = training_data_split[a].mean()
            df_max = training_data_split[a].max()
            df_min = training_data_split[a].min()
            df_median = training_data_split[a].median()
            df_std = training_data_split[a].std()
            df_q25 = training_data_split[a].quantile(0.25)
            df_q75 = training_data_split[a].quantile(0.75)
            array2 = [df_min[1:],df_max[1:],df_mean[1:],df_median[1:],df_std[1:],df_q25[1:],df_q75[1:]]
            dataframe_train[i]= dataframe_train[i].append(pd.Series(list(itertools.chain.from_iterable(array2)),index=total_columns),ignore_index=True)

# %% [markdown]
# Calculating P values using RFE

# %%
count=1
a = [0] * 9
b = [1] * 60
for i in range(0,20):
    k = a * count
    v = b * count
    y_train_all = k + v
    logreg = LogisticRegression()
    rfe = RFE(logreg,7)
    rfe = rfe.fit(dataframe_train[i], y_train_all)
    print(rfe.support_)
    print(rfe.ranking_)
    scores = cross_val_score(rfe, dataframe_train[i], y_train_all, cv=5)
    print("P value scores")
    print(scores.mean())
    count=count+1
# Out:
# [False False False False  True False False  True False False  True False
#   True False False False  True False False False False False False False
#  False False False False False False False False False False  True False
#   True False False False False False]
# [ 9 36 22 35  1 34 33  1  6 25  1  3  1 15 18 16  1 11 30 27  2 13 12 14
#  21 20 24 32 31 26 19 28 29 23  1 17  1  4  7  8 10  5]
# P value scores
# 0.9857142857142858
# [False False False False False False False False  True False  True False
#  False False False False False False False False False  True False False
#  False False False False  True False False False False False False False
#   True False  True  True False False]
# [33 35 17 36  4 34  8  7  1 18  1 14  6  2 10 11 12 28 22 30 24  1 21 15
#   9  5 29 20  1 26 27 32 23 16 13 19  1  3  1  1 31 25]
# P value scores
# 0.8997354497354497
# [False False False False False False False False False False  True False
# ...

# %%
print("From the above output we can see the best L is 1")
# Out:
# From the above output we can see the best L is 1

# %% [markdown]
# Based on the best value of L, Logistic regression model will be built

# %%
m=1
dataframe_train_1 = pd.DataFrame(columns=total_columns)
for j in mylist:
    training_data_split = np.array_split(j,1)
    a=1
    for i in range(0,a):   
        dt1 = training_data_split[i]
        dt1_mean = dt1.mean()
        dt1_max = dt1.max()
        dt1_min = dt1.min()
        dt1_median = dt1.median()
        dt1_std = dt1.std()
        dt1_q25 = dt1.quantile(0.25)
        dt1_q75 = dt1.quantile(0.50)
        array2 = [dt1_min[1:],dt1_max[1:],dt1_mean[1:],dt1_median[1:],dt1_std[1:],dt1_q25[1:],dt1_q75[1:]]
        dataframe_train_1.loc[m] = list(itertools.chain.from_iterable(array2))
        m=m+1

# %% [markdown]
# Fitting Logistic regression model using the best value of L

# %%
a=[0]*9
b=[1]*60
X_train_data = dataframe_train_1.as_matrix()
y_train_data = a+b
X_train, X_test, y_train, y_test = train_test_split(X_train_data, y_train_data, test_size=0.30, random_state=0)
logreg_train = LogisticRegression(solver='newton-cg',C=5.0)
result1 = logreg_train.fit(X_train, y_train)
print(result1)
# Out:
# LogisticRegression(C=5.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# Confusion Matrix

# %%
y_pred_train = logreg_train.predict(X_test)
y_actu = pd.Series(y_test)
y_pred = pd.Series(y_pred_train)
df_confusion = pd.crosstab(y_actu, y_pred)
df_confusion
# Out:
# col_0  0   1
# row_0
# 0      2   0
# 1      0  19

# %% [markdown]
# AUC

# %%
preds = logreg_train.predict_proba(X_test)[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test, preds)
auc = metrics.auc(fpr,tpr)
print(auc)
# Out:
# 1.0

# %% [markdown]
# ROC Curve

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Parameters of Logistic Regression

# %%
logreg_train.coef_
# Out:
# array([[-1.21963559e-02,  0.00000000e+00,  8.60193930e-02,
#          0.00000000e+00, -3.85419351e-01,  1.89357955e-05,
#          1.52018740e-02,  2.09510054e-01, -4.24279830e-02,
#         -6.63573484e-02, -8.36281695e-01, -2.04644899e-02,
#          1.96570015e-01,  9.83496730e-02,  9.55355952e-02,
#          8.43057439e-02, -2.35759491e-01,  8.57906993e-02,
#          8.88391021e-02,  7.58621969e-02,  1.90121539e-01,
#          8.98080598e-02, -1.36969830e-01,  7.48860070e-02,
#          6.27299937e-02,  5.97540771e-02, -1.18804592e-02,
#          2.14519976e-02,  7.55767610e-03,  4.70528704e-02,
#          1.49246463e-01,  6.89808838e-02,  7.33861287e-02,
#          5.07372924e-02, -2.02666497e-01,  4.72874544e-02,
#          8.88391021e-02,  7.58621969e-02,  1.90121539e-01,
#          8.98080598e-02, -1.36969830e-01,  7.48860070e-02]])

# %%
model = sm.OLS(y_train,X_train)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     192.0
# Date:                Mon, 25 Feb 2019   Prob (F-statistic):           4.89e-14
# Time:                        22:00:38   Log-Likelihood:                 83.202
# No. Observations:                  48   AIC:                            -98.40
# Df Residuals:                      14   BIC:                            -34.78
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0086      0.004      2.441      0.029       0.001       0.016
# ...

# %%
mylist=[data_bending1_test_1,data_bending1_test_2,data_bending2_test_1,data_bending2_test_2,data_cycling_test_1,data_cycling_test_2,data_cycling_test_3,data_lying_test_1,data_lying_test_2,data_lying_test_3,data_sitting_test_1,data_sitting_test_2,data_sitting_test_3,data_standing_test_1,data_standing_test_2,data_standing_test_3,data_walking_test_1,data_walking_test_2,data_walking_test_3]

# %%
Test_1=pd.DataFrame()
Test_2=pd.DataFrame()
Test_3=pd.DataFrame()
Test_4=pd.DataFrame()
Test_5=pd.DataFrame()
Test_6=pd.DataFrame()
Test_7=pd.DataFrame()
Test_8=pd.DataFrame()
Test_9=pd.DataFrame()
Test_10=pd.DataFrame()
Test_11=pd.DataFrame()
Test_12=pd.DataFrame()
Test_13=pd.DataFrame()
Test_14=pd.DataFrame()
Test_15=pd.DataFrame()
Test_16=pd.DataFrame()
Test_17=pd.DataFrame()
Test_18=pd.DataFrame()
Test_19=pd.DataFrame()
Test_20=pd.DataFrame()

dataframe_Test=[Test_1,Test_2,Test_3,Test_4,Test_5,Test_6,Test_7,Test_8,Test_9,Test_10,Test_11,Test_12,Test_13,Test_14,Test_15,Test_16,Test_17,Test_18,Test_19,Test_20]

# %%
total_columns =['min_avg_rss12','min_var_rss12','min_avg_rss13','min_var_rss13','min_avg_rss23',
                'min_var_rss23','max_avg_rss12','max_var_rss12','max_avg_rss13','max_var_rss13',
                'max_avg_rss23','max_var_rss23','mean_avg_rss12','mean_var_rss12','mean_avg_rss13',
                'mean_var_rss13','mean_avg_rss23','mean_var_rss23','median_avg_rss12','median_var_rss12',
                'median_avg_rss13','median_var_rss13','median_avg_rss23','median_var_rss23','std_avg_rss12',
                'std_var_rss12','std_avg_rss13','std_var_rss13','std_avg_rss23','std_var_rss23','q25_avg_rss12',
                'q25_var_rss12','q25_avg_rss13','q25_var_rss13','q25_avg_rss23','q25_var_rss23','q75_avg_rss12',
                'q75_var_rss12','q75_avg_rss13','q75_var_rss13','q75_avg_rss23','q75_var_rss23']

# %%
for i in range(0,20):
    dataframe_Test[i] = pd.DataFrame(columns=total_columns)
    for j in range(0,19):
        test_data_split = np.array_split(mylist[j],i+1)
        for a in range(0,i+1):   
            df_mean = test_data_split[a].mean()
            df_max = test_data_split[a].max()
            df_min = test_data_split[a].min()
            df_median = test_data_split[a].median()
            df_std = test_data_split[a].std()
            df_q25 = test_data_split[a].quantile(0.25)
            df_q75 = test_data_split[a].quantile(0.75)
            array2 = [df_min[1:],df_max[1:],df_mean[1:],df_median[1:],df_std[1:],df_q25[1:],df_q75[1:]]
            dataframe_Test[i]= dataframe_Test[i].append(pd.Series(list(itertools.chain.from_iterable(array2)),index=total_columns),ignore_index=True)

# %% [markdown]
# Running Logistic Regression model for test set

# %%
count=1
a = [0] * 4
b = [1] * 15
for i in range(0,20):
    k = a * count
    v = b * count
    y_test_all = k + v
    logreg = LogisticRegression()
    rfe = RFE(logreg,7)
    rfe = rfe.fit(dataframe_Test[i], y_test_all)
    print(rfe.support_)
    print(rfe.ranking_)
    scores = cross_val_score(logreg, dataframe_Test[i], y_test_all, cv=5)
    print(scores.mean())
    count=count+1
# Out:
# [False False False False False False False  True False False  True False
#   True False False False  True False False False False False  True False
#  False False False False False False False False False False False False
#   True False False False  True False]
# [ 3 36 29 35  8 34 12  1  6 15  1  4  1 17 14 20  1 21  5 22 11 19  1 23
#  26 28 32 31 33 30  9 25 10 24  2 27  1  7 18 13  1 16]
# C:\Users\Rohit Kulkarni\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 4 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# 0.95
# [False False False False  True False False  True False False  True False
#   True False False False False False False False False False False False
#  False False False False False False False False  True False False False
#   True False  True False False False]
# ...

# %% [markdown]
# Best L in this case is 2, hence splitting the data and performing Logistic regression

# %%
m=1
dataframe_test_1 = pd.DataFrame(columns=total_columns)
for j in mylist:
    test_data_split = np.array_split(j,2)
    a=2
    for i in range(0,a):   
        dt1 = test_data_split[i]
        dt1_mean = dt1.mean()
        dt1_max = dt1.max()
        dt1_min = dt1.min()
        dt1_median = dt1.median()
        dt1_std = dt1.std()
        dt1_q25 = dt1.quantile(0.25)
        dt1_q75 = dt1.quantile(0.50)
        array2 = [dt1_min[1:],dt1_max[1:],dt1_mean[1:],dt1_median[1:],dt1_std[1:],dt1_q25[1:],dt1_q75[1:]]
        dataframe_test_1.loc[m] = list(itertools.chain.from_iterable(array2))
        m=m+1

# %%
a = [0] * 4 * 2
b = [1] * 15 * 2
X_train_data = dataframe_test_1.as_matrix()
y_train_data = a+b
X_train, X_test, y_train, y_test = train_test_split(X_train_data, y_train_data, test_size=0.30, random_state=0)
logreg_train = LogisticRegression(solver='newton-cg',C=5.0)
result1 = logreg_train.fit(X_train, y_train)
print(result1)
# Out:
# LogisticRegression(C=5.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred_train = logreg_train.predict(X_test)
y_actu = pd.Series(y_test)
y_pred = pd.Series(y_pred_train)
df_confusion = pd.crosstab(y_actu, y_pred)
print(df_confusion)
# Out:
# col_0  0   1
# row_0
# 0      1   0
# 1      0  11

# %% [markdown]
# L1-penalized Logistic Regression

# %%
count=1
a = [0] * 9
b = [1] * 60
for i in range(0,20):
    k = a * count
    v = b * count
    y_train_all = k + v
    logreg = LogisticRegression(penalty='l1', solver='liblinear', C=1)
    result=logreg.fit(dataframe_train[i],y_train_all)
    scores = cross_val_score(result, dataframe_train[i], y_train_all, cv=5)
    print("L1-penalized scores")
    print(scores.mean())
    count=count+1
# Out:
# L1-penalized scores
# 0.9714285714285715
# L1-penalized scores
# 0.9137566137566138
# L1-penalized scores
# 0.8880371660859465
# L1-penalized scores
# 0.9164935064935065
# L1-penalized scores
# 0.8840579710144928
# L1-penalized scores
# 0.9010578900969733
# L1-penalized scores
# 0.9028994845360824
# L1-penalized scores
# 0.9073873873873873
# L1-penalized scores
# 0.9080645161290324
# L1-penalized scores
# 0.9028985507246376
# L1-penalized scores
# 0.9038602300453119
# L1-penalized scores
# 0.9095290251916758
# L1-penalized scores
# 0.8961576660459342
# L1-penalized scores
# 0.8984455958549222
# L1-penalized scores
# 0.8946859903381641
# L1-penalized scores
# 0.8858988070752776
# L1-penalized scores
# 0.8977777777777778
# L1-penalized scores
# 0.8960195621194454
# L1-penalized scores
# 0.8931355760020898
# ...

# %%
print("Best L value from the L1-penalized logistic regression model is 1")
# Out:
# Best L value from the L1-penalized logistic regression model is 1

# %% [markdown]
# L1-penalized multinomial regression model

# %%
count=1
a = [0] * 9
b = [1] * 12
c = [2] * 12
d = [3] * 12
e = [4] * 12
f = [5] * 12
for i in range(0,20):
    k = a * count
    l = b * count
    m = c * count
    n = d * count
    o = e * count
    p = f * count
    y_train_all = k + l + m + n + o + p
    logreg = LogisticRegression(penalty='l1',solver='saga', C=1,multi_class='multinomial')
    result=logreg.fit(dataframe_train[i],y_train_all)
    scores = cross_val_score(result, dataframe_train[i], y_train_all, cv=5)
    print("L1-penalized scores")
    print(scores.mean())
    count=count+1
print(logreg)
# Out:
# C:\Users\Rohit Kulkarni\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Rohit Kulkarni\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Rohit Kulkarni\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\Rohit Kulkarni\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# ...

# %%
print("Best L value from the L1-penalized multinomial regression model is 1")
# Out:
# Best L value from the L1-penalized multinomial regression model is 1

# %% [markdown]
# Test Error

# %%
X_train, X_test, y_train, y_test = train_test_split(dataframe_train[0], y, test_size=.5,random_state=0)
print("Test Errors")
print(logreg.score(X_test,y_test))
# Out:
# Test Errors
# 0.8857142857142857

# %% [markdown]
# Confusion matrices and ROC curves for multiclass classification

# %%
from sklearn.metrics import roc_curve, auc
a = [0] * 9
b = [1] * 12
c = [2] * 12
d = [3] * 12
e = [4] * 12
f = [5] * 12
y = a+b+c+d+e+f
y = label_binarize(y, classes=[0,1,2,3,4,5])
n_classes = y.shape[1]
random_state = np.random.RandomState(0)
lw = 2
X_train, X_test, y_train, y_test = train_test_split(dataframe_train[0], y, test_size=.5,random_state=0)
classifier = OneVsRestClassifier(svm.SVC(kernel='linear', probability=True,random_state=random_state))
y_score = classifier.fit(X_train, y_train).decision_function(X_test)

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
y_pred_train = classifier.predict(X_test)
for i in range(n_classes):
    y_actu = pd.Series(y_test[:, i])
    y_pred = pd.Series(y_pred_train[:, i])
    df_confusion = pd.crosstab(y_actu, y_pred)
    print(df_confusion)
# Out:
# col_0   0  1
# row_0
# 0      31  0
# 1       2  2
# col_0   0  1
# row_0
# 0      30  2
# 1       0  3
# col_0   0  1
# row_0
# 0      27  1
# 1       0  7
# col_0   0   1
# row_0
# 0      19  10
# 1       0   6
# col_0   0  1
# row_0
# 0      27  0
# 1       6  2
# col_0   0  1
# row_0
# 0      28  0
# 1       0  7

# %% [markdown]
# Naive Bayes' classifier using Gaussian

# %%
count=1
a = [0] * 9
b = [1] * 12
c = [2] * 12
d = [3] * 12
e = [4] * 12
f = [5] * 12
for i in range(0,20):
    k = a * count
    l = b * count
    m = c * count
    n = d * count
    o = e * count
    p = f * count
    y_train_all = k + l + m + n + o + p
    nb = GaussianNB()
    result1 = nb.fit(dataframe_train[i],y_train_all)
    print(nb.score(dataframe_train[i],y_train_all))
    count= count+1
# Out:
# 0.9855072463768116
# 0.9492753623188406
# 0.8840579710144928
# 0.8695652173913043
# 0.855072463768116
# 0.8357487922705314
# 0.8612836438923396
# 0.822463768115942
# 0.8405797101449275
# 0.8014492753623188
# 0.8063241106719368
# 0.8043478260869565
# 0.7959866220735786
# 0.7888198757763976
# 0.7942028985507247
# 0.7880434782608695
# 0.783461210571185
# 0.7954911433172303
# 0.7971014492753623
# 0.7934782608695652

# %% [markdown]
# Naive Bayes' classifier using Multi-nomial priors

# %%
count=1
a = [0] * 9
b = [1] * 12
c = [2] * 12
d = [3] * 12
e = [4] * 12
f = [5] * 12
for i in range(0,20):
    k = a * count
    l = b * count
    m = c * count
    n = d * count
    o = e * count
    p = f * count
    y_train_all = k + l + m + n + o + p
    nb = MultinomialNB()
    result2 = nb.fit(dataframe_train[i],y_train_all)
    print(nb.score(dataframe_train[i],y_train_all))
    count=count+1
# Out:
# 0.927536231884058
# 0.8115942028985508
# 0.8115942028985508
# 0.7862318840579711
# 0.8028985507246377
# 0.7801932367149759
# 0.7701863354037267
# 0.7844202898550725
# 0.7665056360708534
# 0.7724637681159421
# 0.761528326745718
# 0.7705314009661836
# 0.7658862876254181
# 0.7577639751552795
# 0.7603864734299517
# 0.7608695652173914
# 0.7621483375959079
# 0.7616747181964574
# 0.7589626239511823
# 0.7681159420289855
